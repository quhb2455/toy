# %%
from scipy import io

# %%
mat_file = io.loadmat('test.mat')

mat_file
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: posix, Created on: Fri Sep 24 05:20:22 2021',
#  '__version__': '1.0',
#  '__globals__': [],
#  'cropped_img': array([[[159, 186, 188],
#          [161, 188, 190],
#          [162, 189, 191],
#          ...,
#          [164, 185, 188],
#          [166, 186, 189],
#          [165, 185, 188]],
#
#         [[161, 187, 189],
#          [160, 185, 186],
#          [163, 189, 190],
#          ...,
#          [164, 185, 188],
#          [164, 185, 186],
#          [164, 185, 186]],
#
#         [[159, 187, 188],
#          [159, 185, 186],
#          [160, 186, 187],
#          ...,
#          [165, 184, 188],
#          [164, 184, 185],
#          [164, 184, 185]],
#
#         ...,
#
#         [[182, 182, 180],
#          [180, 180, 178],
#          [179, 179, 177],
#          ...,
#          [213, 209, 208],
#          [214, 210, 208],
#          [217, 213, 210]],
#
#         [[181, 181, 179],
#          [179, 179, 177],
# ...

# %%
print(mat_file['face_shape'].shape)
print(mat_file['face_color'].shape)
print(mat_file['face_texture'].shape)
print(mat_file['recon_img'].shape)
print(mat_file['cropped_img'].shape)
print(mat_file['coeff'].shape)
import cv2
cv2.imwrite('./test2.png', mat_file['recon_img'])
# Out:
# (35709, 3)
# (35709, 3)
# (35709, 3)
# (224, 224, 4)
# (224, 224, 3)
# (1, 257)
# True

# %%
print(mat_file['coeff'][0]*480)
# Out:
# [-3.00237000e+02 -4.06681244e+02 -5.99048523e+02  8.94634888e+02
#  -3.05140285e+01 -4.08734497e+02  8.69137390e+02 -4.58585691e+00
#  -1.16736473e+02 -7.71060562e+01 -7.16471924e+02 -2.15957123e+02
#  -1.40905685e+02 -7.31800354e+02 -1.41908093e+03  3.58297211e+02
#  -6.96956238e+02  2.87353729e+02 -1.94092056e+02  1.80288391e+02
#   5.49540091e+00 -4.90996674e+02 -3.73795105e+02 -2.26378693e+02
#  -1.62340622e+02 -3.23243256e+02 -7.11472244e+01 -5.90261780e+02
#  -2.15703766e+02 -6.43696289e+01  2.33384521e+02  2.36148095e+00
#   2.59797272e+02 -3.66872955e+02  5.12393188e+02 -3.26623749e+02
#   3.17811462e+02  1.02332336e+03 -2.53027725e+02  5.88852844e+02
#   1.60605591e+02 -2.01527573e+02  3.65185730e+02 -2.87059784e+02
#  -3.94462799e+02  4.10677063e+02  2.23626633e+01  4.85409431e+01
#  -4.07333832e+02  3.89497009e+02 -1.63796265e+02 -2.21838165e+02
#   5.22856140e+02 -1.99550766e+02  1.24154431e+03  4.36766907e+02
# ...
