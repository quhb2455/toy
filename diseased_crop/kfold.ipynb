# %%
from glob import glob
from tqdm import tqdm
import pandas as pd
import json
import albumentations as A
import numpy as np
import cv2
from sklearn.model_selection import train_test_split, StratifiedKFold
import torch
import torch.nn
from torch.utils.data import Dataset

# %%
class CustomDataset(Dataset):
    def __init__(self, files, transforms, mode='train'):
        self.mode = mode
        self.files = files
        self.csv_feature_dict = csv_feature_dict
        self.csv_feature_check = [0]*len(self.files)
        self.csv_features = [None]*len(self.files)
        self.max_len = 24 * 6
        self.label_encoder = train_label_encoder #label_encoder
        self.transforms = transforms
    def __len__(self):
        return len(self.files)
    
    def __getitem__(self, i):
        file = self.files[i]
        file_name = file.split('\\')[-1]
        
        # csv
        if self.csv_feature_check[i] == 0:
            csv_path = f'{file}/{file_name}.csv'
            df = pd.read_csv(csv_path)[self.csv_feature_dict.keys()]
            df = df.replace('-', 0)
            # MinMax scaling
            for col in df.columns:
                df[col] = df[col].astype(float) - self.csv_feature_dict[col][0]
                df[col] = df[col] / (self.csv_feature_dict[col][1]-self.csv_feature_dict[col][0])
            # zero padding
            pad = np.zeros((self.max_len, len(df.columns)))
            length = min(self.max_len, len(df))
            pad[-length:] = df.to_numpy()[-length:]
            # transpose to sequential data
            csv_feature = pad.T
            self.csv_features[i] = csv_feature
            self.csv_feature_check[i] = 1
        else:
            csv_feature = self.csv_features[i]
        
        # image
        image_path = f'{file}/{file_name}.jpg'
        img = cv2.imread(image_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = self.transforms(image=img)["image"]
        img = img.transpose(2,0,1)
        
        if self.mode == 'train':
            json_path = f'{file}/{file_name}.json'
            with open(json_path, 'r') as f:
                json_file = json.load(f)
            
            crop = json_file['annotations']['crop']
            disease = json_file['annotations']['disease']
            risk = json_file['annotations']['risk']
            label = f'{crop}_{disease}_{risk}'
            
            return {
                'img' : torch.tensor(img, dtype=torch.float32) / 255.0,
                'csv_feature' : torch.tensor(csv_feature, dtype=torch.float32),
                'label' : torch.tensor(self.label_encoder[label], dtype=torch.long)
            }
        else:
            return {
                'img' : torch.tensor(img, dtype=torch.float32) / 255.0,
                'csv_feature' : torch.tensor(csv_feature, dtype=torch.float32)
            }

# %%
labels = pd.read_csv('./data/train.csv')

train_label_encoder = {}
label_cnt = 0
previous_label = '0_00_0'
for i, label in enumerate(tqdm(sorted(labels['label']))) :
    crop_val = label.split('_')[0] # crop
    disease_val = label.split('_')[1] # disease
    risk_val = label.split('_')[2] # risk
    
    tmp_label = f'{crop_val}_{disease_val}_{risk_val}'
    if previous_label != tmp_label :
        train_label_encoder[tmp_label] = label_cnt
        previous_label = tmp_label
        label_cnt += 1
        
train_label_decoder = {val : key for key, val in train_label_encoder.items()}
display(train_label_decoder)
display(train_label_encoder)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 5767/5767 [00:00<00:00, 720905.77it/s]
# {0: '1_00_0',
#  1: '2_00_0',
#  2: '2_a5_2',
#  3: '3_00_0',
#  4: '3_a9_1',
#  5: '3_a9_2',
#  6: '3_a9_3',
#  7: '3_b3_1',
#  8: '3_b6_1',
#  9: '3_b7_1',
#  10: '3_b8_1',
#  11: '4_00_0',
#  12: '5_00_0',
#  13: '5_a7_2',
#  14: '5_b6_1',
#  15: '5_b7_1',
#  16: '5_b8_1',
#  17: '6_00_0',
#  18: '6_a11_1',
#  19: '6_a11_2',
#  20: '6_a12_1',
#  21: '6_a12_2',
#  22: '6_b4_1',
#  23: '6_b4_3',
#  24: '6_b5_1'}
# {'1_00_0': 0,
#  '2_00_0': 1,
#  '2_a5_2': 2,
#  '3_00_0': 3,
#  '3_a9_1': 4,
#  '3_a9_2': 5,
#  '3_a9_3': 6,
#  '3_b3_1': 7,
#  '3_b6_1': 8,
#  '3_b7_1': 9,
#  '3_b8_1': 10,
#  '4_00_0': 11,
#  '5_00_0': 12,
#  '5_a7_2': 13,
#  '5_b6_1': 14,
#  '5_b7_1': 15,
#  '5_b8_1': 16,
#  '6_00_0': 17,
#  '6_a11_1': 18,
#  '6_a11_2': 19,
#  '6_a12_1': 20,
#  '6_a12_2': 21,
#  '6_b4_1': 22,
#  '6_b4_3': 23,
#  '6_b5_1': 24}

# %%
json_path = glob('./data/train/*/*.json')

labels = []
for path in tqdm(json_path) :
    json_file = json.load(open(path, 'r'))
    
    crop = json_file['annotations']['crop']
    disease = json_file['annotations']['disease']
    risk = json_file['annotations']['risk']
    
    label = f'{crop}_{disease}_{risk}'
    labels.append(train_label_encoder[label])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 5767/5767 [00:02<00:00, 2607.58it/s]

# %%
def accuracy_function(real, pred):    
    real = real.cpu()
    pred = torch.argmax(pred, dim=1).cpu()
    score = f1_score(real, pred, average='macro')
    return score

def train_step(batch_item, training):
    img = batch_item['img'].to(device)
    csv_feature = batch_item['csv_feature'].to(device)
    label = batch_item['label'].to(device)
    if training is True:
        model.train()
        optimizer.zero_grad()
        with torch.cuda.amp.autocast():
            output = model(img, csv_feature)
            loss = criterion(output, label)
        loss.backward()
        optimizer.step()
        score = accuracy_function(label, output)
        return loss, score
    else:
        model.eval()
        with torch.no_grad():
            output = model(img, csv_feature)
            loss = criterion(output, label)
        score = accuracy_function(label, output)
        return loss, score

# %% [markdown]
# # K-fold 적용된 training

# %%
data_list = glob('./data/train/*')
csv_list = glob('./data/train/*/*.csv')
label_list = labels

kfold = StratifiedKFold(n_splits=4, random_state=13, shuffle=True)
for k, (fold_train, fold_val) in enumerate(kfold.split(data_list, label_list), 1) :
    
    train_data_list = []
    val_data_list = []
    
    for k_train in fold_train :
        train_data_list.append(data_list[k_train])
    
    for k_val in fold_val :
        val_data_list.append(data_list[k_val])
    
    print(f"\n\n\n===== k_fold : {k} / 5 =====")
    train_dataset = CustomDataset(train_data_list, train_transforms)
    val_dataset = CustomDataset(val_data_list, val_transforms)
    
    train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    loss_plot, val_loss_plot = [], []
    metric_plot, val_metric_plot = [], []

    for epoch in range(epochs):
        total_loss, total_val_loss = 0, 0
        total_acc, total_val_acc = 0, 0

        tqdm_dataset = tqdm(enumerate(train_dataloader))
        training = True
        for batch, batch_item in tqdm_dataset:
            batch_loss, batch_acc = train_step(batch_item, training)
            total_loss += batch_loss
            total_acc += batch_acc

            tqdm_dataset.set_postfix({
                'Epoch': epoch + 1,
                'Loss': '{:06f}'.format(batch_loss.item()),
                'Mean Loss' : '{:06f}'.format(total_loss/(batch+1)),
                'Mean F-1' : '{:06f}'.format(total_acc/(batch+1))
            })
        loss_plot.append(total_loss/(batch+1))
        metric_plot.append(total_acc/(batch+1))

        tqdm_dataset = tqdm(enumerate(val_dataloader))
        training = False
        for batch, batch_item in tqdm_dataset:
            batch_loss, batch_acc = train_step(batch_item, training)
            total_val_loss += batch_loss
            total_val_acc += batch_acc

            tqdm_dataset.set_postfix({
                'Epoch': epoch + 1,
                'Val Loss': '{:06f}'.format(batch_loss.item()),
                'Mean Val Loss' : '{:06f}'.format(total_val_loss/(batch+1)),
                'Mean Val F-1' : '{:06f}'.format(total_val_acc/(batch+1))
            })
        val_loss_plot.append(total_val_loss/(batch+1))
        val_metric_plot.append(total_val_acc/(batch+1))

        if np.max(val_metric_plot) == val_metric_plot[-1]:
            torch.save(model.state_dict(), f'{k}_{save_path}')
# Out:
# ['./data/train\\10027', './data/train\\10037', './data/train\\10043', './data/train\\10045', './data/train\\10063', './data/train\\10090', './data/train\\10109', './data/train\\10115', './data/train\\10118', './data/train\\10124', './data/train\\10169', './data/train\\10173', './data/train\\10192', './data/train\\10199', './data/train\\10224', './data/train\\10226', './data/train\\10238', './data/train\\10251', './data/train\\10252', './data/train\\10299', './data/train\\10300', './data/train\\10304', './data/train\\10323', './data/train\\10365', './data/train\\10419', './data/train\\10421', './data/train\\10442', './data/train\\10462', './data/train\\10478', './data/train\\10480', './data/train\\10496', './data/train\\10513', './data/train\\10519', './data/train\\10523', './data/train\\10525', './data/train\\10540', './data/train\\10546', './data/train\\10549', './data/train\\10601', './data/train\\10612', './data/train\\10635', './data/train\\10649', './data/train\\10652', './data/train\\10653', './data/train\\10682', './data/train\\10693', './data/train\\10721', './data/train\\10733', './data/train\\10738', './data/train\\10764', './data/train\\10813', './data/train\\10817', './data/train\\10828', './data/train\\10834', './data/train\\10851', './data/train\\10862', './data/train\\10864', './data/train\\10882', './data/train\\10908', './data/train\\10925', './data/train\\10927', './data/train\\10945', './data/train\\10970', './data/train\\10991', './data/train\\10997', './data/train\\11003', './data/train\\11058', './data/train\\11087', './data/train\\11107', './data/train\\11119', './data/train\\11122', './data/train\\11138', './data/train\\11148', './data/train\\11149', './data/train\\11150', './data/train\\11159', './data/train\\11165', './data/train\\11179', './data/train\\11193', './data/train\\11198', './data/train\\11221', './data/train\\11225', './data/train\\11231', './data/train\\11242', './data/train\\11261', './data/train\\11292', './data/train\\11314', './data/train\\11321', './data/train\\11335', './data/train\\11346', './data/train\\11358', './data/train\\11400', './data/train\\11402', './data/train\\11403', './data/train\\11409', './data/train\\11438', './data/train\\11443', './data/train\\11470', './data/train\\11482', './data/train\\11485', './data/train\\11492', './data/train\\11497', './data/train\\11498', './data/train\\11523', './data/train\\11526', './data/train\\11533', './data/train\\11537', './data/train\\11542', './data/train\\11546', './data/train\\11556', './data/train\\11558', './data/train\\11568', './data/train\\11596', './data/train\\11618', './data/train\\11639', './data/train\\11644', './data/train\\11648', './data/train\\11655', './data/train\\11664', './data/train\\11715', './data/train\\11724', './data/train\\11744', './data/train\\11759', './data/train\\11766', './data/train\\11768', './data/train\\11770', './data/train\\11773', './data/train\\11777', './data/train\\11785', './data/train\\11798', './data/train\\11811', './data/train\\11860', './data/train\\11864', './data/train\\11883', './data/train\\11895', './data/train\\11921', './data/train\\11931', './data/train\\11936', './data/train\\11942', './data/train\\11943', './data/train\\11945', './data/train\\11951', './data/train\\11978', './data/train\\11990', './data/train\\11995', './data/train\\12010', './data/train\\12045', './data/train\\12054', './data/train\\12055', './data/train\\12063', './data/train\\12071', './data/train\\12148', './data/train\\12152', './data/train\\12158', './data/train\\12164', './data/train\\12179', './data/train\\12185', './data/train\\12190', './data/train\\12203', './data/train\\12205', './data/train\\12217', './data/train\\12225', './data/train\\12231', './data/train\\12232', './data/train\\12239', './data/train\\12240', './data/train\\12256', './data/train\\12258', './data/train\\12276', './data/train\\12283', './data/train\\12285', './data/train\\12290', './data/train\\12294', './data/train\\12299 ...
# ['./data/train\\10117', './data/train\\10201', './data/train\\10263', './data/train\\10274', './data/train\\10328', './data/train\\10345', './data/train\\10348', './data/train\\10369', './data/train\\10418', './data/train\\10505', './data/train\\10677', './data/train\\10706', './data/train\\10826', './data/train\\10847', './data/train\\10850', './data/train\\10858', './data/train\\10879', './data/train\\10880', './data/train\\10922', './data/train\\10950', './data/train\\10983', './data/train\\11040', './data/train\\11045', './data/train\\11050', './data/train\\11134', './data/train\\11233', './data/train\\11295', './data/train\\11333', './data/train\\11350', './data/train\\11364', './data/train\\11407', './data/train\\11449', './data/train\\11622', './data/train\\11673', './data/train\\11738', './data/train\\11740', './data/train\\11804', './data/train\\11886', './data/train\\11977', './data/train\\11997', './data/train\\12085', './data/train\\12136', './data/train\\12173', './data/train\\12197', './data/train\\12214', './data/train\\12253', './data/train\\12356', './data/train\\12389', './data/train\\12422', './data/train\\12452', './data/train\\12455', './data/train\\12483', './data/train\\12519', './data/train\\12589', './data/train\\12712', './data/train\\12716', './data/train\\12723', './data/train\\12748', './data/train\\12842', './data/train\\12916', './data/train\\12928', './data/train\\13109', './data/train\\13156', './data/train\\13193', './data/train\\13217', './data/train\\13273', './data/train\\13300', './data/train\\13320', './data/train\\13356', './data/train\\13403', './data/train\\13426', './data/train\\13444', './data/train\\13454', './data/train\\13579', './data/train\\13583', './data/train\\13674', './data/train\\13719', './data/train\\13748', './data/train\\13816', './data/train\\13828', './data/train\\13845', './data/train\\13848', './data/train\\13986', './data/train\\14003', './data/train\\14050', './data/train\\14163', './data/train\\14168', './data/train\\14275', './data/train\\14324', './data/train\\14353', './data/train\\14405', './data/train\\14411', './data/train\\14445', './data/train\\14471', './data/train\\14481', './data/train\\14568', './data/train\\14585', './data/train\\14601', './data/train\\14669', './data/train\\14796', './data/train\\14968', './data/train\\15014', './data/train\\15089', './data/train\\15097', './data/train\\15129', './data/train\\15131', './data/train\\15152', './data/train\\15176', './data/train\\15218', './data/train\\15263', './data/train\\15302', './data/train\\15405', './data/train\\15468', './data/train\\15497', './data/train\\15624', './data/train\\15676', './data/train\\15681', './data/train\\15742', './data/train\\15765', './data/train\\15778', './data/train\\15842', './data/train\\15843', './data/train\\15866', './data/train\\15873', './data/train\\15892', './data/train\\15978', './data/train\\16076', './data/train\\16115', './data/train\\16125', './data/train\\16150', './data/train\\16195', './data/train\\16291', './data/train\\16485', './data/train\\16577', './data/train\\16643', './data/train\\16652', './data/train\\16678', './data/train\\16737', './data/train\\16759', './data/train\\16767', './data/train\\16811', './data/train\\16842', './data/train\\16872', './data/train\\16884', './data/train\\16947', './data/train\\16958', './data/train\\16962', './data/train\\16979', './data/train\\17061', './data/train\\17065', './data/train\\17259', './data/train\\17268', './data/train\\17300', './data/train\\17305', './data/train\\17344', './data/train\\17370', './data/train\\17420', './data/train\\17428', './data/train\\17451', './data/train\\17465', './data/train\\17487', './data/train\\17569', './data/train\\17573', './data/train\\17603', './data/train\\17627', './data/train\\17633', './data/train\\17714', './data/train\\17752', './data/train\\17836', './data/train\\17839', './data/train\\17842', './data/train\\17953', './data/train\\18088', './data/train\\18095 ...
# ['./data/train\\10027', './data/train\\10043', './data/train\\10045', './data/train\\10063', './data/train\\10090', './data/train\\10109', './data/train\\10115', './data/train\\10117', './data/train\\10169', './data/train\\10173', './data/train\\10192', './data/train\\10199', './data/train\\10201', './data/train\\10224', './data/train\\10226', './data/train\\10238', './data/train\\10251', './data/train\\10252', './data/train\\10263', './data/train\\10274', './data/train\\10299', './data/train\\10304', './data/train\\10323', './data/train\\10328', './data/train\\10345', './data/train\\10348', './data/train\\10365', './data/train\\10369', './data/train\\10418', './data/train\\10419', './data/train\\10421', './data/train\\10442', './data/train\\10496', './data/train\\10505', './data/train\\10513', './data/train\\10519', './data/train\\10540', './data/train\\10546', './data/train\\10549', './data/train\\10601', './data/train\\10612', './data/train\\10635', './data/train\\10649', './data/train\\10652', './data/train\\10677', './data/train\\10682', './data/train\\10693', './data/train\\10706', './data/train\\10721', './data/train\\10733', './data/train\\10738', './data/train\\10813', './data/train\\10817', './data/train\\10826', './data/train\\10828', './data/train\\10834', './data/train\\10847', './data/train\\10850', './data/train\\10858', './data/train\\10862', './data/train\\10864', './data/train\\10879', './data/train\\10880', './data/train\\10882', './data/train\\10908', './data/train\\10922', './data/train\\10925', './data/train\\10927', './data/train\\10945', './data/train\\10950', './data/train\\10970', './data/train\\10983', './data/train\\10997', './data/train\\11040', './data/train\\11045', './data/train\\11050', './data/train\\11058', './data/train\\11087', './data/train\\11122', './data/train\\11134', './data/train\\11138', './data/train\\11148', './data/train\\11159', './data/train\\11165', './data/train\\11193', './data/train\\11198', './data/train\\11221', './data/train\\11231', './data/train\\11233', './data/train\\11242', './data/train\\11292', './data/train\\11295', './data/train\\11314', './data/train\\11321', './data/train\\11333', './data/train\\11335', './data/train\\11346', './data/train\\11350', './data/train\\11358', './data/train\\11364', './data/train\\11400', './data/train\\11403', './data/train\\11407', './data/train\\11409', './data/train\\11443', './data/train\\11449', './data/train\\11470', './data/train\\11482', './data/train\\11485', './data/train\\11492', './data/train\\11497', './data/train\\11523', './data/train\\11533', './data/train\\11537', './data/train\\11556', './data/train\\11558', './data/train\\11568', './data/train\\11596', './data/train\\11618', './data/train\\11622', './data/train\\11639', './data/train\\11648', './data/train\\11673', './data/train\\11724', './data/train\\11738', './data/train\\11740', './data/train\\11744', './data/train\\11766', './data/train\\11768', './data/train\\11770', './data/train\\11777', './data/train\\11785', './data/train\\11798', './data/train\\11804', './data/train\\11860', './data/train\\11864', './data/train\\11883', './data/train\\11886', './data/train\\11895', './data/train\\11936', './data/train\\11945', './data/train\\11951', './data/train\\11977', './data/train\\11978', './data/train\\11990', './data/train\\11995', './data/train\\11997', './data/train\\12045', './data/train\\12054', './data/train\\12055', './data/train\\12063', './data/train\\12071', './data/train\\12085', './data/train\\12136', './data/train\\12148', './data/train\\12158', './data/train\\12164', './data/train\\12173', './data/train\\12185', './data/train\\12197', './data/train\\12203', './data/train\\12205', './data/train\\12214', './data/train\\12217', './data/train\\12225', './data/train\\12231', './data/train\\12232', './data/train\\12239', './data/train\\12240', './data/train\\12253', './data/train\\12256', './data/train\\12258', './data/train\\12283', './data/train\\12290 ...
# ['./data/train\\10037', './data/train\\10118', './data/train\\10124', './data/train\\10300', './data/train\\10462', './data/train\\10478', './data/train\\10480', './data/train\\10523', './data/train\\10525', './data/train\\10653', './data/train\\10764', './data/train\\10851', './data/train\\10991', './data/train\\11003', './data/train\\11107', './data/train\\11119', './data/train\\11149', './data/train\\11150', './data/train\\11179', './data/train\\11225', './data/train\\11261', './data/train\\11402', './data/train\\11438', './data/train\\11498', './data/train\\11526', './data/train\\11542', './data/train\\11546', './data/train\\11644', './data/train\\11655', './data/train\\11664', './data/train\\11715', './data/train\\11759', './data/train\\11773', './data/train\\11811', './data/train\\11921', './data/train\\11931', './data/train\\11942', './data/train\\11943', './data/train\\12010', './data/train\\12152', './data/train\\12179', './data/train\\12190', './data/train\\12276', './data/train\\12285', './data/train\\12310', './data/train\\12344', './data/train\\12357', './data/train\\12446', './data/train\\12504', './data/train\\12515', './data/train\\12576', './data/train\\12604', './data/train\\12652', './data/train\\12721', './data/train\\12734', './data/train\\12738', './data/train\\12797', './data/train\\12841', './data/train\\12978', './data/train\\13041', './data/train\\13051', './data/train\\13145', './data/train\\13152', './data/train\\13183', './data/train\\13249', './data/train\\13252', './data/train\\13271', './data/train\\13289', './data/train\\13291', './data/train\\13644', './data/train\\13726', './data/train\\13794', './data/train\\13863', './data/train\\13932', './data/train\\13998', './data/train\\14017', './data/train\\14093', './data/train\\14212', './data/train\\14239', './data/train\\14247', './data/train\\14248', './data/train\\14273', './data/train\\14291', './data/train\\14314', './data/train\\14322', './data/train\\14358', './data/train\\14404', './data/train\\14423', './data/train\\14490', './data/train\\14649', './data/train\\14659', './data/train\\14702', './data/train\\14722', './data/train\\14824', './data/train\\14873', './data/train\\14895', './data/train\\14963', './data/train\\14975', './data/train\\14994', './data/train\\15010', './data/train\\15019', './data/train\\15026', './data/train\\15043', './data/train\\15273', './data/train\\15328', './data/train\\15339', './data/train\\15367', './data/train\\15416', './data/train\\15491', './data/train\\15503', './data/train\\15519', './data/train\\15521', './data/train\\15586', './data/train\\15674', './data/train\\15702', './data/train\\15767', './data/train\\15861', './data/train\\15880', './data/train\\15909', './data/train\\16005', './data/train\\16057', './data/train\\16152', './data/train\\16225', './data/train\\16238', './data/train\\16246', './data/train\\16267', './data/train\\16298', './data/train\\16308', './data/train\\16402', './data/train\\16437', './data/train\\16455', './data/train\\16469', './data/train\\16523', './data/train\\16554', './data/train\\16568', './data/train\\16587', './data/train\\16604', './data/train\\16709', './data/train\\16746', './data/train\\16757', './data/train\\16758', './data/train\\16776', './data/train\\16821', './data/train\\17051', './data/train\\17135', './data/train\\17188', './data/train\\17223', './data/train\\17232', './data/train\\17261', './data/train\\17310', './data/train\\17324', './data/train\\17328', './data/train\\17341', './data/train\\17497', './data/train\\17508', './data/train\\17579', './data/train\\17608', './data/train\\17638', './data/train\\17665', './data/train\\17681', './data/train\\17768', './data/train\\17785', './data/train\\17883', './data/train\\17902', './data/train\\17917', './data/train\\17944', './data/train\\17989', './data/train\\18055', './data/train\\18119', './data/train\\18171', './data/train\\18199', './data/train\\18464', './data/train\\18499', './data/train\\18575 ...
# ['./data/train\\10027', './data/train\\10037', './data/train\\10043', './data/train\\10045', './data/train\\10063', './data/train\\10090', './data/train\\10115', './data/train\\10117', './data/train\\10118', './data/train\\10124', './data/train\\10169', './data/train\\10192', './data/train\\10199', './data/train\\10201', './data/train\\10226', './data/train\\10238', './data/train\\10251', './data/train\\10252', './data/train\\10263', './data/train\\10274', './data/train\\10299', './data/train\\10300', './data/train\\10304', './data/train\\10323', './data/train\\10328', './data/train\\10345', './data/train\\10348', './data/train\\10365', './data/train\\10369', './data/train\\10418', './data/train\\10419', './data/train\\10462', './data/train\\10478', './data/train\\10480', './data/train\\10496', './data/train\\10505', './data/train\\10519', './data/train\\10523', './data/train\\10525', './data/train\\10540', './data/train\\10546', './data/train\\10549', './data/train\\10612', './data/train\\10649', './data/train\\10653', './data/train\\10677', './data/train\\10682', './data/train\\10706', './data/train\\10721', './data/train\\10733', './data/train\\10738', './data/train\\10764', './data/train\\10813', './data/train\\10817', './data/train\\10826', './data/train\\10828', './data/train\\10847', './data/train\\10850', './data/train\\10851', './data/train\\10858', './data/train\\10862', './data/train\\10879', './data/train\\10880', './data/train\\10908', './data/train\\10922', './data/train\\10925', './data/train\\10927', './data/train\\10945', './data/train\\10950', './data/train\\10983', './data/train\\10991', './data/train\\11003', './data/train\\11040', './data/train\\11045', './data/train\\11050', './data/train\\11058', './data/train\\11087', './data/train\\11107', './data/train\\11119', './data/train\\11122', './data/train\\11134', './data/train\\11148', './data/train\\11149', './data/train\\11150', './data/train\\11159', './data/train\\11165', './data/train\\11179', './data/train\\11193', './data/train\\11198', './data/train\\11221', './data/train\\11225', './data/train\\11233', './data/train\\11242', './data/train\\11261', './data/train\\11292', './data/train\\11295', './data/train\\11333', './data/train\\11335', './data/train\\11346', './data/train\\11350', './data/train\\11364', './data/train\\11402', './data/train\\11407', './data/train\\11438', './data/train\\11443', './data/train\\11449', './data/train\\11482', './data/train\\11492', './data/train\\11498', './data/train\\11523', './data/train\\11526', './data/train\\11533', './data/train\\11537', './data/train\\11542', './data/train\\11546', './data/train\\11568', './data/train\\11596', './data/train\\11622', './data/train\\11644', './data/train\\11648', './data/train\\11655', './data/train\\11664', './data/train\\11673', './data/train\\11715', './data/train\\11724', './data/train\\11738', './data/train\\11740', './data/train\\11759', './data/train\\11766', './data/train\\11770', './data/train\\11773', './data/train\\11777', './data/train\\11785', './data/train\\11804', './data/train\\11811', './data/train\\11860', './data/train\\11886', './data/train\\11921', './data/train\\11931', './data/train\\11936', './data/train\\11942', './data/train\\11943', './data/train\\11945', './data/train\\11951', './data/train\\11977', './data/train\\11990', './data/train\\11997', './data/train\\12010', './data/train\\12054', './data/train\\12055', './data/train\\12063', './data/train\\12071', './data/train\\12085', './data/train\\12136', './data/train\\12148', './data/train\\12152', './data/train\\12158', './data/train\\12164', './data/train\\12173', './data/train\\12179', './data/train\\12185', './data/train\\12190', './data/train\\12197', './data/train\\12203', './data/train\\12205', './data/train\\12214', './data/train\\12217', './data/train\\12225', './data/train\\12240', './data/train\\12253', './data/train\\12256', './data/train\\12258', './data/train\\12276', './data/train\\12285 ...
# ['./data/train\\10109', './data/train\\10173', './data/train\\10224', './data/train\\10421', './data/train\\10442', './data/train\\10513', './data/train\\10601', './data/train\\10635', './data/train\\10652', './data/train\\10693', './data/train\\10834', './data/train\\10864', './data/train\\10882', './data/train\\10970', './data/train\\10997', './data/train\\11138', './data/train\\11231', './data/train\\11314', './data/train\\11321', './data/train\\11358', './data/train\\11400', './data/train\\11403', './data/train\\11409', './data/train\\11470', './data/train\\11485', './data/train\\11497', './data/train\\11556', './data/train\\11558', './data/train\\11618', './data/train\\11639', './data/train\\11744', './data/train\\11768', './data/train\\11798', './data/train\\11864', './data/train\\11883', './data/train\\11895', './data/train\\11978', './data/train\\11995', './data/train\\12045', './data/train\\12231', './data/train\\12232', './data/train\\12239', './data/train\\12283', './data/train\\12290', './data/train\\12299', './data/train\\12348', './data/train\\12361', './data/train\\12448', './data/train\\12550', './data/train\\12598', './data/train\\12692', './data/train\\12727', './data/train\\12793', './data/train\\12838', './data/train\\12922', './data/train\\12949', './data/train\\13018', './data/train\\13019', './data/train\\13143', './data/train\\13180', './data/train\\13186', './data/train\\13210', './data/train\\13224', './data/train\\13240', './data/train\\13298', './data/train\\13351', './data/train\\13392', './data/train\\13488', './data/train\\13492', './data/train\\13506', './data/train\\13521', './data/train\\13601', './data/train\\13698', './data/train\\13721', './data/train\\13813', './data/train\\13818', './data/train\\13820', './data/train\\13861', './data/train\\13885', './data/train\\13895', './data/train\\13993', './data/train\\14035', './data/train\\14082', './data/train\\14142', './data/train\\14164', './data/train\\14268', './data/train\\14363', './data/train\\14369', './data/train\\14438', './data/train\\14468', './data/train\\14495', './data/train\\14498', './data/train\\14529', './data/train\\14577', './data/train\\14723', './data/train\\14802', './data/train\\14814', './data/train\\14841', './data/train\\14876', './data/train\\15022', './data/train\\15132', './data/train\\15227', './data/train\\15236', './data/train\\15239', './data/train\\15295', './data/train\\15362', './data/train\\15411', './data/train\\15493', './data/train\\15507', './data/train\\15596', './data/train\\15598', './data/train\\15663', './data/train\\15684', './data/train\\15710', './data/train\\15738', './data/train\\15788', './data/train\\15801', './data/train\\15805', './data/train\\15911', './data/train\\15914', './data/train\\15967', './data/train\\16045', './data/train\\16105', './data/train\\16113', './data/train\\16172', './data/train\\16234', './data/train\\16269', './data/train\\16362', './data/train\\16503', './data/train\\16606', './data/train\\16647', './data/train\\16675', './data/train\\16764', './data/train\\16796', './data/train\\16951', './data/train\\16963', './data/train\\16992', './data/train\\17067', './data/train\\17117', './data/train\\17129', './data/train\\17160', './data/train\\17266', './data/train\\17303', './data/train\\17326', './data/train\\17327', './data/train\\17332', './data/train\\17334', './data/train\\17346', './data/train\\17354', './data/train\\17367', './data/train\\17442', './data/train\\17463', './data/train\\17534', './data/train\\17580', './data/train\\17851', './data/train\\17862', './data/train\\17879', './data/train\\17918', './data/train\\18063', './data/train\\18064', './data/train\\18109', './data/train\\18110', './data/train\\18129', './data/train\\18132', './data/train\\18185', './data/train\\18248', './data/train\\18302', './data/train\\18408', './data/train\\18437', './data/train\\18481', './data/train\\18525', './data/train\\18652', './data/train\\18726', './data/train\\18804 ...
# ['./data/train\\10027', './data/train\\10037', './data/train\\10045', './data/train\\10063', './data/train\\10090', './data/train\\10109', './data/train\\10115', './data/train\\10117', './data/train\\10118', './data/train\\10124', './data/train\\10173', './data/train\\10192', './data/train\\10199', './data/train\\10201', './data/train\\10224', './data/train\\10226', './data/train\\10251', './data/train\\10252', './data/train\\10263', './data/train\\10274', './data/train\\10299', './data/train\\10300', './data/train\\10304', './data/train\\10328', './data/train\\10345', './data/train\\10348', './data/train\\10369', './data/train\\10418', './data/train\\10419', './data/train\\10421', './data/train\\10442', './data/train\\10462', './data/train\\10478', './data/train\\10480', './data/train\\10505', './data/train\\10513', './data/train\\10519', './data/train\\10523', './data/train\\10525', './data/train\\10540', './data/train\\10549', './data/train\\10601', './data/train\\10635', './data/train\\10652', './data/train\\10653', './data/train\\10677', './data/train\\10693', './data/train\\10706', './data/train\\10733', './data/train\\10738', './data/train\\10764', './data/train\\10826', './data/train\\10828', './data/train\\10834', './data/train\\10847', './data/train\\10850', './data/train\\10851', './data/train\\10858', './data/train\\10864', './data/train\\10879', './data/train\\10880', './data/train\\10882', './data/train\\10908', './data/train\\10922', './data/train\\10950', './data/train\\10970', './data/train\\10983', './data/train\\10991', './data/train\\10997', './data/train\\11003', './data/train\\11040', './data/train\\11045', './data/train\\11050', './data/train\\11087', './data/train\\11107', './data/train\\11119', './data/train\\11134', './data/train\\11138', './data/train\\11149', './data/train\\11150', './data/train\\11179', './data/train\\11193', './data/train\\11198', './data/train\\11225', './data/train\\11231', './data/train\\11233', './data/train\\11261', './data/train\\11295', './data/train\\11314', './data/train\\11321', './data/train\\11333', './data/train\\11335', './data/train\\11350', './data/train\\11358', './data/train\\11364', './data/train\\11400', './data/train\\11402', './data/train\\11403', './data/train\\11407', './data/train\\11409', './data/train\\11438', './data/train\\11443', './data/train\\11449', './data/train\\11470', './data/train\\11482', './data/train\\11485', './data/train\\11497', './data/train\\11498', './data/train\\11526', './data/train\\11542', './data/train\\11546', './data/train\\11556', './data/train\\11558', './data/train\\11568', './data/train\\11618', './data/train\\11622', './data/train\\11639', './data/train\\11644', './data/train\\11648', './data/train\\11655', './data/train\\11664', './data/train\\11673', './data/train\\11715', './data/train\\11738', './data/train\\11740', './data/train\\11744', './data/train\\11759', './data/train\\11768', './data/train\\11773', './data/train\\11777', './data/train\\11798', './data/train\\11804', './data/train\\11811', './data/train\\11864', './data/train\\11883', './data/train\\11886', './data/train\\11895', './data/train\\11921', './data/train\\11931', './data/train\\11936', './data/train\\11942', './data/train\\11943', './data/train\\11977', './data/train\\11978', './data/train\\11990', './data/train\\11995', './data/train\\11997', './data/train\\12010', './data/train\\12045', './data/train\\12055', './data/train\\12063', './data/train\\12071', './data/train\\12085', './data/train\\12136', './data/train\\12152', './data/train\\12173', './data/train\\12179', './data/train\\12190', './data/train\\12197', './data/train\\12214', './data/train\\12225', './data/train\\12231', './data/train\\12232', './data/train\\12239', './data/train\\12253', './data/train\\12256', './data/train\\12276', './data/train\\12283', './data/train\\12285', './data/train\\12290', './data/train\\12299', './data/train\\12310', './data/train\\12344', './data/train\\12348 ...
# ['./data/train\\10043', './data/train\\10169', './data/train\\10238', './data/train\\10323', './data/train\\10365', './data/train\\10496', './data/train\\10546', './data/train\\10612', './data/train\\10649', './data/train\\10682', './data/train\\10721', './data/train\\10813', './data/train\\10817', './data/train\\10862', './data/train\\10925', './data/train\\10927', './data/train\\10945', './data/train\\11058', './data/train\\11122', './data/train\\11148', './data/train\\11159', './data/train\\11165', './data/train\\11221', './data/train\\11242', './data/train\\11292', './data/train\\11346', './data/train\\11492', './data/train\\11523', './data/train\\11533', './data/train\\11537', './data/train\\11596', './data/train\\11724', './data/train\\11766', './data/train\\11770', './data/train\\11785', './data/train\\11860', './data/train\\11945', './data/train\\11951', './data/train\\12054', './data/train\\12148', './data/train\\12158', './data/train\\12164', './data/train\\12185', './data/train\\12203', './data/train\\12205', './data/train\\12217', './data/train\\12240', './data/train\\12258', './data/train\\12294', './data/train\\12536', './data/train\\12591', './data/train\\12679', './data/train\\12683', './data/train\\12696', './data/train\\12770', './data/train\\12796', './data/train\\12817', './data/train\\12827', './data/train\\12891', './data/train\\12892', './data/train\\12961', './data/train\\13033', './data/train\\13034', './data/train\\13036', './data/train\\13054', './data/train\\13064', './data/train\\13069', './data/train\\13071', './data/train\\13082', './data/train\\13135', './data/train\\13141', './data/train\\13167', './data/train\\13203', './data/train\\13231', './data/train\\13305', './data/train\\13338', './data/train\\13413', './data/train\\13452', './data/train\\13514', './data/train\\13626', './data/train\\13679', './data/train\\13691', './data/train\\13709', './data/train\\13980', './data/train\\14119', './data/train\\14187', './data/train\\14317', './data/train\\14507', './data/train\\14518', './data/train\\14623', './data/train\\14646', './data/train\\14756', './data/train\\14772', './data/train\\14812', './data/train\\14879', './data/train\\14943', './data/train\\14966', './data/train\\14986', './data/train\\15071', './data/train\\15141', './data/train\\15156', './data/train\\15201', './data/train\\15232', './data/train\\15245', './data/train\\15368', './data/train\\15379', './data/train\\15381', './data/train\\15391', './data/train\\15486', './data/train\\15512', './data/train\\15572', './data/train\\15575', './data/train\\15582', './data/train\\15633', './data/train\\15709', './data/train\\15716', './data/train\\15723', './data/train\\15802', './data/train\\15846', './data/train\\15905', './data/train\\15918', './data/train\\15943', './data/train\\16080', './data/train\\16112', './data/train\\16138', './data/train\\16197', './data/train\\16213', './data/train\\16266', './data/train\\16290', './data/train\\16300', './data/train\\16315', './data/train\\16335', './data/train\\16350', './data/train\\16395', './data/train\\16427', './data/train\\16435', './data/train\\16486', './data/train\\16491', './data/train\\16512', './data/train\\16514', './data/train\\16556', './data/train\\16607', './data/train\\16609', './data/train\\16651', './data/train\\16729', './data/train\\16845', './data/train\\16991', './data/train\\17017', './data/train\\17055', './data/train\\17079', './data/train\\17080', './data/train\\17126', './data/train\\17127', './data/train\\17187', './data/train\\17247', './data/train\\17251', './data/train\\17349', './data/train\\17368', './data/train\\17427', './data/train\\17446', './data/train\\17551', './data/train\\17575', './data/train\\17592', './data/train\\17595', './data/train\\17737', './data/train\\17788', './data/train\\17816', './data/train\\17962', './data/train\\17968', './data/train\\18009', './data/train\\18042', './data/train\\18212', './data/train\\18321', './data/train\\18418 ...
# ['./data/train\\10037', './data/train\\10043', './data/train\\10109', './data/train\\10117', './data/train\\10118', './data/train\\10124', './data/train\\10169', './data/train\\10173', './data/train\\10201', './data/train\\10224', './data/train\\10238', './data/train\\10263', './data/train\\10274', './data/train\\10300', './data/train\\10323', './data/train\\10328', './data/train\\10345', './data/train\\10348', './data/train\\10365', './data/train\\10369', './data/train\\10418', './data/train\\10421', './data/train\\10442', './data/train\\10462', './data/train\\10478', './data/train\\10480', './data/train\\10496', './data/train\\10505', './data/train\\10513', './data/train\\10523', './data/train\\10525', './data/train\\10546', './data/train\\10601', './data/train\\10612', './data/train\\10635', './data/train\\10649', './data/train\\10652', './data/train\\10653', './data/train\\10677', './data/train\\10682', './data/train\\10693', './data/train\\10706', './data/train\\10721', './data/train\\10764', './data/train\\10813', './data/train\\10817', './data/train\\10826', './data/train\\10834', './data/train\\10847', './data/train\\10850', './data/train\\10851', './data/train\\10858', './data/train\\10862', './data/train\\10864', './data/train\\10879', './data/train\\10880', './data/train\\10882', './data/train\\10922', './data/train\\10925', './data/train\\10927', './data/train\\10945', './data/train\\10950', './data/train\\10970', './data/train\\10983', './data/train\\10991', './data/train\\10997', './data/train\\11003', './data/train\\11040', './data/train\\11045', './data/train\\11050', './data/train\\11058', './data/train\\11107', './data/train\\11119', './data/train\\11122', './data/train\\11134', './data/train\\11138', './data/train\\11148', './data/train\\11149', './data/train\\11150', './data/train\\11159', './data/train\\11165', './data/train\\11179', './data/train\\11221', './data/train\\11225', './data/train\\11231', './data/train\\11233', './data/train\\11242', './data/train\\11261', './data/train\\11292', './data/train\\11295', './data/train\\11314', './data/train\\11321', './data/train\\11333', './data/train\\11346', './data/train\\11350', './data/train\\11358', './data/train\\11364', './data/train\\11400', './data/train\\11402', './data/train\\11403', './data/train\\11407', './data/train\\11409', './data/train\\11438', './data/train\\11449', './data/train\\11470', './data/train\\11485', './data/train\\11492', './data/train\\11497', './data/train\\11498', './data/train\\11523', './data/train\\11526', './data/train\\11533', './data/train\\11537', './data/train\\11542', './data/train\\11546', './data/train\\11556', './data/train\\11558', './data/train\\11596', './data/train\\11618', './data/train\\11622', './data/train\\11639', './data/train\\11644', './data/train\\11655', './data/train\\11664', './data/train\\11673', './data/train\\11715', './data/train\\11724', './data/train\\11738', './data/train\\11740', './data/train\\11744', './data/train\\11759', './data/train\\11766', './data/train\\11768', './data/train\\11770', './data/train\\11773', './data/train\\11785', './data/train\\11798', './data/train\\11804', './data/train\\11811', './data/train\\11860', './data/train\\11864', './data/train\\11883', './data/train\\11886', './data/train\\11895', './data/train\\11921', './data/train\\11931', './data/train\\11942', './data/train\\11943', './data/train\\11945', './data/train\\11951', './data/train\\11977', './data/train\\11978', './data/train\\11995', './data/train\\11997', './data/train\\12010', './data/train\\12045', './data/train\\12054', './data/train\\12085', './data/train\\12136', './data/train\\12148', './data/train\\12152', './data/train\\12158', './data/train\\12164', './data/train\\12173', './data/train\\12179', './data/train\\12185', './data/train\\12190', './data/train\\12197', './data/train\\12203', './data/train\\12205', './data/train\\12214', './data/train\\12217', './data/train\\12231', './data/train\\12232 ...
# ['./data/train\\10027', './data/train\\10045', './data/train\\10063', './data/train\\10090', './data/train\\10115', './data/train\\10192', './data/train\\10199', './data/train\\10226', './data/train\\10251', './data/train\\10252', './data/train\\10299', './data/train\\10304', './data/train\\10419', './data/train\\10519', './data/train\\10540', './data/train\\10549', './data/train\\10733', './data/train\\10738', './data/train\\10828', './data/train\\10908', './data/train\\11087', './data/train\\11193', './data/train\\11198', './data/train\\11335', './data/train\\11443', './data/train\\11482', './data/train\\11568', './data/train\\11648', './data/train\\11777', './data/train\\11936', './data/train\\11990', './data/train\\12055', './data/train\\12063', './data/train\\12071', './data/train\\12225', './data/train\\12256', './data/train\\12470', './data/train\\12476', './data/train\\12485', './data/train\\12522', './data/train\\12543', './data/train\\12655', './data/train\\12698', './data/train\\12834', './data/train\\12905', './data/train\\12982', './data/train\\13056', './data/train\\13061', './data/train\\13196', './data/train\\13229', './data/train\\13242', './data/train\\13364', './data/train\\13478', './data/train\\13483', './data/train\\13502', './data/train\\13532', './data/train\\13599', './data/train\\13614', './data/train\\13658', './data/train\\13667', './data/train\\13693', './data/train\\13741', './data/train\\13761', './data/train\\13945', './data/train\\13983', './data/train\\14107', './data/train\\14148', './data/train\\14178', './data/train\\14179', './data/train\\14223', './data/train\\14236', './data/train\\14412', './data/train\\14417', './data/train\\14419', './data/train\\14545', './data/train\\14694', './data/train\\14780', './data/train\\14835', './data/train\\14926', './data/train\\14949', './data/train\\14955', './data/train\\14957', './data/train\\14965', './data/train\\15072', './data/train\\15109', './data/train\\15267', './data/train\\15384', './data/train\\15427', './data/train\\15435', './data/train\\15436', './data/train\\15452', './data/train\\15509', './data/train\\15554', './data/train\\15692', './data/train\\15718', './data/train\\15769', './data/train\\15776', './data/train\\15782', './data/train\\15845', './data/train\\15959', './data/train\\15969', './data/train\\15993', './data/train\\16011', './data/train\\16075', './data/train\\16108', './data/train\\16186', './data/train\\16194', './data/train\\16203', './data/train\\16324', './data/train\\16423', './data/train\\16505', './data/train\\16531', './data/train\\16571', './data/train\\16603', './data/train\\16621', './data/train\\16626', './data/train\\16748', './data/train\\16752', './data/train\\16766', './data/train\\16866', './data/train\\16938', './data/train\\16983', './data/train\\16985', './data/train\\17006', './data/train\\17026', './data/train\\17066', './data/train\\17119', './data/train\\17125', './data/train\\17183', './data/train\\17205', './data/train\\17316', './data/train\\17401', './data/train\\17482', './data/train\\17521', './data/train\\17607', './data/train\\17835', './data/train\\17849', './data/train\\17873', './data/train\\18017', './data/train\\18094', './data/train\\18146', './data/train\\18154', './data/train\\18204', './data/train\\18274', './data/train\\18329', './data/train\\18333', './data/train\\18352', './data/train\\18391', './data/train\\18441', './data/train\\18450', './data/train\\18459', './data/train\\18646', './data/train\\18648', './data/train\\18649', './data/train\\18711', './data/train\\18724', './data/train\\18798', './data/train\\18830', './data/train\\18870', './data/train\\18980', './data/train\\19019', './data/train\\19103', './data/train\\19166', './data/train\\19169', './data/train\\19189', './data/train\\19211', './data/train\\19271', './data/train\\19362', './data/train\\19405', './data/train\\19501', './data/train\\19507', './data/train\\19519', './data/train\\19543', './data/train\\19546 ...

# %%
train_transforms = A.Compose([
                A.Resize(224 ,224),
#                 A.RandomRotate(),
                A.HorizontalFlip(),
                A.VerticalFlip(),
#                 A.ColorJitter(),
                A.Normalize()
            ])
val_transforms = A.Compose([
    A.Resize(224,224),
    A.Normalize()
])
train_dataset = CustomDataset(train, train_transforms)
val_dataset = CustomDataset(val, val_transforms)
test_dataset = CustomDataset(test, val_transforms, mode = 'test')

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
data_list = glob('./data/train/*')
train_data, val_data = train_test_split(data_list, 
                                         test_size=0.2, 
                                        shuffle=True,
                                        random_state=41)

# %%
display(len(train_data))
display(len(val_data))
# Out:
# 4613
# 1154

# %%
labelsss = pd.read_csv('data/train.csv')['label']
# Out:
# 5767

# %% [markdown]
# # Cutmix

# %%
def accuracy_function(real, pred):    
    real = real.cpu()
    pred = torch.argmax(pred, dim=1).cpu()
    score = f1_score(real, pred, average='macro')
    return score

def train_step(batch_item, training):
    img = batch_item['img'].to(device)
    csv_feature = batch_item['csv_feature'].to(device)
    label = batch_item['label'].to(device)
    
    lam = np.random.beta(1.0, 1.0)
    
    if training is True:
        model.train()
        optimizer.zero_grad()
        with torch.cuda.amp.autocast():
            # add - cutmix
            rand_index = torch.randperm(img.size()[0])
            target_a = label
            target_b = label[rand_index]
            bbx1, bby1, bbx2, bby2 = rand_bbox(img.size(), lam)
            img[:, :, bbx1:bbx2, bby1:bby2] = img[rand_index, :, bbx1:bbx2, bby1:bby2]
            lam = 1 - ((bbx2 - bbx1) * (bby2 - bby1) / (img.size()[-1] * img.size()[-2]))
            
            output = model(img, csv_feature)
            loss = criterion(output, target_a) * lam + criterion(output, target_b) * (1. - lam)
            
#             output = model(img, csv_feature)
#             loss = criterion(output, label)
        loss.backward()
        optimizer.step()
        score = accuracy_function(label, output)
        return loss, score
    else:
        model.eval()
        with torch.no_grad():
            output = model(img, csv_feature)
            loss = criterion(output, label)
        score = accuracy_function(label, output)
        return loss, score

# %%
def rand_bbox(size, lam):
    W = size[2]
    H = size[3]
    cut_rat = np.sqrt(1. - lam)
    cut_w = np.int(W * cut_rat)
    cut_h = np.int(H * cut_rat)

    # uniform
    cx = np.random.randint(W)
    cy = np.random.randint(H)

    bbx1 = np.clip(cx - cut_w // 2, 0, W)
    bby1 = np.clip(cy - cut_h // 2, 0, H)
    bbx2 = np.clip(cx + cut_w // 2, 0, W)
    bby2 = np.clip(cy + cut_h // 2, 0, H)

    return bbx1, bby1, bbx2, bby2

# %%
data_list = glob('./data/train/*')
csv_list = glob('./data/train/*/*.csv')
label_list = labels

kfold = StratifiedKFold(n_splits=4, random_state=13, shuffle=True)
for k, (fold_train, fold_val) in enumerate(kfold.split(data_list, label_list), 1) :
    
    train_data_list = []
    val_data_list = []
    
    for k_train in fold_train :
        train_data_list.append(data_list[k_train])
    
    for k_val in fold_val :
        val_data_list.append(data_list[k_val])
    
    print(f"\n\n\n===== k_fold : {k} / 5 =====")
    train_dataset = CustomDataset(train_data_list, train_transforms)
    val_dataset = CustomDataset(val_data_list, val_transforms)
    
    train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    loss_plot, val_loss_plot = [], []
    metric_plot, val_metric_plot = [], []

    for epoch in range(epochs):
        total_loss, total_val_loss = 0, 0
        total_acc, total_val_acc = 0, 0

        tqdm_dataset = tqdm(enumerate(train_dataloader))
        training = True
        for batch, batch_item in tqdm_dataset:
            batch_loss, batch_acc = train_step(batch_item, training)
            total_loss += batch_loss
            total_acc += batch_acc

            tqdm_dataset.set_postfix({
                'Epoch': epoch + 1,
                'Loss': '{:06f}'.format(batch_loss.item()),
                'Mean Loss' : '{:06f}'.format(total_loss/(batch+1)),
                'Mean F-1' : '{:06f}'.format(total_acc/(batch+1))
            })
        loss_plot.append(total_loss/(batch+1))
        metric_plot.append(total_acc/(batch+1))

        tqdm_dataset = tqdm(enumerate(val_dataloader))
        training = False
        for batch, batch_item in tqdm_dataset:
            batch_loss, batch_acc = train_step(batch_item, training)
            total_val_loss += batch_loss
            total_val_acc += batch_acc

            tqdm_dataset.set_postfix({
                'Epoch': epoch + 1,
                'Val Loss': '{:06f}'.format(batch_loss.item()),
                'Mean Val Loss' : '{:06f}'.format(total_val_loss/(batch+1)),
                'Mean Val F-1' : '{:06f}'.format(total_val_acc/(batch+1))
            })
        val_loss_plot.append(total_val_loss/(batch+1))
        val_metric_plot.append(total_val_acc/(batch+1))

        if np.max(val_metric_plot) == val_metric_plot[-1]:
            torch.save(model.state_dict(), f'{k}_{save_path}')

# %% [markdown]
# # 이미지 별 Width, Height 확인
# - Width 는 여러개임
# - Height 는 512로 통일
# - resize시 알아둬야할듯

# %%
json_path = glob('./data/train/*/*.json')
widths = []
heights = []
for path in json_path :
    json_file = json.load(open(path, 'r'))   
    widths.append(json_file['description']['width'])
    heights.append(json_file['description']['height'])
# widths = np.array(widths)
# heights = np.array(heights)
print(np.unique(widths))
print(np.unique(heights))
# Out:
# [ 242  262  384  512  622  682  740 1081]
# [512]

# %% [markdown]
# # class 별 갯수 확인

# %%
labels = pd.read_csv('./data/train.csv')

train_label_encoder = {}
label_cnt = 0
previous_label = '0_00_0'
for i, label in enumerate(tqdm(sorted(labels['label']))) :
    crop_val = label.split('_')[0] # crop
    disease_val = label.split('_')[1] # disease
    risk_val = label.split('_')[2] # risk
    
    tmp_label = f'{crop_val}_{disease_val}_{risk_val}'
    if previous_label != tmp_label :
        train_label_encoder[tmp_label] = label_cnt
        previous_label = tmp_label
        label_cnt += 1
        
train_label_decoder = {val : key for key, val in train_label_encoder.items()}
display(train_label_decoder)
display(train_label_encoder)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 5767/5767 [00:00<00:00, 820256.75it/s]
# {0: '1_00_0',
#  1: '2_00_0',
#  2: '2_a5_2',
#  3: '3_00_0',
#  4: '3_a9_1',
#  5: '3_a9_2',
#  6: '3_a9_3',
#  7: '3_b3_1',
#  8: '3_b6_1',
#  9: '3_b7_1',
#  10: '3_b8_1',
#  11: '4_00_0',
#  12: '5_00_0',
#  13: '5_a7_2',
#  14: '5_b6_1',
#  15: '5_b7_1',
#  16: '5_b8_1',
#  17: '6_00_0',
#  18: '6_a11_1',
#  19: '6_a11_2',
#  20: '6_a12_1',
#  21: '6_a12_2',
#  22: '6_b4_1',
#  23: '6_b4_3',
#  24: '6_b5_1'}
# {'1_00_0': 0,
#  '2_00_0': 1,
#  '2_a5_2': 2,
#  '3_00_0': 3,
#  '3_a9_1': 4,
#  '3_a9_2': 5,
#  '3_a9_3': 6,
#  '3_b3_1': 7,
#  '3_b6_1': 8,
#  '3_b7_1': 9,
#  '3_b8_1': 10,
#  '4_00_0': 11,
#  '5_00_0': 12,
#  '5_a7_2': 13,
#  '5_b6_1': 14,
#  '5_b7_1': 15,
#  '5_b8_1': 16,
#  '6_00_0': 17,
#  '6_a11_1': 18,
#  '6_a11_2': 19,
#  '6_a12_1': 20,
#  '6_a12_2': 21,
#  '6_b4_1': 22,
#  '6_b4_3': 23,
#  '6_b5_1': 24}

# %%
label_cnt = {k:0 for k, v in train_label_encoder.items()}
label_cnt
# Out:
# {'1_00_0': 0,
#  '2_00_0': 0,
#  '2_a5_2': 0,
#  '3_00_0': 0,
#  '3_a9_1': 0,
#  '3_a9_2': 0,
#  '3_a9_3': 0,
#  '3_b3_1': 0,
#  '3_b6_1': 0,
#  '3_b7_1': 0,
#  '3_b8_1': 0,
#  '4_00_0': 0,
#  '5_00_0': 0,
#  '5_a7_2': 0,
#  '5_b6_1': 0,
#  '5_b7_1': 0,
#  '5_b8_1': 0,
#  '6_00_0': 0,
#  '6_a11_1': 0,
#  '6_a11_2': 0,
#  '6_a12_1': 0,
#  '6_a12_2': 0,
#  '6_b4_1': 0,
#  '6_b4_3': 0,
#  '6_b5_1': 0}

# %%
labels = pd.read_csv('./data/train.csv')

previous_label = '0_00_0'
for i, label in enumerate(tqdm(sorted(labels['label']))) :
    crop_val = label.split('_')[0] # crop
    disease_val = label.split('_')[1] # disease
    risk_val = label.split('_')[2] # risk
    
    tmp_label = f'{crop_val}_{disease_val}_{risk_val}'
    label_cnt[tmp_label] += 1
label_cnt
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 5767/5767 [00:00<00:00, 524310.73it/s]
# {'1_00_0': 810,
#  '2_00_0': 143,
#  '2_a5_2': 189,
#  '3_00_0': 1177,
#  '3_a9_1': 154,
#  '3_a9_2': 111,
#  '3_a9_3': 42,
#  '3_b3_1': 166,
#  '3_b6_1': 142,
#  '3_b7_1': 156,
#  '3_b8_1': 153,
#  '4_00_0': 917,
#  '5_00_0': 69,
#  '5_a7_2': 99,
#  '5_b6_1': 148,
#  '5_b7_1': 159,
#  '5_b8_1': 157,
#  '6_00_0': 828,
#  '6_a11_1': 40,
#  '6_a11_2': 12,
#  '6_a12_1': 13,
#  '6_a12_2': 29,
#  '6_b4_1': 18,
#  '6_b4_3': 14,
#  '6_b5_1': 21}

# %% [markdown]
# # class 별 weight
# - 값이 너무 커서.. 안될됫

# %%
print("가장 작은 class 개수 : ",min(label_cnt.values()))
print("가장 큰 class 개수 : ", max(label_cnt.values()))
min_val = min(label_cnt.values())
max_val = max(label_cnt.values())
class_weight = [round(max_val/v, 3)for v in label_cnt.values()]
class_weight
# Out:
# 가장 작은 class 개수 :  12
# 가장 큰 class 개수 :  1177
# [1.453,
#  8.231,
#  6.228,
#  1.0,
#  7.643,
#  10.604,
#  28.024,
#  7.09,
#  8.289,
#  7.545,
#  7.693,
#  1.284,
#  17.058,
#  11.889,
#  7.953,
#  7.403,
#  7.497,
#  1.421,
#  29.425,
#  98.083,
#  90.538,
#  40.586,
#  65.389,
#  84.071,
#  56.048]

# %% [markdown]
# # timm 모델 리스트
# - deit_small_path16_224 모델 사용해보기

# %%
import timm
a = timm.list_models()
a
# Out:
# ['adv_inception_v3',
#  'bat_resnext26ts',
#  'botnet26t_256',
#  'botnet50ts_256',
#  'cait_m36_384',
#  'cait_m48_448',
#  'cait_s24_224',
#  'cait_s24_384',
#  'cait_s36_384',
#  'cait_xs24_384',
#  'cait_xxs24_224',
#  'cait_xxs24_384',
#  'cait_xxs36_224',
#  'cait_xxs36_384',
#  'coat_lite_mini',
#  'coat_lite_small',
#  'coat_lite_tiny',
#  'coat_mini',
#  'coat_tiny',
#  'convit_base',
#  'convit_small',
#  'convit_tiny',
#  'cspdarknet53',
#  'cspdarknet53_iabn',
#  'cspresnet50',
#  'cspresnet50d',
#  'cspresnet50w',
#  'cspresnext50',
#  'cspresnext50_iabn',
#  'darknet53',
#  'deit_base_distilled_patch16_224',
#  'deit_base_distilled_patch16_384',
#  'deit_base_patch16_224',
#  'deit_base_patch16_384',
#  'deit_small_distilled_patch16_224',
#  'deit_small_patch16_224',
#  'deit_tiny_distilled_patch16_224',
#  'deit_tiny_patch16_224',
#  'densenet121',
#  'densenet121d',
#  'densenet161',
#  'densenet169',
#  'densenet201',
#  'densenet264',
#  'densenet264d_iabn',
#  'densenetblur121d',
#  'dla34',
#  'dla46_c',
#  'dla46x_c',
#  'dla60',
#  'dla60_res2net',
#  'dla60_res2next',
#  'dla60x',
#  'dla60x_c',
#  'dla102',
#  'dla102x',
#  'dla102x2',
#  'dla169',
#  'dm_nfnet_f0',
#  'dm_nfnet_f1',
#  'dm_nfnet_f2',
#  'dm_nfnet_f3',
#  'dm_nfnet_f4',
#  'dm_nfnet_f5',
#  'dm_nfnet_f6',
#  'dpn68',
#  'dpn68b',
#  'dpn92',
#  'dpn98',
#  'dpn107',
#  'dpn131',
#  'eca_botnext26ts_256',
#  'eca_efficientnet_b0',
#  'eca_halonext26ts',
#  'eca_lambda_resnext26ts',
#  'eca_nfnet_l0',
#  'eca_nfnet_l1',
#  'eca_nfnet_l2',
#  'eca_nfnet_l3',
#  'eca_swinnext26ts_256',
#  'eca_vovnet39b',
#  'ecaresnet26t',
#  'ecaresnet50d',
#  'ecaresnet50d_pruned',
#  'ecaresnet50t',
#  'ecaresnet101d',
#  'ecaresnet101d_pruned',
#  'ecaresnet200d',
#  'ecaresnet269d',
#  'ecaresnetlight',
#  'ecaresnext26t_32x4d',
#  'ecaresnext50t_32x4d',
#  'efficientnet_b0',
#  'efficientnet_b1',
#  'efficientnet_b1_pruned',
#  'efficientnet_b2',
#  'efficientnet_b2_pruned',
#  'efficientnet_b2a',
#  'efficientnet_b3',
#  'efficientnet_b3_pruned',
#  'efficientnet_b3a',
#  'efficientnet_b4',
#  'efficientnet_b5',
#  'efficientnet_b6',
#  'efficientnet_b7',
#  'efficientnet_b8',
#  'efficientnet_cc_b0_4e',
#  'efficientnet_cc_b0_8e',
#  'efficientnet_cc_b1_8e',
#  'efficientnet_el',
#  'efficientnet_el_pruned',
#  'efficientnet_em',
#  'efficientnet_es',
#  'efficientnet_es_pruned',
#  'efficientnet_l2',
#  'efficientnet_lite0',
#  'efficientnet_lite1',
#  'efficientnet_lite2',
#  'efficientnet_lite3',
#  'efficientnet_lite4',
#  'efficientnetv2_l',
#  'efficientnetv2_m',
#  'efficientnetv2_rw_m',
#  'efficientnetv2_rw_s',
#  'efficientnetv2_s',
#  'ens_adv_inception_resnet_v2',
#  'ese_vovnet19b_dw',
#  'ese_vovnet19b_slim',
#  'ese_vovnet19b_slim_dw',
#  'ese_vovnet39b',
#  'ese_vovnet39b_evos',
#  'ese_vovnet57b',
#  'ese_vovnet99b',
#  'ese_vovnet99b_iabn',
#  'fbnetc_100',
#  'fbnetv3_b',
#  'fbnetv3_d',
#  'fbnetv3_g',
#  'gc_efficientnet_b0',
#  'gcresnet50t',
#  'gcresnext26ts',
#  'geresnet50t',
#  'gernet_l',
#  'gernet_m',
#  'gernet_s',
#  'ghostnet_050',
#  'ghostnet_100',
#  'ghostnet_130',
#  'gluon_inception_v3',
#  'gluon_resnet18_v1b',
#  'gluon_resnet34_v1b',
#  'gluon_resnet50_v1b',
#  'gluon_resnet50_v1c',
#  'gluon_resnet50_v1d',
#  'gluon_resnet50_v1s',
#  'gluon_resnet101_v1b',
#  'gluon_resnet101_v1c',
#  'gluon_resnet101_v1d',
#  'gluon_resnet101_v1s',
#  'gluon_resnet152_v1b',
#  'gluon_resnet152_v1c',
#  'gluon_resnet152_v1d',
#  'gluon_resnet152_v1s',
#  'gluon_resnext50_32x4d',
#  'gluon_resnext101_32x4d',
#  'gluon_resnext101_64x4d',
#  'gluon_senet154',
#  'gluon_seresnext50_32x4d',
#  'gluon_seresnext101_32x4d',
#  'gluon_seresnext101_64x4d',
#  'gluon_xception65',
#  'gmixer_12_224',
#  'gmixer_24_224',
#  'gmlp_b16_224',
#  'gmlp_s16_224',
#  'gmlp_ti16_224',
#  'halonet26t',
#  'halonet50ts',
#  'halonet_h1',
#  'halonet_h1_c4c5',
#  'hardcorenas_a',
#  'hardcorenas_b',
#  'hardcorenas_c',
#  'hardcorenas_d',
#  'hardcorenas_e',
#  'hardcorenas_f',
#  'hrnet_w18',
#  'hrnet_w18_small',
#  'hrnet_w18_small_v2',
#  'hrnet_w30',
#  'hrnet_w32',
#  'hrnet_w40',
#  'hrnet_w44',
#  'hrnet_w48',
#  'hrnet_w64',
#  'ig_resnext101_32x8d',
#  'ig_resnext101_32x16d',
#  'ig_resnext101_32x32d',
#  'ig_resnext101_32x48d',
#  'inception_resnet_v2',
#  'inception_v3',
#  'inception_v4',
#  'lambda_resnet26t',
#  'lambda_resnet50t',
#  'legacy_senet154',
#  'legacy_seresnet18',
#  'legacy_seresnet34',
#  'legacy_seresnet50',
#  'legacy_seresnet101',
#  'legacy_seresnet152',
#  'legacy_seresnext26_32x4d',
#  'legacy_seresnext50_32x4d',
#  'legacy_seresnext101_32x4d',
#  'levit_128',
#  'levit_128s',
#  'levit_192',
#  'levit_256',
#  'levit_384',
#  'mixer_b16_224',
#  'mixer_b16_224_in21k',
#  'mixer_b16_224_miil',
#  'mixer_b16_224_miil_in21k',
#  'mixer_b32_224',
#  'mixer_l16_224',
#  'mixer_l16_224_in21k',
#  'mixer_l32_224',
#  'mixer_s16_224',
#  'mixer_s32_224',
#  'mixnet_l',
#  'mixnet_m',
#  'mixnet_s',
#  'mixnet_xl',
#  'mixnet_xxl',
#  'mnasnet_050',
#  'mnasnet_075',
#  'mnasnet_100',
#  'mnasnet_140',
#  'mnasnet_a1',
#  'mnasnet_b1',
#  'mnasnet_small',
#  'mobilenetv2_100',
#  'mobilenetv2_110d',
#  'mobilenetv2_120d',
#  'mobilenetv2_140',
#  'mobilenetv3_large_075',
#  'mobilenetv3_large_100',
#  'mobilenetv3_large_100_miil',
#  'mobilenetv3_large_100_miil_in21k',
#  'mobilenetv3_rw',
#  'mobilenetv3_small_075',
#  'mobilenetv3_small_100',
#  'nasnetalarge',
#  'nf_ecaresnet26',
#  'nf_ecaresnet50',
#  'nf_ecaresnet101',
#  'nf_regnet_b0',
#  'nf_regnet_b1',
#  'nf_regnet_b2',
#  'nf_regnet_b3',
#  'nf_regnet_b4',
#  'nf_regnet_b5',
#  'nf_resnet26',
#  'nf_resnet50',
#  'nf_resnet101',
#  'nf_seresnet26',
#  'nf_seresnet50',
#  'nf_seresnet101',
#  'nfnet_f0',
#  'nfnet_f0s',
#  'nfnet_f1',
#  'nfnet_f1s',
#  'nfnet_f2',
#  'nfnet_f2s',
#  'nfnet_f3',
#  'nfnet_f3s',
#  'nfnet_f4',
#  'nfnet_f4s',
#  'nfnet_f5',
#  'nfnet_f5s',
#  'nfnet_f6',
#  'nfnet_f6s',
#  'nfnet_f7',
#  'nfnet_f7s',
#  'nfnet_l0',
#  'pit_b_224',
#  'pit_b_distilled_224',
#  'pit_s_224',
#  'pit_s_distilled_224',
#  'pit_ti_224',
#  'pit_ti_distilled_224',
#  'pit_xs_224',
#  'pit_xs_distilled_224',
#  'pnasnet5large',
#  'rednet26t',
#  'rednet50ts',
#  'regnetx_002',
#  'regnetx_004',
#  'regnetx_006',
#  'regnetx_008',
#  'regnetx_016',
#  'regnetx_032',
#  'regnetx_040',
#  'regnetx_064',
#  'regnetx_080',
#  'regnetx_120',
#  'regnetx_160',
#  'regnetx_320',
#  'regnety_002',
#  'regnety_004',
#  'regnety_006',
#  'regnety_008',
#  'regnety_016',
#  'regnety_032',
#  'regnety_040',
#  'regnety_064',
#  'regnety_080',
#  'regnety_120',
#  'regnety_160',
#  'regnety_320',
#  'repvgg_a2',
#  'repvgg_b0',
#  'repvgg_b1',
#  'repvgg_b1g4',
#  'repvgg_b2',
#  'repvgg_b2g4',
#  'repvgg_b3',
#  'repvgg_b3g4',
#  'res2net50_14w_8s',
#  'res2net50_26w_4s',
#  'res2net50_26w_6s',
#  'res2net50_26w_8s',
#  'res2net50_48w_2s',
#  'res2net101_26w_4s',
#  'res2next50',
#  'resmlp_12_224',
#  'resmlp_12_distilled_224',
#  'resmlp_24_224',
#  'resmlp_24_distilled_224',
#  'resmlp_36_224',
#  'resmlp_36_distilled_224',
#  'resmlp_big_24_224',
#  'resmlp_big_24_224_in22ft1k',
#  'resmlp_big_24_distilled_224',
#  'resnest14d',
#  'resnest26d',
#  'resnest50d',
#  'resnest50d_1s4x24d',
#  'resnest50d_4s2x40d',
#  'resnest101e',
#  'resnest200e',
#  'resnest269e',
#  'resnet18',
#  'resnet18d',
#  'resnet26',
#  'resnet26d',
#  'resnet26t',
#  'resnet34',
#  'resnet34d',
#  'resnet50',
#  'resnet50d',
#  'resnet50t',
#  'resnet51q',
#  'resnet61q',
#  'resnet101',
#  'resnet101d',
#  'resnet152',
#  'resnet152d',
#  'resnet200',
#  'resnet200d',
#  'resnetblur18',
#  'resnetblur50',
#  'resnetrs50',
#  'resnetrs101',
#  'resnetrs152',
#  'resnetrs200',
#  'resnetrs270',
#  'resnetrs350',
#  'resnetrs420',
#  'resnetv2_50',
#  'resnetv2_50d',
#  'resnetv2_50t',
#  'resnetv2_50x1_bit_distilled',
#  'resnetv2_50x1_bitm',
#  'resnetv2_50x1_bitm_in21k',
#  'resnetv2_50x3_bitm',
#  'resnetv2_50x3_bitm_in21k',
#  'resnetv2_101',
#  'resnetv2_101d',
#  'resnetv2_101x1_bitm',
#  'resnetv2_101x1_bitm_in21k',
#  'resnetv2_101x3_bitm',
#  'resnetv2_101x3_bitm_in21k',
#  'resnetv2_152',
#  'resnetv2_152d',
#  'resnetv2_152x2_bit_teacher',
#  'resnetv2_152x2_bit_teacher_384',
#  'resnetv2_152x2_bitm',
#  'resnetv2_152x2_bitm_in21k',
#  'resnetv2_152x4_bitm',
#  'resnetv2_152x4_bitm_in21k',
#  'resnext50_32x4d',
#  'resnext50d_32x4d',
#  'resnext101_32x4d',
#  'resnext101_32x8d',
#  'resnext101_64x4d',
#  'rexnet_100',
#  'rexnet_130',
#  'rexnet_150',
#  'rexnet_200',
#  'rexnetr_100',
#  'rexnetr_130',
#  'rexnetr_150',
#  'rexnetr_200',
#  'selecsls42',
#  'selecsls42b',
#  'selecsls60',
#  'selecsls60b',
#  'selecsls84',
#  'semnasnet_050',
#  'semnasnet_075',
#  'semnasnet_100',
#  'semnasnet_140',
#  'senet154',
#  'seresnet18',
#  'seresnet34',
#  'seresnet50',
#  'seresnet50t',
#  'seresnet101',
#  'seresnet152',
#  'seresnet152d',
#  'seresnet200d',
#  'seresnet269d',
#  'seresnext26d_32x4d',
#  'seresnext26t_32x4d',
#  'seresnext26tn_32x4d',
#  'seresnext50_32x4d',
#  'seresnext101_32x4d',
#  'seresnext101_32x8d',
#  'skresnet18',
#  'skresnet34',
#  'skresnet50',
#  'skresnet50d',
#  'skresnext50_32x4d',
#  'spnasnet_100',
#  'ssl_resnet18',
#  'ssl_resnet50',
#  'ssl_resnext50_32x4d',
#  'ssl_resnext101_32x4d',
#  'ssl_resnext101_32x8d',
#  'ssl_resnext101_32x16d',
#  'swin_base_patch4_window7_224',
#  'swin_base_patch4_window7_224_in22k',
#  'swin_base_patch4_window12_384',
#  'swin_base_patch4_window12_384_in22k',
#  'swin_large_patch4_window7_224',
#  'swin_large_patch4_window7_224_in22k',
#  'swin_large_patch4_window12_384',
#  'swin_large_patch4_window12_384_in22k',
#  'swin_small_patch4_window7_224',
#  'swin_tiny_patch4_window7_224',
#  'swinnet26t_256',
#  'swinnet50ts_256',
#  'swsl_resnet18',
#  'swsl_resnet50',
#  'swsl_resnext50_32x4d',
#  'swsl_resnext101_32x4d',
#  'swsl_resnext101_32x8d',
#  'swsl_resnext101_32x16d',
#  'tf_efficientnet_b0',
#  'tf_efficientnet_b0_ap',
#  'tf_efficientnet_b0_ns',
#  'tf_efficientnet_b1',
#  'tf_efficientnet_b1_ap',
#  'tf_efficientnet_b1_ns',
#  'tf_efficientnet_b2',
#  'tf_efficientnet_b2_ap',
#  'tf_efficientnet_b2_ns',
#  'tf_efficientnet_b3',
#  'tf_efficientnet_b3_ap',
#  'tf_efficientnet_b3_ns',
#  'tf_efficientnet_b4',
#  'tf_efficientnet_b4_ap',
#  'tf_efficientnet_b4_ns',
#  'tf_efficientnet_b5',
#  'tf_efficientnet_b5_ap',
#  'tf_efficientnet_b5_ns',
#  'tf_efficientnet_b6',
#  'tf_efficientnet_b6_ap',
#  'tf_efficientnet_b6_ns',
#  'tf_efficientnet_b7',
#  'tf_efficientnet_b7_ap',
#  'tf_efficientnet_b7_ns',
#  'tf_efficientnet_b8',
#  'tf_efficientnet_b8_ap',
#  'tf_efficientnet_cc_b0_4e',
#  'tf_efficientnet_cc_b0_8e',
#  'tf_efficientnet_cc_b1_8e',
#  'tf_efficientnet_el',
#  'tf_efficientnet_em',
#  'tf_efficientnet_es',
#  'tf_efficientnet_l2_ns',
#  'tf_efficientnet_l2_ns_475',
#  'tf_efficientnet_lite0',
#  'tf_efficientnet_lite1',
#  'tf_efficientnet_lite2',
#  'tf_efficientnet_lite3',
#  'tf_efficientnet_lite4',
#  'tf_efficientnetv2_b0',
#  'tf_efficientnetv2_b1',
#  'tf_efficientnetv2_b2',
#  'tf_efficientnetv2_b3',
#  'tf_efficientnetv2_l',
#  'tf_efficientnetv2_l_in21ft1k',
#  'tf_efficientnetv2_l_in21k',
#  'tf_efficientnetv2_m',
#  'tf_efficientnetv2_m_in21ft1k',
#  'tf_efficientnetv2_m_in21k',
#  'tf_efficientnetv2_s',
#  'tf_efficientnetv2_s_in21ft1k',
#  'tf_efficientnetv2_s_in21k',
#  'tf_inception_v3',
#  'tf_mixnet_l',
#  'tf_mixnet_m',
#  'tf_mixnet_s',
#  'tf_mobilenetv3_large_075',
#  'tf_mobilenetv3_large_100',
#  'tf_mobilenetv3_large_minimal_100',
#  'tf_mobilenetv3_small_075',
#  'tf_mobilenetv3_small_100',
#  'tf_mobilenetv3_small_minimal_100',
#  'tnt_b_patch16_224',
#  'tnt_s_patch16_224',
#  'tresnet_l',
#  'tresnet_l_448',
#  'tresnet_m',
#  'tresnet_m_448',
#  'tresnet_m_miil_in21k',
#  'tresnet_xl',
#  'tresnet_xl_448',
#  'tv_densenet121',
#  'tv_resnet34',
#  'tv_resnet50',
#  'tv_resnet101',
#  'tv_resnet152',
#  'tv_resnext50_32x4d',
#  'twins_pcpvt_base',
#  'twins_pcpvt_large',
#  'twins_pcpvt_small',
#  'twins_svt_base',
#  'twins_svt_large',
#  'twins_svt_small',
#  'vgg11',
#  'vgg11_bn',
#  'vgg13',
#  'vgg13_bn',
#  'vgg16',
#  'vgg16_bn',
#  'vgg19',
#  'vgg19_bn',
#  'visformer_small',
#  'visformer_tiny',
#  'vit_base_patch16_224',
#  'vit_base_patch16_224_in21k',
#  'vit_base_patch16_224_miil',
#  'vit_base_patch16_224_miil_in21k',
#  'vit_base_patch16_384',
#  'vit_base_patch32_224',
#  'vit_base_patch32_224_in21k',
#  'vit_base_patch32_384',
#  'vit_base_r26_s32_224',
#  'vit_base_r50_s16_224',
#  'vit_base_r50_s16_224_in21k',
#  'vit_base_r50_s16_384',
#  'vit_base_resnet26d_224',
#  'vit_base_resnet50_224_in21k',
#  'vit_base_resnet50_384',
#  'vit_base_resnet50d_224',
#  'vit_huge_patch14_224_in21k',
#  'vit_large_patch16_224',
#  'vit_large_patch16_224_in21k',
#  'vit_large_patch16_384',
#  'vit_large_patch32_224',
#  'vit_large_patch32_224_in21k',
#  'vit_large_patch32_384',
#  'vit_large_r50_s32_224',
#  'vit_large_r50_s32_224_in21k',
#  'vit_large_r50_s32_384',
#  'vit_small_patch16_224',
#  'vit_small_patch16_224_in21k',
#  'vit_small_patch16_384',
#  'vit_small_patch32_224',
#  'vit_small_patch32_224_in21k',
#  'vit_small_patch32_384',
#  'vit_small_r26_s32_224',
#  'vit_small_r26_s32_224_in21k',
#  'vit_small_r26_s32_384',
#  'vit_small_resnet26d_224',
#  'vit_small_resnet50d_s16_224',
#  'vit_tiny_patch16_224',
#  'vit_tiny_patch16_224_in21k',
#  'vit_tiny_patch16_384',
#  'vit_tiny_r_s16_p8_224',
#  'vit_tiny_r_s16_p8_224_in21k',
#  'vit_tiny_r_s16_p8_384',
#  'vovnet39a',
#  'vovnet57a',
#  'wide_resnet50_2',
#  'wide_resnet101_2',
#  'xception',
#  'xception41',
#  'xception65',
#  'xception71']
