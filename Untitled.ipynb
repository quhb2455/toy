# %%
import shutil
from glob import glob

# %%
train_path = '/Users/quhb2/Downloads/open/train/'
train_folders = sorted(glob(train_path + '/*'), key = lambda x : int(x.split('\\')[-1].replace('file_','')))

# %%
for train_folder in train_folders :
    json_path = glob(train_folder + '/*.json')[0]
    print(json_path)
    ds_path = '/Users/quhb2/Downloads/open/ori_label'
    name = json_path.split('\\')[-1]
    print(name)
    shutil.copy(json_path, ds_path)
# Out:
# /Users/quhb2/Downloads/open/train\file_0\file_0.json
# file_0.json
# /Users/quhb2/Downloads/open/train\file_1\file_1.json
# file_1.json
# /Users/quhb2/Downloads/open/train\file_2\file_2.json
# file_2.json
# /Users/quhb2/Downloads/open/train\file_3\file_3.json
# file_3.json
# /Users/quhb2/Downloads/open/train\file_4\file_4.json
# file_4.json
# /Users/quhb2/Downloads/open/train\file_5\file_5.json
# file_5.json
# /Users/quhb2/Downloads/open/train\file_6\file_6.json
# file_6.json
# /Users/quhb2/Downloads/open/train\file_7\file_7.json
# file_7.json
# /Users/quhb2/Downloads/open/train\file_8\file_8.json
# file_8.json
# /Users/quhb2/Downloads/open/train\file_9\file_9.json
# file_9.json
# /Users/quhb2/Downloads/open/train\file_10\file_10.json
# file_10.json
# /Users/quhb2/Downloads/open/train\file_11\file_11.json
# file_11.json
# /Users/quhb2/Downloads/open/train\file_12\file_12.json
# file_12.json
# /Users/quhb2/Downloads/open/train\file_13\file_13.json
# file_13.json
# ...
