# %%
import cv2
import glob
import os
import albumentations as A
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from tqdm import tqdm
from easydict import EasyDict

# %%
img = cv2.imread('../data/train/10001.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

img_w = cv2.imread('../data/train/10473.png')
img_w = cv2.cvtColor(img_w, cv2.COLOR_BGR2RGB)
# img_aug_w = aug_transforms(image=img_w)['image']

mixup = cv2.addWeighted(img, 0.3, img_w, 0.7, 1)
f, axs = plt.subplots(1,1, figsize=(20, 40))
axs.imshow(mixup)
plt.show()

# %%
a = {"b":{"c":1}}
a = EasyDict(a)
# Out:
#   Input In [10]
#     a."b".c
#       ^
# SyntaxError: invalid syntax
