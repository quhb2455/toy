# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

import os
from glob import glob
from tqdm import tqdm
import albumentations as A
from sklearn.model_selection import train_test_split, StratifiedKFold

# %% [markdown]
# # PlatVillage

# %%
village_data = os.listdir('./data/public/PlantVillage')
label_encoder = {}
for idx, data_name in enumerate(village_data) :
    label_encoder[idx] = data_name

label_decoder = {val:key for key, val in label_encoder.items()}
display(label_decoder)
display(label_encoder)
# Out:
# {'Pepper__bell___Bacterial_spot': 0,
#  'Pepper__bell___healthy': 1,
#  'Potato___Early_blight': 2,
#  'Potato___healthy': 3,
#  'Potato___Late_blight': 4,
#  'Tomato_Bacterial_spot': 5,
#  'Tomato_Early_blight': 6,
#  'Tomato_healthy': 7,
#  'Tomato_Late_blight': 8,
#  'Tomato_Leaf_Mold': 9,
#  'Tomato_Septoria_leaf_spot': 10,
#  'Tomato_Spider_mites_Two_spotted_spider_mite': 11,
#  'Tomato__Target_Spot': 12,
#  'Tomato__Tomato_mosaic_virus': 13,
#  'Tomato__Tomato_YellowLeaf__Curl_Virus': 14}
# {0: 'Pepper__bell___Bacterial_spot',
#  1: 'Pepper__bell___healthy',
#  2: 'Potato___Early_blight',
#  3: 'Potato___healthy',
#  4: 'Potato___Late_blight',
#  5: 'Tomato_Bacterial_spot',
#  6: 'Tomato_Early_blight',
#  7: 'Tomato_healthy',
#  8: 'Tomato_Late_blight',
#  9: 'Tomato_Leaf_Mold',
#  10: 'Tomato_Septoria_leaf_spot',
#  11: 'Tomato_Spider_mites_Two_spotted_spider_mite',
#  12: 'Tomato__Target_Spot',
#  13: 'Tomato__Tomato_mosaic_virus',
#  14: 'Tomato__Tomato_YellowLeaf__Curl_Virus'}

# %% [markdown]
# # custom dataset 정의

# %%
class VillageDataset(Dataset) :
    def __init__(self, files, transform, mode='train') :
        super(VillageDataset, self).__init__()
        self.files = files
        self.transform = transform
        self.mode = mode
        
    def __len__(self) :
        return len(self.files)
    
    def __getitem__(self, idx) :
        file_path = self.files[idx]
        
        label = label_decoder[file_path.split('\\')[-2]]
        
        img = cv2.imread(file_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = self.transform(image=img)['image']
        img = img.transpose(2, 0, 1)
        
        return torch.tensor(img, dtype=torch.float32) / 255.0, torch.tensor(label, dtype=torch.long)

# %% [markdown]
# # Dataloader w/o kfold

# %%
train_transforms = A.Compose([
                A.Resize(224 ,224),
                A.OneOf([
                    A.Rotate(),
                    A.HorizontalFlip(),
                    A.VerticalFlip()
                ], p=1)
            ])

val_transforms = A.Compose([
    A.Resize(224,224)
])

train = glob('./data/public/PlantVillage/*/*.JPG')
print("total : ", len(train))
label_list = [label_decoder[img_path.split('\\')[-2]] for img_path in train]

train, val = train_test_split(train, test_size=0.2, shuffle=True, stratify=label_list)
print("train : ", len(train))
print("val : ", len(val))
display(train)
train_dataset = VillageDataset(train, train_transforms)
val_dataset = VillageDataset(val, val_transforms)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
# Out:
# total :  20636
# train :  16508
# val :  4128
# ['./data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\94c2cf91-17c3-4ee1-b8f2-b20103e1c14f___NREC_B.Spot 9094.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\983a04ad-2cc6-4d78-9365-a67012b4ffdc___RS_Erly.B 7661.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\17a06d03-8a7b-48a8-aaf9-3300741c65de___RS_Early.B 7625.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\f88f405a-176b-479c-9028-913957456752___Com.G_SpM_FL 9638.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\ec7551da-66db-48cf-a1ab-2f9589f947d6___Com.G_TgS_FL 8095.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\4f5dde42-a6ac-4886-8b9e-a944568ace95___RS_HL 0080.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\63476e74-7aae-4e1c-b550-89e4be34149f___UF.GRC_YLCV_Lab 08428.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\bb4a96a1-3f00-4c1c-aa56-c88620a64aa4___Com.G_TgS_FL 7938.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\bb0d7ad0-8374-41a1-85bd-699892bb8431___RS_HL 0176.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\1e99ce6b-b7fa-4ae1-9076-279f430b8c5f___RS_Early.B 7092.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\f0dfdada-f425-46d7-8cf3-2957850b5a2e___RS_Erly.B 9466.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\83a8e340-30f9-4e2f-b825-a1078d5c63cf___RS_HL 0033.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\40285dce-33de-4a59-82f4-2eb1d6d38469___RS_LB 4929.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\70ef7eee-0584-44fc-9c5d-95b504554266___RS_Erly.B 7709.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\d67b224c-b089-430d-b185-dfae7b7a5a9e___Keller.St_CG 1950.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\18a21f42-8794-4665-8174-b0ccd3758af8___RS_Erly.B 7650.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\b8514357-a1cf-454c-b6c3-9873b8a1bab9___Com.G_TgS_FL 9903.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\c873c09b-f3b9-466c-bd1d-dc069eefde79___GHLB2 Leaf 9063.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\de4a4bd4-b611-46fd-8190-cff651b56326___Matt.S_CG 6718.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\0ed45bc2-c8cc-4d65-8f53-bdc10d78a7dc___RS_Early.B 8504.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\0c09c121-e945-4b7e-acbf-dff4e0d01acb___GCREC_Bact.Sp 3379.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\55c87fde-32cc-474c-a25a-1846d39aa6f4___RS_LB 2683.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\3f2d7c62-8d58-4a40-9df4-0ab3497b13b9___RS_LB 4487.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\8cdd8352-69a6-471e-978b-2f733fb4d33d___Com.G_TgS_FL 0004.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\5d99044d-1316-4808-9580-770052a59c46___JR_HL 5876.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\3266de9f-884f-424a-b3fa-9f8e9aae4478___UF.GRC_YLCV_Lab 01595.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\85a38441-6df7-4401-9905-fba74ebfa717___RS_Early.B 8230.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\17c7e5bd-f44e-4dbd-9cd0-f0dbcc654306___JR_Sept.L.S 8557.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\5bac1e11-978e-457e-85c2-11a1b5c618ca___GCREC_Bact.Sp 5860.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\c53ed58f-ec94-4b0d-b2e7-f9d76ffc2fd0___JR_HL 8630.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\077f081a-67f2-48d2-8084-53b912e65f3c___YLCV_GCREC 2935.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\d6016818-1e71-4bb2-a10b-35ef305b5dfb___Com.G_SpM_FL 1396.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\72361f8d-d158-48b5-a77e-f10cbaf7b29f___RS_HL 0118.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\ccc2f713-80ff-4e68-bb2d-14d6152dfa6d___GHLB2 Leaf 8898.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\2f433332-c89a-482b-993b-37a3a10096e0___GHLB2 Leaf 8616.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\a903e94f-f46d-430c-9ff1-3aab78130dca___Com.G_TgS_FL 9696.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\fba7a41d-25df-4a1c-93d1-98d62e3376e0___RS_Early.B 8207.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\aac2ff70-dd50-419f-8737-04bdbe3cec1c___Com.G_SpM_FL 1216.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\c4e95382-4bc7-4271-89ba-889f1dc55a2b___GHLB2 Leaf 9093.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\76cefc70-6454-4dd0-bd4d-fddb3d129bed___Com.G_TgS_FL 1057.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\0c83302d-4233-4e98-8ecf-755a970495bb___RS_LB 4904.JPG',
#  './data/public/PlantVillage\\Tomato_Leaf_Mold\\3a7f507d-76d7-4489-baf4-2e4dad468173___Crnl_L.Mold 8784.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\51c3e8ee-a665-4b7d-b4b5-b694ef56bd5f___UF.GRC_YLCV_Lab 01911.JPG',
#  './data/public/PlantVillage\\Potato___healthy\\414f6249-9f78-4af5-9593-9d5a7e7d979f___RS_HL 1918.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\3a66348b-a6b7-42ee-9411-9575a4240c6f___JR_HL 8627.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\8f1dc4b2-220e-4afd-a559-48a2f142007c___YLCV_NREC 2298.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\947b3e00-f128-48a1-b130-8170ef1d7ece___GCREC_Bact.Sp 3409.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\55dcc83b-4c4a-4ce3-84ab-3b57f30b0525___YLCV_GCREC 5222.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\ef3f651f-80cf-4a1e-9c1d-543953ccf1ee___Com.G_SpM_FL 1286.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\dd2bf52d-685d-4feb-ac7e-846cbd29d9c3___JR_B.Spot 8891.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\78071f69-3d02-4576-bd46-28732dd528aa___RS_Early.B 9228.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\2ec298be-1276-4077-8492-926b0d4f7a8f___YLCV_NREC 2000.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\e2157d7b-cb1c-417a-8db6-679a20872be4___JR_HL 5960.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\d4ea7c9d-a3ff-4055-a150-77a5bf30c2b6___Com.G_SpM_FL 9299.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\9d8b787b-4b2f-4f54-8a2d-e0640c374fe0___Matt.S_CG 1425.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\af0ee942-50f5-43a7-a9fe-486ba1f5f989___RS_Early.B 7700.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\08a52166-1435-4602-9d59-5dc6ef93c549___YLCV_NREC 0224.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\4c2d693d-a7e9-4c74-b400-1983abbcb0e5___YLCV_GCREC 2554.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\84f03e83-ac3b-4804-8791-68b2a523b065___NREC_B.Spot 1870.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\26d0fa09-d463-461b-830c-3e970244cabb___RS_Early.B 7406.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\4f4ae955-8ed2-4eae-b013-bc26ae5e91b0___GHLB2 Leaf 91.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\dae7db93-d197-4616-a16b-5dcc59058bc2___RS_LB 3178.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\08166dc1-9f39-4086-bcc9-f0dc0f0e85a6___UF.GRC_YLCV_Lab 02812.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\939b8ab2-3d4d-4ee3-8677-18e29f2f8bc3___Matt.S_CG 1651.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\7a469155-1492-4f16-b352-d4e99b3e94a2___Matt.S_CG 0838.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\503785a3-9eaa-4887-b832-2288f747624a___RS_Erly.B 7636.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\af156939-f96f-4b7a-bd93-a5ebde95fc14___Com.G_TgS_FL 1036.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\d5c51ec6-506e-4b85-b774-66f6a5493c90___RS_Early.B 7071.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\6e8def24-a55a-464e-88a3-624075de0cf1___GCREC_Bact.Sp 2952.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\1cda9dae-d9ec-42b2-a420-52001ccb4941___UF.GRC_YLCV_Lab 03302.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\79ae335e-dbb0-4bb0-8003-6dba7402cbd5___Com.G_SpM_FL 1302.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\923e88aa-d37a-4890-98f6-503eb87dbee4___YLCV_NREC 2568.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_mosaic_virus\\860780b3-9c8b-4f90-9010-ac255e953784___PSU_CG 2150.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\d598dca9-3560-44d7-ac84-7dc1eeb72655___NREC_B.Spot 9121.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\217dfd47-7d8c-44f0-addb-c05b218d3735___YLCV_NREC 2691.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\5418736d-c947-4cdc-b82c-692de712880a___JR_Sept.L.S 2619.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\7ace1bb9-5005-4a1b-a207-7d55e65c6652___JR_HL 7875.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\2171d774-ac55-4859-8c78-2de496fef822___YLCV_NREC 2976.JPG',
#  './data/public/PlantVillage\\Tomato_Leaf_Mold\\a9bfbf7a-3669-4b5e-a5c7-ac8fcd03fd48___Crnl_L.Mold 7094.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\5755142f-0cba-45b7-a563-beb1bf6db374___RS_Early.B 8321.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\23b6e2a4-c231-4270-994e-6a5e58edddc7___Com.G_TgS_FL 8279.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\6fa01a78-0d8d-4ecf-b90f-4dbc2e89f2d9___RS_HL 0220.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\904ba0d5-9070-496a-8983-1eb75cd4149c___Com.G_TgS_FL 0049.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\d5a1e4e1-f646-408e-b0af-e64262e492d8___Matt.S_CG 0884.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\b4c4e221-ab02-4e57-a82c-5f2dfd431675___RS_Late.B 5029.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\3ab17a89-2e50-49c2-bb75-518369da98c1___RS_Early.B 8636.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\b5397b14-c009-41b4-b828-45203ffa2d22___GHLB2 Leaf 8986.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\6dcca219-2671-49d7-82f4-dac9571aae01___Matt.S_CG 1030.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\504b03b4-c056-4468-a6ce-19fa79243071___Com.G_SpM_FL 8965.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\25a52867-003f-4390-a80d-03c63c038e9a___UF.GRC_BS_Lab Leaf 0341.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\6e382244-fb3a-4caa-af71-05fff25f1c27___UF.GRC_YLCV_Lab 03397.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\41fed9b9-d409-4b56-a9d6-3e98f31a4e3a___JR_B.Spot 3275.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\1c28ac78-ae5c-4e33-81bb-c2311ded2d8d___YLCV_GCREC 2560.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\75fbe8d1-9d11-4039-9973-ba2599641426___UF.GRC_YLCV_Lab 02548.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\29e2d4fc-01ad-4da0-8b2c-dfd51fcc294c___UF.GRC_YLCV_Lab 03280.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\1469ba5d-2d15-4089-a7a2-762a4a43bdbd___JR_Sept.L.S 8452.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\1fa569d8-45ba-4633-b66d-3fdb07ed523e___RS_HL 0533.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\add7e2f3-37f3-42e8-952d-6703822d10b4___Com.G_SpM_FL 8870.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\824cf247-344d-446f-9f9c-09d24a0da04c___Com.G_TgS_FL 9735.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\803ac166-670f-4cad-9f37-e36eea3118d9___RS_Erly.B 9457.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\d1072068-911c-4656-8bf2-e662982199e1___RS_Early.B 8141.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\07eda9a1-8f8a-471b-b3c6-9093c3d6ca90___JR_HL 8177.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\989c19ba-120b-472c-abe1-821da1b065d0___RS_HL 0280.JPG',
#  './data/public/PlantVillage\\Tomato_Leaf_Mold\\9a1244ad-a278-41bb-99e7-f7d2fcff0b98___Crnl_L.Mold 7029.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\9bcca2b9-103b-49bd-ab07-54c810d4c932___Com.G_TgS_FL 9684.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\3294ec88-cc8d-4e3a-af08-f2f9d7f4a73b___JR_B.Spot 3196.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\19f1a490-694f-45f1-a606-00c800a4d10b___Com.G_SpM_FL 1492.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\bb2586ff-9676-4100-89f7-200d9ce5ecd6___RS_Erly.B 9386.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\35a552c8-feba-4b4a-9aee-3833e8b1daea___NREC_B.Spot 9200.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\919be4c2-1ff6-4fd2-8f71-26aa280b8d3b___YLCV_NREC 2639.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\bd66c86d-1aa8-47ae-bfa6-8bf8dcd2c146___Com.G_SpM_FL 1167.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\991e779d-ffcb-4f55-98f6-20575d202757___RS_HL 0166.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\964b07f8-2eb7-45b4-9ac8-79ec296b1655___RS_Erly.B 7378.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\09f2d645-c2e5-413c-b5fb-3be87c149566___YLCV_NREC 0090.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\39528564-9273-41d9-96d4-2170096eb649___Com.G_SpM_FL 8756.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\8c84bc07-0e52-4584-ba94-793b136eead2___GCREC_Bact.Sp 2950.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_mosaic_virus\\bf950cb4-985f-4174-b32b-9ae2d6e99a84___PSU_CG 2320.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\0d4ba6a2-e8a6-49b0-8f94-ab63ab5c5d3c___YLCV_NREC 2030.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\2312305e-c167-4730-a07a-db5c9956077a___RS_Erly.B 7752.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\a10b278a-fcce-4cf4-aada-254e89050be5___RS_Early.B 7524.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\c7b40855-4938-49bd-9b74-02d3cb06c1a3___Matt.S_CG 6555.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\f8666878-6995-4e12-93b9-c20b02b606ba___Keller.St_CG 1985.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\841cd513-3d3b-4ba5-ba29-1b7bf5220f9c___GCREC_Bact.Sp 3595.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\05c6ea65-cce4-43da-b57b-a45321b0e51b___NREC_B.Spot 9048.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\64518a58-5c06-4a14-9ab6-2c4f71456050___GH_HL Leaf 394.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\7d85c8c9-a4fa-4241-9de5-dd9959ea7a62___UF.GRC_YLCV_Lab 01726.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\3049a6ad-905d-4a96-92b4-2ec045c397a1___Com.G_SpM_FL 8796.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\ae016efb-ee4a-457c-8e91-788ddbbdaee4___JR_HL 7715.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\e40b6718-52b6-46a7-970c-5f1b6bae23af___RS_Early.B 8287.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\e65ea8c4-01ff-42ff-8666-1dc4958b37da___GCREC_Bact.Sp 5653.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\54e98d19-a7a0-44d8-a004-1eaee5f3610b___RS_Erly.B 7348.JPG',
#  './data/public/PlantVillage\\Tomato_Leaf_Mold\\3876f39d-ca68-494d-ac22-f71d5d459a66___Crnl_L.Mold 9175.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\0114f7b3-7f56-4bef-aa47-7a82da142d4b___RS_Erly.B 7437.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\ee4400a9-c4f6-432d-985a-ff8dc730467b___JR_HL 7620.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\71c96679-5107-4efd-b1ad-f3b9b60e0f08___Com.G_TgS_FL 9790.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\0e94696b-3e0d-4d4c-a712-01197e228cf1___UF.GRC_BS_Lab Leaf 8641.JPG',
#  './data/public/PlantVillage\\Potato___healthy\\a4d1d8cb-26a2-413f-a229-021e2eea87ac___RS_HL 1819.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\0ce66ec5-0bb7-4fde-9c61-750a1a150f75___UF.GRC_YLCV_Lab 02219.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\92757a8e-b68a-45b3-9d70-0281c8ea90ca___RS_Early.B 7199.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\3fd0b775-f9e3-4f35-96e0-cd75d9aae7de___UF.GRC_YLCV_Lab 09525.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\f63f3650-9f84-45f9-898b-a6adef0294a3___RS_Erly.B 8419.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\24342d0b-36bf-45df-8a26-d4d748f52890___UF.GRC_YLCV_Lab 01940.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\3af826c4-e8d8-472f-b4cf-d1a34bc2cd35___NREC_B.Spot 9051.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\fcf8557f-890e-441b-9dc1-c8854f694f2e___RS_Erly.B 9505.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\6d5a3f06-e19e-4a6e-8e10-c441daf2a48e___YLCV_GCREC 1978.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\50affc63-4d3e-4eb4-ad9c-4f9b7311e989___GCREC_Bact.Sp 3035.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\0bfc96b3-56ba-4ba4-804a-fc2ba59e0c6a___UF.GRC_YLCV_Lab 03202.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\c4ec31de-5466-49c0-b034-84a825327e0b___RS_Early.B 8062.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\369bde96-5f99-4fa3-a08f-e5dbf0eeeb9c___YLCV_NREC 2593.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\aca08460-3229-47d9-9ce6-7b2bb9f1ce7f___JR_B.Spot 8901.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\7f0c3ad4-67f7-4a6e-81da-5cdbe1c5ff8b___RS_Early.B 8453.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_mosaic_virus\\f7d8d2a1-2cc6-41e7-9626-76ddf51e7a8b___PSU_CG 2179.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\c3a27dc9-0abc-4828-9163-f55530332cab___GH_HL Leaf 228.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\58a5fcdf-b53d-4f8d-ab17-a163e11fda15___YLCV_NREC 0167.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\78863d29-72bb-494d-8f05-c5648130283f___GHLB2 Leaf 9112.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\acad7d53-5c67-48e9-a383-af6ced180029___Com.G_TgS_FL 8150.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\ffef8a3b-3e8a-4c24-a27e-64c41708f7a0___RS_Early.B 7132.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\615a9d50-74d8-4435-af2c-459d8f97e453___GCREC_Bact.Sp 5676.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\0bbf4db7-38a1-4d5c-8fd7-503e9f37ef8f___Matt.S_CG 7848.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\3472596b-2763-4b57-a0af-43c294f7ba93___Com.G_SpM_FL 1575.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\a885be53-67e7-4897-b0ee-179971cd7976___Matt.S_CG 1642.JPG',
#  './data/public/PlantVillage\\Tomato_Leaf_Mold\\10e1a86f-0355-4534-aed8-08c6f01548d4___Crnl_L.Mold 7018.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\6c475c34-fcf6-4386-97f3-a08424dc0401___NREC_B.Spot 1801.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\b3cc95da-557b-456d-9c5d-2ba5d9eb0e98___RS_Late.B 4930.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\1b966d62-d5c3-4a67-ba36-b67d873ccfdf___GH_HL Leaf 440.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\f964b423-2146-4523-9f71-d7937c475bf0___RS_LB 3842.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\9d12ad8a-e252-48bc-bbeb-a198c1c9049b___Matt.S_CG 6367.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\eb5f70b3-7bc8-4b2b-b2c3-26389d0ffc2f___Com.G_TgS_FL 0044.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\cbdb596e-46a9-4d85-9adf-550b8d2bd7ae___RS_HL 0340.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\57cc95ac-1fae-4959-ba16-d65c3db753d1___RS_HL 0312.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\806a1f93-1b9f-4860-91e1-9aff2d68c494___RS_HL 0468.JPG',
#  './data/public/PlantVillage\\Tomato_Leaf_Mold\\e9a29961-5b3e-47a8-b2aa-b8d0ba9f2a80___Crnl_L.Mold 6838.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\cef9fa90-aca2-4354-b79e-2486409ac685___RS_Erly.B 7563.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\ce0bad5b-8752-4d85-af7f-d4d6ad672865___JR_Sept.L.S 2529.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\19de5bae-f8a3-467b-a0f8-11a6b42b271f___YLCV_GCREC 2477.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\fc135130-76fe-4249-a36f-8aa02129c7c7___Com.G_SpM_FL 9366.JPG',
#  './data/public/PlantVillage\\Tomato_Leaf_Mold\\ecee5a37-1c82-4f93-a9d9-d1c098e6514d___Crnl_L.Mold 8618.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\e33f0c2f-ff87-42e2-a31f-aaf232e67e10___RS_Late.B 5231.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\1ce80571-2358-4616-b04a-14bbdfd2af6b___JR_HL 8340.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\e54d8bbc-d1e7-4ac8-86e0-06a0a2e88ed7___Com.G_TgS_FL 9873.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\2a8a3b2f-d65a-416b-a251-63bb89f448c3___JR_B.Spot 3322.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\7cb1f036-bf36-4271-a765-86e575664f3c___JR_HL 8075.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_mosaic_virus\\ee1d7f40-d80c-4cac-9cd3-1a687431496e___PSU_CG 2282.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\2572d994-464a-461e-a0c8-597dc2229c09___RS_LB 2763.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\e980207c-6e67-4caf-8973-7128ca2a1c12___GHLB2 Leaf 8876.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\d34bb16c-4890-499a-8bcd-7fbd6c540a91___Matt.S_CG 7546.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\2dfa5a01-658b-4876-a02e-31cec4378f9c___UF.GRC_YLCV_Lab 01339.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\6148bead-5236-461d-90ca-bc552dc95abc___RS_LB 2983.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\8c3ccc36-216d-4249-af4f-a6d41f9991d5___Com.G_SpM_FL 9022.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\f295d002-ba3b-45f4-ad4d-44ecf10afbf7___GCREC_Bact.Sp 5820.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\38c1c136-d91d-4527-aa8f-623a574a41d9___RS_LB 3042.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\5973fb5e-f34c-4fa0-9c27-190c517b964f___YLCV_GCREC 5428.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\54004f4a-6645-410f-ba96-5d3055522667___JR_Sept.L.S 2515.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\ea5724f3-d1ff-4a32-b679-b08bdfc9b997___GCREC_Bact.Sp 3662.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\15e6ea48-3815-4e37-a901-e2fbeea1b78c___Com.G_TgS_FL 7870.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\2c11cd9f-5a64-49eb-91ba-63a7188c8eb7___GCREC_Bact.Sp 5926.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\0a47f32c-1724-4c8d-bfe4-986cedd3587b___RS_Early.B 8001.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\0d70d565-520e-474c-85c1-ab478c9f1d4b___GH_HL Leaf 203.1.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\fb7d1c6e-6d3c-4f03-b8dd-9c51740ed23a___Com.G_SpM_FL 1681.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\373bf7cd-8cf2-46dd-accb-71bd92a75e25___YLCV_GCREC 2628.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\bc3ca9e1-86c1-4945-9993-c61a38a942ed___GH_HL Leaf 294.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\62b21608-afe7-40c5-aa91-f9a05b021736___UF.GRC_YLCV_Lab 02889.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\b338fbbd-ec79-4807-be12-a5c678d1f78d___JR_B.Spot 8881.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\befda082-9237-4371-bd11-5d3513a365a5___RS_LB 2608.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\610d8d2d-c28d-4d99-9f37-a6a79148b529___RS_Early.B 8023.JPG',
#  './data/public/PlantVillage\\Tomato_Leaf_Mold\\d9dbc294-2f3a-409f-a238-218c4700d011___Crnl_L.Mold 8748.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_mosaic_virus\\67d62cc2-ac5e-4ad7-91a0-c097163df653___PSU_CG 2048.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\e421fcb0-be23-4ff8-a5f0-0ee7110160e5___Com.G_SpM_FL 1680.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\42c56133-35dc-4a2b-a92e-d3085408cb6f___UF.GRC_YLCV_Lab 02314.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\932b6ab7-9d96-43ec-9e7b-e2b0508d8a1e___Matt.S_CG 1596.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\743d6eb8-a7c4-4632-95f0-8ca346e6de2b___YLCV_GCREC 1975.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\2f9b712f-708a-4e10-b63e-5c1c2208081d___GCREC_Bact.Sp 2966.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\879d0dfe-d17d-486a-992c-d80089133c50___RS_Early.B 7428.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\3af1fd7b-aca5-405e-b4ab-3615eaa6c0df___Matt.S_CG 6915.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\da3fdd83-69de-4688-8386-71e01138f324___JR_B.Spot 8994.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\303b8c34-0a74-4248-b5ce-1f9a0e367d6b___GCREC_Bact.Sp 3477.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\b5d5a42e-5d4f-4429-8923-aee42e0a0c5d___NREC_B.Spot 9189.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\17557939-f9e2-435a-a4e7-f4d3cff8aa8b___JR_B.Spot 3107.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\db60c4cf-30f1-460c-a345-3045f192f725___RS_Early.B 6722.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\4685f4da-68f9-42e2-be02-ed5efd249606___YLCV_GCREC 2669.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\c4554e01-7d63-459a-9d37-0f8ba985b950___Keller.St_CG 1910.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\1f8f9ea6-3154-4874-8937-f8762b70a917___YLCV_GCREC 2459.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\4c41c67d-564c-44e2-98e0-b19bc3e10c7c___Com.G_SpM_FL 8887.JPG',
#  './data/public/PlantVillage\\Tomato_Leaf_Mold\\06885d98-1412-4073-8800-9da44c3935c6___Crnl_L.Mold 6794.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\cda3b0ec-ee7d-4616-95d4-d8064c30e376___Com.G_TgS_FL 0928.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\9365125f-1687-4a9b-ba71-e92a869b774c___Com.G_TgS_FL 1120.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\aef76e6b-3245-4653-887a-a64d76a93bb8___JR_HL 8042.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\5a43b236-f091-4e4b-8b17-b7fe3a6515d3___JR_Sept.L.S 8390.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\3633c989-bce5-4cfc-bb1c-49cc1976f0b4___Matt.S_CG 6012.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\8581fc41-9bd8-4845-9eef-bf1c58997a37___JR_B.Spot 9038.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\239580d0-a58b-4c44-ba1c-b195629d03e6___UF.GRC_YLCV_Lab 01787.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\d4d0e98c-5d9c-4301-9c1e-546c3a3abfd1___JR_B.Spot 9008.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\dbbb04ee-e2ea-4c76-bf67-c3a0aa708407___UF.GRC_BS_Lab Leaf 0508.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\f5d9fa8d-af44-4362-9134-190479bbe522___GCREC_Bact.Sp 3610.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\1d31b822-7933-4801-a18c-657b8af377d6___RS_HL 0636.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\f7964e03-1651-4a72-8f28-be8626513372___GCREC_Bact.Sp 5591.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_mosaic_virus\\382828a4-dbdf-4ddc-a75b-9a6fcc4b600e___PSU_CG 2054.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\bb88a552-d534-4175-ad70-209157de60d8___JR_HL 5809.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\9dae6946-8d64-403b-bc51-b1b58cf8050b___RS_LB 4028.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\676eaef6-b16c-4f13-a39d-86c22f64da83___GH_HL Leaf 356.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\f7069452-9405-45a6-bfb3-f21ea42b9b02___RS_HL 9966.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\62398423-ef8e-4a9f-a1d0-1ebee08faafc___GCREC_Bact.Sp 3521.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\1757f48b-435b-4c4a-9de6-47b959ed1e67___RS_LB 5295.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\5f473bdb-1899-4877-8d8f-df2e94996d1f___RS_Late.B 6266.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\b3201f15-9503-436f-889e-c71663ca0b2c___Com.G_TgS_FL 9691.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\fb916ecd-183f-4caa-8daf-fb9d83f43e88___JR_HL 7972.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\321e0205-71b9-438d-baf3-e6429b301689___Matt.S_CG 1657.JPG',
#  './data/public/PlantVillage\\Tomato_Leaf_Mold\\866d57df-74c8-4546-9f82-d03b3c554556___Crnl_L.Mold 8981.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\869168d7-a45c-40e6-888b-ad5ba94a657e___RS_Late.B 6193.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\524b0b87-2adb-409c-acd6-02327fb7a064___NREC_B.Spot 9212.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\249c9700-e21c-405d-94a9-dbdd4964a38c___YLCV_NREC 2786.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\00100ffa-095e-4881-aebf-61fe5af7226e___JR_HL 7886.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\8c3a26fe-2c28-4f55-9a5b-3d8b2be54502___GCREC_Bact.Sp 3682.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\c6a1dc1f-e0fd-40df-8726-5db2b0be7150___Com.G_TgS_FL 0736.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\bdba3ee1-95a1-45b8-9c31-21add45a86aa___JR_HL 8594.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\973b8b82-cccd-433c-a868-5dee559b2dce___GHLB Leaf 2.6 Day 12.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_mosaic_virus\\20182b2d-dfda-4ef1-89cc-17856e051b00___PSU_CG 2072.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\150f2e9e-1317-492d-a926-3014853ea6de___UF.GRC_YLCV_Lab 03116.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\56e3c593-6093-4777-a1f0-e2c808190457___YLCV_NREC 2847.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\5032f1a5-22a0-42c3-bcf4-d44d4334ac5a___JR_Sept.L.S 8554.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\ae43f1d0-3ae6-4634-938c-0b003b193416___GCREC_Bact.Sp 6105.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\96b822e7-9d51-40d2-9a1f-b4125446531b___Matt.S_CG 7397.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\839f0c78-eea2-4a82-a483-46f2e671e855___Com.G_TgS_FL 8217.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\e4ea3383-b5fc-45b6-a583-0363f632c3be___GCREC_Bact.Sp 3094.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\10724f1f-17fb-4443-9878-26e31d97e2d9___JR_HL 7585.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\b6905f0b-a167-4b6c-a72b-3c6c187d8032___Matt.S_CG 6046.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\e92997f6-dbc1-41b2-a369-df791b3150ce___Com.G_TgS_FL 0649.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\4a1fef3f-35be-48ca-9e6c-78d5578c727a___Com.G_SpM_FL 1316.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\0650f176-add9-444e-893e-707969054a43___JR_Sept.L.S 2722.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\591c89ff-a75f-4613-b06d-4f3fbf6c426c___GH_HL Leaf 435.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\620df2cc-834d-48b9-b9a8-11da26395739___RS_Erly.B 9557.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_mosaic_virus\\c668017b-5c87-4f2e-90ab-021b81f48b1b___PSU_CG 2272.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\b8b09399-338a-4e6d-b05b-30b7a24afc43___GCREC_Bact.Sp 3273.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\0fdcaef4-4723-4b4b-b81c-45f250a8ede3___YLCV_NREC 0254.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\760a8072-2979-49aa-a6bf-e075151758d8___RS_Late.B 5089.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\c6c8843f-6b36-472a-9a87-bf1a235e08b6___RS_LB 5136.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\8d786c11-5426-4af6-96a0-0c0d9ec804d7___RS_Late.B 5009.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\d83aedd2-b79e-420f-ab88-af97cc3b685d___JR_Sept.L.S 8414.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\00726ad4-2569-46ce-9d4e-dbf82b14bd94___JR_HL 8686.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\87b6a20f-1b39-4696-a2a7-5fdcf5dbc4f5___Com.G_TgS_FL 1014.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\3bbbc0b0-261d-4bf7-ae6c-8d43782a7918___YLCV_NREC 2149.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\66534b5a-a6b7-46bb-bc09-a6bba9d9a61a___GH_HL Leaf 225.2.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\758b39d7-12bc-401f-b280-2c8435a02f43___RS_Early.B 6839.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\096df0cf-7d61-4e67-8785-cba26db95895___Com.G_TgS_FL 9970.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\7a08fe90-da9a-41a0-99f0-5952625a83bb___Com.G_SpM_FL 1371.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\9d06e189-6e39-4fb9-853b-e2ce180469a5___RS_HL 0407.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\31d61797-f3dd-4452-8db9-cdfd8be9ebf2___RS_LB 4823.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\dc3a13dc-a628-433f-a038-a3f377bc608e___GH_HL Leaf 422.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\0ab15cde-93e5-41ff-8fd5-db09c6829d72___YLCV_GCREC 2293.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\6e849af6-2a4c-49d9-b5d1-febeec2cc8b5___UF.GRC_YLCV_Lab 02965.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\0c8d8784-1442-45e6-b7b9-0d9659015bfa___YLCV_NREC 0228.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\e0e15d89-8c3b-43f5-8617-136b720e39cd___RS_LB 2668.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\2fb5c266-b7ec-4b31-91b4-3f2dc9b0cdcb___RS_HL 0147.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\1ca9e3ba-e029-48bf-b207-e8cb3546f953___RS_Early.B 7978.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\79466870-1413-4b75-93e6-31b827cfa3ac___GCREC_Bact.Sp 6043.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\eb2eebd9-62f0-441c-908f-1ff90f36bb66___GCREC_Bact.Sp 5752.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\8026acba-1bf2-4c4c-94d4-dac6d642be34___YLCV_GCREC 2786.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\f0037c61-001d-4b1f-b794-5b5ab49d50d5___RS_HL 0527.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\70640fa6-e8ff-416c-a8a1-256e754c9f2c___Com.G_TgS_FL 0947.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\3ecf6ae1-56d9-47c0-bedb-af7954dbc3c6___JR_B.Spot 8953.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\e13060fe-90fb-49c9-ab46-9a4cfd68c02a___Com.G_SpM_FL 1749.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\31d3fd73-b756-4d79-9774-3ddb034f8fd5___JR_HL 8582.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\7c2aba18-254c-4e86-86ee-196a5a092324___RS_HL 0395.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\525c2813-206e-40ee-80a2-83b56ef45b13___RS_HL 0547.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\cac99520-3403-4602-961d-3a668bb980fb___RS_Early.B 7388.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\b88f6060-ca8b-4c4d-bd4c-1ec1ae186b71___GHLB2 Leaf 8711.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\a42b5660-6dff-4433-995f-18ea64ec0339___Com.G_TgS_FL 8226.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\812654c4-843c-42b1-a026-ab3ee7c9f837___RS_Late.B 7061.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\0f809e80-ee2b-4ad4-9a80-50d789298d48___GH_HL Leaf 192.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\689d9301-7023-4488-9c9e-ba194bbd195b___GCREC_Bact.Sp 3315.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\83e7aaf4-0c60-4712-a484-cb0cc4616065___YLCV_GCREC 2833.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\c86292c5-5f49-498d-9339-5f8d5d0b7492___JR_HL 7821.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\e55af4aa-1f1c-4300-86ca-bdcff04bef80___GHLB_PS Leaf 2 Day 9.jpg',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\0f94b000-c54f-45c1-b976-22cb57dda0c4___Com.G_SpM_FL 9640.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\d489099b-31cf-484f-a0d6-46f24e6875ab___GCREC_Bact.Sp 3523.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\5be6f633-9ae7-40b9-b1aa-f92a1ab919fb___RS_Late.B 5011.JPG',
#  './data/public/PlantVillage\\Tomato_Leaf_Mold\\924b52ad-82dd-4562-94b6-5a5a9e41e81c___Crnl_L.Mold 9110.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\4e726fa5-592c-4e69-a29e-4fc466d82597___GCREC_Bact.Sp 3377.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\d8b0ded7-7d30-4b52-acea-d1a3ca70a392___RS_Late.B 6096.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\1f560f09-0b70-40c9-b907-4cac9ba47b8d___RS_LB 3184.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\d50b9da6-eb7a-4552-aea7-d74b6da2e071___Com.G_SpM_FL 8607.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\024623ab-be81-4d99-a653-c3be1495ce8e___JR_B.Spot 8889.JPG',
#  './data/public/PlantVillage\\Tomato_Leaf_Mold\\27e8bb41-97a2-44b7-95e2-fd3b2e99f317___Crnl_L.Mold 7064.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\16e6cb79-1738-454a-aca2-a092bb0f5805___Com.G_TgS_FL 0861.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\0e321bad-3d5e-4f2f-abf0-f991bfc12b26___UF.GRC_YLCV_Lab 09481.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\cbd4ef4a-1e84-41ac-8744-b5a1c52461be___RS_Early.B 8191.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\44a9131e-6f2a-408d-ab7e-ccd0a935cdcc___Com.G_TgS_FL 9934.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\2853ccb3-5c5e-49b9-a2ff-988224505f23___JR_HL 7851.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\c8080916-dd9d-40c4-a39b-1957ebd17b87___NREC_B.Spot 9115.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\985f3b47-d5ee-45d4-a020-f43ca80fb59e___RS_Early.B 9211.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\d7d2bf3e-2e90-4f21-8c2f-df9baffac2e9___Com.G_TgS_FL 8354.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\221b0575-215a-430d-a728-60020b7ad160___GH_HL Leaf 340.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\5d40d3db-1277-4136-9276-229450f81b5b___YLCV_NREC 2588.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\d14316d2-f733-4b05-933e-bb29ab3af867___Com.G_TgS_FL 1128.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\483fca3c-0413-4136-a2ff-931bc789c830___YLCV_GCREC 5298.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\fb967f21-6c02-4bd3-9145-ee91db7eb2c8___Com.G_TgS_FL 8059.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\35f15b6d-a287-4e3c-ace7-428c80d94d68___YLCV_NREC 0263.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\34d7e068-10e6-4ea0-8547-c90937fccbbc___RS_Early.B 8198.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\82b9b632-6609-4f02-b58c-63480badb4e9___GCREC_Bact.Sp 6164.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\a8056fd4-4ac0-46c4-a7c5-905b4bf87760___Keller.St_CG 1782.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\d13cfcd6-79ac-48c9-9e88-931982463214___NREC_B.Spot 1895.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\5eeede3b-6469-48f4-9bd9-56732ee3c4cf___UF.GRC_BS_Lab Leaf 0627.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\92d04528-2709-4cc0-8e98-bdfe2ef97143___RS_HL 9808.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\6c93e40c-bd94-4583-8651-2b9d7215a392___RS_HL 0054.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\cf72fe62-8411-4b4e-b4df-98c6683c00ca___Keller.St_CG 1816.JPG',
#  './data/public/PlantVillage\\Potato___healthy\\00fc2ee5-729f-4757-8aeb-65c3355874f2___RS_HL 1864.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\e3c99f3d-4947-41c6-99b1-137fb60195d2___Matt.S_CG 1374.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\b3ff240c-bcdd-4926-9e87-c515cd6c2971___GH_HL Leaf 409.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\0a246e71-0551-4603-a017-d1dfc4ea06be___Com.G_SpM_FL 1178.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\d2ff230f-99a5-4dc5-968c-246d772788af___RS_LB 3279.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\76ee26db-ef55-43b9-9179-6b9ba15dc21a___RS_LB 4058.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\2605218e-e8bf-43d8-8b00-52058e9f0f25___RS_HL 9893.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\5153c319-4ab2-4ad0-af02-37219b0766d3___GH_HL Leaf 500.3.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\5373b361-a0ee-477a-b8e9-f889d062ac1c___JR_B.Spot 3209.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\caa74798-7dab-43f3-8ed0-f53d79cb31db___JR_Sept.L.S 8397.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\2796069c-4173-4395-ae06-0f2de4f3bc6f___YLCV_NREC 2532.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_mosaic_virus\\91247151-4bae-4d55-a35c-edb9318bdb09___PSU_CG 2139.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\e34619bf-28f8-408c-9eda-5975feabaf43___Com.G_TgS_FL 9672.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\dfa62ef3-e71a-49c9-b3fc-6b1c72fa3408___GCREC_Bact.Sp 3176.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\7f790574-ac82-4a3e-9a4d-02cd7762dce2___GHLB2 Leaf 8948.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\ef16608c-6d3f-4974-b478-b45390a1e870___JR_HL 7772.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\0176f68f-a3d8-473b-9bea-c075a5507b34___JR_Sept.L.S 2504.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\002a55fb-7a3d-4a3a-aca8-ce2d5ebc6925___RS_Early.B 8170.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\90fa8cf2-fc80-4944-9484-7cd6bb6cc1da___GCREC_Bact.Sp 5767.JPG',
#  './data/public/PlantVillage\\Tomato_Leaf_Mold\\b7b92cf5-cdc9-4f6b-a844-b5a1d0042230___Crnl_L.Mold 6790.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\4ba45d12-ae1a-4575-880a-b36ee69ec8e9___UF.GRC_YLCV_Lab 03382.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\b4e52186-de58-4c06-bbd2-2fb3dbeda13e___RS_LB 2655.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\7684341d-0c30-4bc4-98c5-e09a96483692___GCREC_Bact.Sp 5695.JPG',
#  './data/public/PlantVillage\\Potato___healthy\\de9a8669-d437-40f0-aa56-fe2d8276a1e0___RS_HL 1910.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\b303761b-5357-4d82-9e78-1b26c2804196___JR_HL 7879.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\7847d3dd-66e7-470f-ab6e-5273c3ee8924___RS_Late.B 4905.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\9430ec1f-c0c4-40ea-9dc1-6821a4c4f84f___YLCV_GCREC 5537.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\efd6193d-7d5b-4207-999d-2aeb08cd64e2___GCREC_Bact.Sp 5739.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\efdf2bd7-ff6c-424a-9d81-dc6628278dc6___RS_HL 0065.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\856076c1-50ec-478d-81a2-4cb3fd26b5af___Com.G_TgS_FL 0750.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\c90fc30f-f9c2-43ed-a912-54ae5bd06f77___JR_HL 8222.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\99af85d7-aac5-46e9-b60e-ef4f6a8e0898___JR_HL 7697.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\ea403e5a-34b3-4b06-a94d-65ad2e78831f___RS_Early.B 8136.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\bc5fd090-21b4-42d8-82b7-354a7697dc22___RS_Late.B 5546.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\73ef196e-eeb9-4fe6-93fe-d7c5d879c455___GHLB2 Leaf 9027.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\28dd4844-6c21-4963-8529-0f4694253e57___YLCV_GCREC 5312.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\0fe7d644-dc8b-49f7-9a41-33ec029f6437___Com.G_TgS_FL 8274.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\1528d8ea-c972-4da3-8f66-b4a0de6ace90___RS_HL 0573.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\e766a563-c87a-4d14-ae00-898ce62e15d4___RS_LB 5123.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\c4791388-b93b-4cad-9ee8-e243c2847f0c___JR_B.Spot 9024.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\61047d59-d93a-4133-92ab-4f2481fa6bed___RS_Erly.B 9533.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\bbe6db0b-868d-4ca4-b8c7-f274b89dd9c8___GHLB2 Leaf 68.1.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\dcccd1d5-958f-4ea9-9d04-a067275f137d___Com.G_TgS_FL 9846.JPG',
#  './data/public/PlantVillage\\Potato___healthy\\bb328d40-e4e6-4b84-a92a-e7cb3922c19d___RS_HL 1829.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\ae99a329-896d-4ff7-82d8-b6431a5255cf___Com.G_TgS_FL 9714.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\e67471bf-2c4e-4957-9ef6-8ff0dfec7ced___Com.G_TgS_FL 0873.JPG',
#  './data/public/PlantVillage\\Potato___healthy\\54f86311-9d76-421b-b401-0b02f6e738a5___RS_HL 4172.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\6ec06fd0-c4c6-4c8d-88f7-b2ff9a2b87c1___JR_HL 8521.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\bf0b58c2-1d95-4f37-80ea-1bcd82e9c59b___GHLB2 Leaf 145.4.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\4bfd707f-94f4-442d-9dfc-8a96b51653d4___JR_B.Spot 3334.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\70ee4f41-ddc6-4626-9a67-44c3a072e509___Matt.S_CG 6680.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\53587f20-0646-4ba9-9124-c2ccbd6e31e6___JR_Sept.L.S 2555.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\a1b90ce3-79b4-404d-a848-4471b793772f___RS_HL 0544.JPG',
#  './data/public/PlantVillage\\Potato___Late_blight\\2377f6d5-3660-4b5a-b5b3-eea448e7a143___RS_LB 2729.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\935376fd-5756-47de-b5b0-da5e0f8283c2___UF.GRC_YLCV_Lab 08560.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\4cf0ee3d-a8b5-47f5-be25-e578d60b6cfd___Matt.S_CG 7373.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\4d035250-f831-438b-a583-d192cbb26a55___JR_B.Spot 3163.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\a0cdaa93-f328-466d-9722-57a29c53e18b___RS_Late.B 7006.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\6e583c78-1f36-4d5e-bc0e-24f3c76a2c1d___RS_HL 0284.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_mosaic_virus\\6804695f-56f8-4ff9-90f8-69ee95097463___PSU_CG 2067.JPG',
#  './data/public/PlantVillage\\Tomato_Leaf_Mold\\0adab1d4-5696-4cd8-8453-3931b70e856d___Crnl_L.Mold 8689.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_mosaic_virus\\2f240e5e-cbb9-406a-98aa-12028411429c___PSU_CG 2123.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\eabeca07-9aa1-431a-92eb-be617775811d___UF.GRC_BS_Lab Leaf 0460.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\098b62a4-f92b-4c0d-9ab9-a6061a9d1625___GCREC_Bact.Sp 2955.JPG',
# ...
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\7d2e7df9-0b0d-49dc-8161-7601f1cdcf5f___JR_Sept.L.S 2552.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\4d20e159-894a-4718-a9f8-e866e7c5a3d9___JR_B.Spot 9025.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\87106385-3a72-45ed-bb0f-8d4e8e1c7aeb___JR_Sept.L.S 8365.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\717a4bbc-52b1-42c1-a718-ca94744ff52d___RS_HL 9726.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\2e129fc6-f9d3-41d3-a562-c69e72871006___Matt.S_CG 0982.JPG',
#  './data/public/PlantVillage\\Potato___healthy\\3edf7c3f-73e0-439c-870d-76cfd7c3bc45___RS_HL 1859.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\eb047146-6e86-44bf-a9b5-f668cb2f301b___GH_HL Leaf 225.1.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\0334d40b-d880-442f-a7db-e5c85a2e0bed___RS_Late.B 6367.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\446f6ec1-1cca-4f62-b5a2-3590ad1b6958___Com.G_SpM_FL 1507.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\98288f42-3067-4117-9e1d-d4a6b88f16eb___RS_Late.B 5545.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\42e607e9-916c-470c-a17d-ec5348a40ded___RS_HL 0373.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\fabba25a-e191-47c5-a468-6acf744312e1___GHLB2 Leaf 8835.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\59fff478-8b46-4b5d-a924-fbe466cd4c95___Matt.S_CG 0961.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\74c531fc-c39c-429c-b285-909272c4238b___RS_Erly.B 9550.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\c311dca2-18ca-4304-b356-a2764d8322d2___Matt.S_CG 7801.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\b3025d7b-862b-4ec3-9724-982a12e305e5___JR_HL 7804.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\4265d731-d90c-42e8-961d-5784472b4e95___JR_HL 7794.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\8e049c5d-6a3b-4972-94e3-057e6cbe3892___NREC_B.Spot 1901.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\3e26a2d8-a7f6-4d3f-bcb7-63ab63b0ff39___JR_HL 8043.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\4507779d-5b5d-4c5d-83d4-8eea46679249___Com.G_SpM_FL 9324.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\63a325a3-94b4-401a-aba8-e902914a6477___Com.G_SpM_FL 1468.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\61fec4ad-9842-40b7-a521-8cad14281b1c___Com.G_SpM_FL 1433.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\30cdd6a0-e7e8-41e1-8cbd-3384d6993f52___UF.GRC_YLCV_Lab 01406.JPG',
#  './data/public/PlantVillage\\Tomato_Leaf_Mold\\b825544a-33a3-4bf7-8568-506acca8eaf5___Crnl_L.Mold 8826.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\e09ba1ab-7952-4b09-a886-0025c4536d7c___Keller.St_CG 1936.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\88e29276-8c4f-4d15-b3d4-d1db0a05cac1___RS_Early.B 6973.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\d42db004-b176-449f-9290-061fb92738d2___RS_Late.B 7139.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\5c51ad21-b0e9-4b61-8980-d5e7a225b594___GH_HL Leaf 485.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\75dd9b0d-dc4d-459a-a209-e94bdaecdc7c___YLCV_NREC 2302.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\4deac08b-8a7b-4929-ade6-17084091a7ba___YLCV_GCREC 2591.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\a5b86c20-323a-42b3-8b1b-60fe21f844b3___JR_HL 8476.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\b2793705-a666-4ba0-ac9f-3b60fc0bbdf4___RS_HL 0342.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\cff6ca5a-84c8-4059-b63d-55127d94b23d___GCREC_Bact.Sp 6100.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\13d71bfc-b33a-42ca-962b-3de4bc7faf9c___Com.G_SpM_FL 1346.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\1cebc4a1-5fb6-4168-8e18-e2973ef6d18f___RS_Erly.B 9552.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\c11a3cf1-de74-421e-89d0-11ea1508673d___RS_HL 0185.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\a8036d3b-eda1-4309-b2ac-5a409963f4d7___RS_HL 9840.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\cd025ad0-9486-4ee6-b545-c9040dc4e1c7___RS_Early.B 8821.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\ae44c6d0-d29c-4f66-9960-40a019bbc838___JR_HL 7779.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\0fee8af3-ca03-418c-a71c-c4fb0a80dc7b___RS_HL 0199.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\225d8d96-41c1-4a03-b02d-0c1ca8c2017a___RS_Late.B 6795.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\b928cffb-f480-44a8-9b09-70ef158fdc7c___JR_B.Spot 3155.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\87de86b2-4720-4841-b014-205bd0084b17___YLCV_NREC 2866.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\c6b57820-5c54-4ee1-841c-07222804c1b7___GCREC_Bact.Sp 6383.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\44dd61ff-4a53-4657-8340-4bd56d8d5dae___JR_B.Spot 8911.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\a57dafc2-4c11-4cd6-8e21-a01d17394753___NREC_B.Spot 9103.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\f1a943c2-373d-43e1-97c4-19458d938bdc___Matt.S_CG 6732.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\1b984071-0529-4e15-9157-0b4b4a214d8f___UF.GRC_YLCV_Lab 08574.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\4cbe4896-66b5-4834-8eb7-5baf49ed2f7d___RS_Erly.B 8354.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\2359d490-4be7-4328-97bf-860b2f78bc19___GCREC_Bact.Sp 6113.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\5e690e70-8511-49a2-8986-4cb7154d9acb___Com.G_TgS_FL 9734.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\e6503dc4-5ab3-427b-9bd7-08c67776352a___Matt.S_CG 6113.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\fe7f0ec0-35b0-49b0-836e-1fa902ee7723___Com.G_SpM_FL 8739.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\c215da6d-139c-40b7-aeae-41138ff98a1c___GHLB2 Leaf 8932.JPG',
#  './data/public/PlantVillage\\Tomato_Leaf_Mold\\201ada31-7b91-42c1-a245-4d37df0b2c52___Crnl_L.Mold 8742.JPG',
#  './data/public/PlantVillage\\Tomato_Leaf_Mold\\eab7f198-a04b-4e25-b329-41e7666d1fde___Crnl_L.Mold 6773.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\4729d4e2-59d3-4f41-b28b-788f9fb20e50___YLCV_GCREC 2754.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\92e2fc60-5e8e-483d-85fd-ec62c11a20a7___UF.GRC_YLCV_Lab 02294.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\9b55aea9-85fc-418b-b1a7-ae919f37d2fc___Com.G_SpM_FL 9401.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\2d07cd71-8088-46c5-9802-dda7a04c2350___UF.GRC_YLCV_Lab 08446.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\1ca23194-53c1-44a9-973a-39aa073f4a33___RS_HL 0058.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\51f50834-78d5-412f-bb47-58bcf0723da0___UF.GRC_YLCV_Lab 02874.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\c6d62e0c-15e0-4e99-8dbd-40e8f7181131___RS_HL 9954.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\c3fbdba4-a285-463b-a3fd-26d0d4a4d936___GCREC_Bact.Sp 3677.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\21c8de33-5db5-4cd9-8f69-c424c0b63414___Com.G_TgS_FL 9888.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\ed76421e-84e4-408b-a1b3-c6164867b3d2___RS_HL 0560.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\8f7f2459-7493-416d-af69-200d1eeb07fa___YLCV_NREC 2082.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\473578ed-99da-4f7f-9eff-25b067e6c761___Com.G_SpM_FL 1545.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\8295d0d3-a2b8-4f32-ac02-7e0ee8f75406___NREC_B.Spot 1790.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\a63b93a4-167f-4544-9a84-1e0d05bf35f6___Matt.S_CG 7623.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\630ae481-49e7-470c-ad05-177132a6648a___RS_HL 0178.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\da412bf6-6bee-4dfb-8bc7-b6e9f80971ff___RS_Early.B 6808.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\0bb186a0-f27a-41b1-b0d2-5cf82eb87251___Com.G_SpM_FL 9018.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\7d9d7a78-4578-4722-9f1f-3c837f0bd3fd___YLCV_GCREC 1945.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_mosaic_virus\\97465c93-52c3-4df9-a820-de9ae6f4d03e___PSU_CG 2232.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\a60106e3-e037-495f-8b5a-080adcb9bdd9___RS_Early.B 8561.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\b023b89b-4115-4c7d-9ae1-02a1201c7ff3___Matt.S_CG 6223.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\3d73d31e-6513-4b4e-90ba-81a0648195f2___YLCV_GCREC 2695.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\73e493c6-3149-451d-b4e4-39aa10d02113___RS_Late.B 6642.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\fe416307-5c50-4c9f-96b5-f6e15ef79045___RS_Late.B 4975.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_mosaic_virus\\9916341f-9dd9-498f-b553-476d9f2d722e___PSU_CG 2087.JPG',
#  './data/public/PlantVillage\\Tomato_Leaf_Mold\\9f25030c-39e2-4a62-a586-40e3c26f60bb___Crnl_L.Mold 6657.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\06b911b8-1375-4da1-929c-2294c4051ece___GHLB2 Leaf 8883.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\06ae69f3-53f7-4ad8-b6b0-185dd26b2fc0___JR_HL 7971.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\092b3e29-d29a-482f-9207-3cd5fbed6710___JR_B.Spot 3238.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\47ce6359-5a16-46ea-bdeb-44a795edd402___UF.GRC_YLCV_Lab 03058.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\66779f6e-2eb3-4bd5-82c1-e00bab5b3b9b___RS_Erly.B 7374.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\8cf12f2f-30db-4019-9efd-6eabed9713f7___YLCV_NREC 2280.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\34d2260c-888c-419c-b32c-938efa379b97___RS_Early.B 8253.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\558ac60b-4d33-4c66-b5af-2568d5edd474___UF.GRC_YLCV_Lab 02151.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\d85bb844-caf7-4858-93e8-74becbd7dbd8___JR_HL 5926.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\2e1daff5-2bc2-4c45-8563-7c6a7a929ddf___Com.G_SpM_FL 9261.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\016bbee4-7b9d-40c8-a802-2bbf00f3bb27___YLCV_NREC 2290.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\a45cff7d-8ae1-4de9-8479-cb0d2dfc6b0f___RS_HL 9863.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\966393c2-cef5-4fe7-b6e2-e6f6b7cfac0a___UF.GRC_YLCV_Lab 01569.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\a2317e6a-8548-432c-b69f-0f6daada41fa___GH_HL Leaf 469.1.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\c0cc5199-5c3e-4bf1-acb5-3b38d26a3938___JR_HL 8781.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\c6eee071-b1e6-4237-9a0a-8f49e4665dc4___GCREC_Bact.Sp 3185.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\6c6d960d-50e1-45ca-adb4-fc9b8218b698___UF.GRC_YLCV_Lab 02722.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\25e772ed-0fc2-437d-b573-5edd92bf441e___Com.G_SpM_FL 8559.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\20d823a4-0be3-4b8a-acdc-6efd1236e7f0___GH_HL Leaf 254.2.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\15fedefd-8147-4e84-9706-0d4cc084d1ef___UF.GRC_YLCV_Lab 02253.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\eeb59903-65af-4d9f-9ab9-ec6725aa3a39___JR_B.Spot 3359.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\ec658169-804d-46eb-b014-30a3ce6abdb6___GHLB2 Leaf 8899.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\5999b12b-b580-486a-a50f-fcdf44d59b71___GCREC_Bact.Sp 6306.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\215565cf-2897-40f6-97b3-3dd63045242f___GHLB2 Leaf 8800.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\c32b4ac0-1b2c-4f26-9cb7-ba400bc2614e___GCREC_Bact.Sp 3385.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\fb798dfa-5365-4180-b4ce-e46ce5aa9de7___Com.G_SpM_FL 9034.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\497e7ecf-8350-4490-9946-b6e55f90d382___Com.G_SpM_FL 1423.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\c7f91fa4-3769-45ef-a494-1669ee62ee7a___RS_HL 9812.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\1666ae7f-31f9-4faf-8b60-40a1ded014ea___YLCV_GCREC 2236.JPG',
#  './data/public/PlantVillage\\Tomato_healthy\\6b53630d-c9df-4e67-a490-b1835772d9a0___GH_HL Leaf 450.2.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\4eee40c4-029f-49eb-a918-1aeee490ccdf___JR_HL 8401.JPG',
#  './data/public/PlantVillage\\Tomato__Target_Spot\\c4abfbdb-e929-465f-a34a-b42e6f308840___Com.G_TgS_FL 7919.JPG',
#  './data/public/PlantVillage\\Tomato_Early_blight\\ca7035fa-f55d-49c7-9d89-3d513c8e35b1___RS_Erly.B 7556.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\03d8267a-c675-439f-9b98-a9c7653dd05e___GHLB2 Leaf 8558.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\3002c053-70f2-45e8-88b7-3507f07bb377___YLCV_NREC 2404.JPG',
#  './data/public/PlantVillage\\Tomato_Bacterial_spot\\e4be767a-e84a-4fd6-9049-ed4ff05962ac___GCREC_Bact.Sp 3678.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\8bf5c35c-1a3a-47cf-97dd-245b5105afb4___NREC_B.Spot 1879.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\433c68d1-9786-48a5-94a2-7dcfea91c5b6___JR_HL 8159.JPG',
#  './data/public/PlantVillage\\Pepper__bell___healthy\\4531baee-70c8-4504-82f1-5cb38c857928___JR_HL 8710.JPG',
#  './data/public/PlantVillage\\Tomato_Spider_mites_Two_spotted_spider_mite\\3b5769b2-b497-47de-9992-bc328452b1ee___Com.G_SpM_FL 8824.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\988d5328-da67-4872-9db0-baff075a432f___JR_Sept.L.S 2586.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\f2b26169-0854-4c81-8d40-814c4d5f40b6___Matt.S_CG 7542.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\236f8177-89aa-4c6c-8cf2-0b0644b3fcfa___UF.GRC_YLCV_Lab 02012.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\1eac2879-1201-4d11-8652-547787cff379___YLCV_GCREC 5357.JPG',
#  './data/public/PlantVillage\\Tomato_Late_blight\\a0fe466c-9953-4458-9621-65377e474227___RS_Late.B 6973.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\4a06db68-bed1-4ae6-80ba-e9df70fa6f7b___RS_Early.B 8657.JPG',
#  './data/public/PlantVillage\\Pepper__bell___Bacterial_spot\\9d26dd65-36c0-4ff0-a1b8-5e6e7ea5e058___JR_B.Spot 8991.JPG',
#  './data/public/PlantVillage\\Potato___Early_blight\\d8efc91f-6e85-4508-8d49-9c4a11c4c71a___RS_Early.B 7484.JPG',
#  './data/public/PlantVillage\\Tomato_Septoria_leaf_spot\\abd969f8-a573-4b5d-b5f2-32f33e6b1374___JR_Sept.L.S 8559.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\0d4d2931-d063-4f29-8190-9c624e42f561___YLCV_NREC 2649.JPG',
#  './data/public/PlantVillage\\Tomato__Tomato_YellowLeaf__Curl_Virus\\8ac16bec-8484-499f-a86d-fbc6bcbe1c29___UF.GRC_YLCV_Lab 08539.JPG',
#  './data/public/PlantVillage\\Potato___healthy\\03da9931-e514-4cc7-b04a-8f474a133ce5___RS_HL 1830.JPG',
#  ...]

# %% [markdown]
# # DataLoader w/ kfold

# %%
img_list = glob('./data/public/PlantVillage/*/*.JPG')
label_list = [label_decoder[img_path.split('\\')[-2]] for img_path in img_list]

kfold = StratifiedKFold(n_splits=4, random_state=13, shuffle=True)
for idx, (kfold_train, kfold_val) in enumerate(kfold.split(img_list, label_list), 1) :
    print(idx, len(kfold_train), len(kfold_val))
    print(kfold_train)
    print(kfold_val)
# Out:
# 1 15477 5159
# [    1     2     3 ... 20632 20634 20635]
# [    0    16    25 ... 20616 20630 20633]
# 2 15477 5159
# [    0     1     3 ... 20633 20634 20635]
# [    2     5    10 ... 20615 20617 20625]
# 3 15477 5159
# [    0     1     2 ... 20633 20634 20635]
# [    6    12    14 ... 20610 20622 20632]
# 4 15477 5159
# [    0     2     5 ... 20630 20632 20633]
# [    1     3     4 ... 20631 20634 20635]

# %% [markdown]
# # Plant Doc

# %% [markdown]
# ### image 이름에 , 있는거 제거

# %%
with open('./data/public/PlantDoc/train/_classes.txt', 'r') as f :
    classese = f.readlines()

before_name = []
modi_name = []
for i in range(1, len(classese)) :
    if ',' in classese[i].split(', ')[0] :
        split_name = classese[i].split(', ')
        before_name.append(split_name[0])
        modi_name.append(split_name[0].replace(',',''))
        
        classese[i] = classese[i].replace(before_name[-1], modi_name[-1])
        print(before_name[-1])
# Out:
# flat,1000x1000,075,f_u2_jpg.rf.66e349ed247b0dabe796bf7bc4821505.jpg
# 8_--Virus-Damaged-foliage-at-top-versus-healthy,-non-infected-bottom-foliage_jpg.rf.b88f190e1dc2af80677face44a88c31f.jpg
# autumn,+blueberry+leaves_jpg.rf.e4e581e9845ac2581d4395de63e617e0.jpg

# %% [markdown]
# ### 새로운 label txt 파일 생성

# %%
with open('./data/public/PlantDoc/train/_modi_classes.txt', 'w') as f :
    for data ina classese:
        f.write(data)

# %% [markdown]
# ### image 이름도 변경해주기

# %%
root_path = './data/public/PlantDoc/train'
img_list = glob(root_path+'/*.JPG')

for i in range(0, len(before_name)) :
    before_index = img_list.index(root_path+'\\'+before_name[i])
    img_list[before_index] = root_path+'\\'+modi_name[i]
    print(root_path+'\\'+before_name[i])
    print(root_path+'\\'+modi_name[i])
    print()
    os.rename(root_path+'\\'+before_name[i], root_path+'\\'+modi_name[i])
# Out:
# ./data/public/PlantDoc/train\flat,1000x1000,075,f_u2_jpg.rf.66e349ed247b0dabe796bf7bc4821505.jpg
# ./data/public/PlantDoc/train\flat1000x1000075f_u2_jpg.rf.66e349ed247b0dabe796bf7bc4821505.jpg
#
# ./data/public/PlantDoc/train\8_--Virus-Damaged-foliage-at-top-versus-healthy,-non-infected-bottom-foliage_jpg.rf.b88f190e1dc2af80677face44a88c31f.jpg
# ./data/public/PlantDoc/train\8_--Virus-Damaged-foliage-at-top-versus-healthy-non-infected-bottom-foliage_jpg.rf.b88f190e1dc2af80677face44a88c31f.jpg
#
# ./data/public/PlantDoc/train\autumn,+blueberry+leaves_jpg.rf.e4e581e9845ac2581d4395de63e617e0.jpg
# ./data/public/PlantDoc/train\autumn+blueberry+leaves_jpg.rf.e4e581e9845ac2581d4395de63e617e0.jpg

# %% [markdown]
# # data list 만들기
# - none, 12, 17, 28번 클래스 삭제

# %%
import pandas as pd

label_csv = pd.read_csv('./data/public/PlantDoc/train/_modi_classes.txt')
columns_name = list(label_csv.columns)
columns_name.remove('filename')
columns_name.insert(0, 'None')

label_encoder = {idx : val.lstrip() for idx, val in enumerate(columns_name)}
label_decoder = {val : key for key, val in label_encoder.items()}
display(label_encoder)
display(label_decoder)
# Out:
# {0: 'None',
#  1: 'Apple Scab Leaf',
#  2: 'Apple leaf',
#  3: 'Apple rust leaf',
#  4: 'Bell_pepper leaf',
#  5: 'Bell_pepper leaf spot',
#  6: 'Blueberry leaf',
#  7: 'Cherry leaf',
#  8: 'Corn Gray leaf spot',
#  9: 'Corn leaf blight',
#  10: 'Corn rust leaf',
#  11: 'Peach leaf',
#  12: 'Potato leaf',
#  13: 'Potato leaf early blight',
#  14: 'Potato leaf late blight',
#  15: 'Raspberry leaf',
#  16: 'Soyabean leaf',
#  17: 'Soybean leaf',
#  18: 'Squash Powdery mildew leaf',
#  19: 'Strawberry leaf',
#  20: 'Tomato Early blight leaf',
#  21: 'Tomato Septoria leaf spot',
#  22: 'Tomato leaf',
#  23: 'Tomato leaf bacterial spot',
#  24: 'Tomato leaf late blight',
#  25: 'Tomato leaf mosaic virus',
#  26: 'Tomato leaf yellow virus',
#  27: 'Tomato mold leaf',
#  28: 'Tomato two spotted spider mites leaf',
#  29: 'grape leaf',
#  30: 'grape leaf black rot'}
# {'None': 0,
#  'Apple Scab Leaf': 1,
#  'Apple leaf': 2,
#  'Apple rust leaf': 3,
#  'Bell_pepper leaf': 4,
#  'Bell_pepper leaf spot': 5,
#  'Blueberry leaf': 6,
#  'Cherry leaf': 7,
#  'Corn Gray leaf spot': 8,
#  'Corn leaf blight': 9,
#  'Corn rust leaf': 10,
#  'Peach leaf': 11,
#  'Potato leaf': 12,
#  'Potato leaf early blight': 13,
#  'Potato leaf late blight': 14,
#  'Raspberry leaf': 15,
#  'Soyabean leaf': 16,
#  'Soybean leaf': 17,
#  'Squash Powdery mildew leaf': 18,
#  'Strawberry leaf': 19,
#  'Tomato Early blight leaf': 20,
#  'Tomato Septoria leaf spot': 21,
#  'Tomato leaf': 22,
#  'Tomato leaf bacterial spot': 23,
#  'Tomato leaf late blight': 24,
#  'Tomato leaf mosaic virus': 25,
#  'Tomato leaf yellow virus': 26,
#  'Tomato mold leaf': 27,
#  'Tomato two spotted spider mites leaf': 28,
#  'grape leaf': 29,
#  'grape leaf black rot': 30}

# %%
root_path = './data/public/PlantDoc/train'

with open('./data/public/PlantDoc/train/_modi_classes.txt', 'r') as f :
    classese = f.readlines()

label_list = []
img_list = []
for i in range(1, len(classese)) :
    img_list.append(root_path + '/' + classese[i].split(', ')[0])
    if '1' in classese[i].split(', ') :
        label_list.append(classese[i].split(', ').index('1'))
    elif '1\n' in classese[i].split(', ') :
        label_list.append(classese[i].split(', ').index('1\n'))
    else : 
        label_list.append(0)

print(img_list)
print(label_list)
# Out:
# ['./data/public/PlantDoc/train/2017-08-27%2B-%2BLate%2BBlight%2Bon%2BGypsy%2B1_jpg.rf.00584c9d14b6fda3086f9a482675d610.jpg', './data/public/PlantDoc/train/Slide1_preview_jpg.rf.00f57cfc188631c10e10e2b93a38d296.jpg', './data/public/PlantDoc/train/d-to-tylv-fo005-14496A31BE70553130A_jpg.rf.017e4558f1b4baeadc32a13beb178a6e.jpg', './data/public/PlantDoc/train/2-3%20Gray%20leaf%20spot%20BRUCE_jpg.rf.0040c2e382cf11216938e6f49b7d65ed.jpg', './data/public/PlantDoc/train/blueberry-leaf-isolated-white-background-blueberry-leaf-isolated-99227523_jpg.rf.00a825930e9396a34d6c3fc5cf86686e.jpg', './data/public/PlantDoc/train/Apple-Scab-image-02_jpg.rf.00cbc9a108dbdaadf4232b5392e3d3c8.jpg', './data/public/PlantDoc/train/Faske%20Southern%20rust%20of%20corn_jpg.rf.016116db58617610bb259b2965f41589.jpg', './data/public/PlantDoc/train/14456_img_jpg.rf.0052b88d849e614c6037a2834800b4f8.jpg', './data/public/PlantDoc/train/24154194959_fd4b42edde_b_jpg.rf.0012f9978a300c5635840700fa784280.jpg', './data/public/PlantDoc/train/Septoria_tomato_Margaret%20B_p8170755_0002_25004_jpg.rf.00ddfef2668a53da256f207f9b844782.jpg', './data/public/PlantDoc/train/DCDl_p8UQAAf2hP_jpg.rf.0192cb81cdbb3365925d7d47527de47a.jpg', './data/public/PlantDoc/train/IMG_6029-001_1500x1500%253E_JPG?1403119544_jpg.rf.01aae68643601f970bad558834c627ae.jpg', './data/public/PlantDoc/train/4-dogwood_pm_jpg.rf.01ee1d6e0173e000acb9da01ba1e3ec3.jpg', './data/public/PlantDoc/train/NCLB6_jpg.rf.0200119534bc7ca383dccb23486a52e3.jpg', './data/public/PlantDoc/train/IMG_1495_JPG_jpg.rf.021c4146d446c07d8c9b8a15761e7745.jpg', './data/public/PlantDoc/train/Bacterial-spot-symptoms-on-pepper-leaves-for-web_jpg.rf.01bc16f3b7ba0e4c9fa8c07133a723c6.jpg', './data/public/PlantDoc/train/schurft_jpg.rf.025af8f92e8ba3726ee840cfb0fffaa6.jpg', './data/public/PlantDoc/train/0061_jpg.rf.01edf4541c53b5b4015bef2add16f44e.jpg', './data/public/PlantDoc/train/patarea-bacteriana-frunzelor-pseudomonas-syringae-maculicola-31_5_2_jpg.rf.028446c5ca2dc9d7919136b4bd3a37d2.jpg', './data/public/PlantDoc/train/CedarApple_Rust168_jpg.rf.029e923c287e430d3cdef96e8dee4a23.jpg', './data/public/PlantDoc/train/Raspberry-leaf-tea-benefits-_-Ayurvedum_jpg.rf.02d626c0428c0f70fe18b49d62ae4894.jpg', './data/public/PlantDoc/train/tomato-fern-leaf-a-symptom-of-tmv-cmv-or-pepmv-virus-on-tomato-plants-h6ey8w_jpg.rf.0350555c7012adc0c86110c64d6ec47f.jpg', './data/public/PlantDoc/train/gosswilt_TMB_jpg.rf.0340e162a37ba15a6677383eca5cf8ee.jpg', './data/public/PlantDoc/train/4-lagenaria_pdic_jpg.rf.0378d7e8bafd23143dac53b33f6d5dd7.jpg', './data/public/PlantDoc/train/Late-Blight-56a34bc55f9b58b7d0d15210_jpg.rf.034b4a46ee6c29d40c358a6b3b6ea22d.jpg', './data/public/PlantDoc/train/pmild1_600px_jpg.rf.02cf41534eae5ae3e33f781ca5a49ea2.jpg', './data/public/PlantDoc/train/swcdg1_jpg.rf.0296e44905b83227da0ba4c4802b064d.jpg', './data/public/PlantDoc/train/p1020083cs_jpg.rf.0370cefd157bce00b6efa11e6bda28bf.jpg', './data/public/PlantDoc/train/1-495x400_jpg.rf.0395dff564e873b90d47357769fa3be6.jpg', './data/public/PlantDoc/train/early-blight-2_jpg.rf.039db07103b9acff11f0652ffe168822.jpg', './data/public/PlantDoc/train/Potato-late-blight-in-field-trial-1_jpg.rf.03e2595e4c36970491ffba21a0c32e34.jpg', './data/public/PlantDoc/train/Diseased-Tomato-Plant_jpg.rf.03a5120fdf3c584299491af9cb370f41.jpg', './data/public/PlantDoc/train/6078710516023296-600x272_jpeg_jpg.rf.041b27d54693e05601dd53330c4fb4fa.jpg', './data/public/PlantDoc/train/early-blight-pp-labeled_orig_jpg.rf.0466436b85b9dbe64c8b52a93678cfa4.jpg', './data/public/PlantDoc/train/late-blight-tom-leaf_jpg.rf.04528305189eaf32cb239271df302efe.jpg', './data/public/PlantDoc/train/366_jpg.rf.047988ae818af9e93f704866e8dad5e2.jpg', './data/public/PlantDoc/train/ac-0018_pdf-2_2_jpg.rf.044964ac83324535fd56bd0a05363b2e.jpg', './data/public/PlantDoc/train/Soy-leaves-FAZ050-2015US-IL-Wuerffel-USNQ0F002-28DAB-Plot106b_jpg.rf.047e2295ab011ef91b18b6f5da71b839.jpg', './data/public/PlantDoc/train/appscab_jpg.rf.047c1b71d1050ca9b1bf ...
# [24, 9, 27, 9, 6, 1, 10, 26, 9, 21, 30, 5, 5, 9, 4, 5, 1, 13, 23, 3, 15, 25, 9, 18, 14, 18, 9, 20, 9, 13, 14, 20, 21, 20, 24, 11, 17, 16, 1, 8, 15, 26, 27, 18, 23, 15, 20, 2, 18, 6, 24, 10, 18, 3, 19, 18, 11, 26, 11, 27, 13, 1, 7, 3, 2, 15, 26, 14, 19, 21, 13, 20, 14, 25, 15, 23, 26, 24, 25, 6, 11, 6, 2, 1, 15, 15, 1, 14, 6, 10, 15, 14, 18, 16, 14, 2, 6, 21, 26, 13, 15, 22, 16, 13, 21, 13, 18, 21, 25, 19, 16, 21, 21, 6, 24, 16, 9, 9, 9, 3, 26, 18, 11, 13, 30, 13, 10, 9, 6, 11, 8, 21, 5, 23, 2, 15, 24, 26, 30, 24, 18, 4, 27, 14, 26, 7, 6, 13, 9, 18, 6, 0, 26, 2, 9, 27, 8, 14, 27, 1, 18, 27, 15, 7, 20, 13, 6, 9, 23, 18, 21, 13, 20, 9, 1, 13, 30, 6, 23, 16, 10, 30, 25, 18, 1, 26, 6, 25, 8, 6, 6, 23, 16, 3, 6, 20, 23, 5, 19, 29, 30, 1, 19, 18, 5, 29, 26, 2, 27, 9, 1, 5, 1, 9, 1, 26, 18, 23, 21, 22, 19, 23, 24, 19, 11, 9, 24, 8, 19, 30, 23, 9, 6, 19, 2, 20, 7, 20, 29, 11, 5, 9, 9, 19, 6, 3, 14, 20, 27, 26, 15, 9, 2, 24, 5, 2, 24, 2, 14, 20, 21, 21, 14, 4, 19, 10, 10, 8, 27, 24, 21, 3, 15, 9, 29, 14, 4, 10, 9, 13, 2, 24, 26, 6, 10, 22, 30, 8, 20, 18, 24, 30, 4, 18, 14, 23, 18, 20, 13, 1, 27, 3, 11, 9, 23, 6, 15, 3, 4, 27, 1, 3, 27, 2, 8, 10, 10, 15, 18, 23, 2, 10, 3, 11, 0, 20, 1, 16, 1, 2, 16, 23, 10, 7, 23, 5, 15, 13, 1, 10, 29, 13, 14, 18, 2, 30, 9, 19, 5, 1, 19, 10, 21, 21, 5, 30, 3, 3, 2, 30, 30, 13, 23, 16, 16, 10, 6, 21, 16, 5, 13, 27, 20, 19, 22, 1, 23, 6, 10, 23, 16, 2, 23, 23, 13, 18, 27, 19, 23, 6, 27, 7, 20, 23, 9, 15, 27, 10, 2, 6, 18, 14, 9, 29, 9, 23, 21, 24, 20, 22, 11, 14, 6, 21, 19, 0, 21, 30, 15, 20, 10, 5, 30, 24, 18, 24, 22, 11, 10, 18, 24, 11, 21, 21, 18, 1, 9, 19, 13, 9, 29, 18, 1, 29, 2, 11, 13, 25, 13, 10, 30, 18, 14, 1, 18, 11, 11, 21, 14, 23, 20, 15, 15, 11, 7, 24, 11, 11, 27, 9, 4, 15, 9, 18, 24, 5, 15, 10, 19, 1, 15, 18, 23, 3, 2, 19, 9, 14, 11, 14, 8, 6, 6, 9, 22, 5, 4, 2, 24, 19, 26, 18, 26, 15, 7, 22, 24, 15, 10, 21, 13, 4, 1, 1, 10, 2, 15, 4, 15, 30, 27, 24, 8, 21, 8, 26, 18, 29, 7, 22, 2, 27, 21, 11, 30, 1, 11, 26, 24, 18, 11, 9, 18, 6, 10, 13, 24, 15, 9, 20, 24, 21, 10, 9, 23, 16, 6, 14, 14, 20, 13, 23, 19, 21, 26, 13, 27, 26, 29, 11, 19, 29, 20, 19, 9, 13, 24, 6, 16, 14, 4, 26, 2, 18, 15, 5, 7, 8, 18, 7, 10, 13, 2, 21, 22, 13, 18, 21, 24, 13, 1, 1, 24, 24, 29, 27, 24, 9, 13, 15, 4, 23, 24, 8, 24, 18, 19, 20, 21, 30, 18, 29, 23, 13, 9, 14, 23, 10, 11, 22, 15, 4, 22, 13, 2, 8, 21, 1, 9, 2, 10, 23, 21, 7, 30, 23, 16, 3, 21, 4, 11, 30, 2, 27, 13, 6, 23, 9, 22, 1, 26, 1, 11, 3, 11, 22, 9, 1, 1, 10, 24, 26, 3, 8, 7, 6, 24, 9, 4, 13, 9, 23, 13, 19, 9, 13, 11, 10, 20, 13, 11, 21, 2, 2, 15, 23, 10, 3, 9, 9, 4, 23, 23, 20, 19, 10, 10, 1, 18, 4, 5, 11, 3, 19, 5, 30, 26, 21, 9, 4, 10, 26, 7, 25, 20, 30, 19, 8, 19, 21, 9, 7, 3, 11, 9, 1, 9, 18, 30, 26, 27, 30, 22, 11, 1, 21, 27, 15, 21, 29, 19, 23, 16, 6, 15, 13, 14, 3, 3, 5, 14, 24, 2, 13, 30, 9, 19, 29, 20, 9, 26, 4, 2, 30, 11, 20, 26, 9, 19, 27, 21, 22, 4, 2, 21, 22, 15, 24, 22, 24, 4, 24, 10, 13, 14, 18, 14, 1, 27, 22, 9, 23, 9, 14, 2, 21, 9, 9, 6, 5, 15, 10, 6, 6, 4, 24, 13, 9, 27, 2, 13, 8, 18, 9, 1, 25, 6, 0, 15, 11, 16, 21, 9, 9, 21, 19, 1, 24, 19, 8, 3, 6, 11, 30, 13, 6, 26, 9, 23, 10, 1, 10, 16, 18, 16, 25, 1, 22, 1, 19, 9, 22, 24, 16, 20, 22, 21, 23, 8, 21, 3, 14, 16, 19, 5, 11, 21, 3, 13, 6, 27, 21, 8, 2, 5, 24, 5, 23, 1, 8, 29, 23, 10, 13, 2, 8, 27, 25, 13, 14, 10, 6, 21, 30, 3, 15, 27, 14, 11, 3, 15, 11, 29, 23, 14, 14, 25, 15, 30, 18, 10, 9, 30, 2, 23, 25, 9, 15, 1, 23, 10, 27, 1, 9, 2, 19, 29, 14, 14, 6, 22, 5, 21, 15, 2, 15, 19, 22, 20, 14, 11, 18, 25, 22, 10, 18, 20, 6, 20, 13, 3, 5, 9, 1, 22, 4, 7, 9, 6, 11, 25, 6, 2, 6, 21, 22, 29, 21, 7, 5, 1, 29, 9, 3, 10, 21, 18, 3, 4, 30, 2, 29, 4, 11, 21, 14, 0, 1, 5, 10, 18, 14, 15, 20, 21, 13, 15, 18, 4, 27, 18, 21, 24, 21, 6, 18, 3, 13, 21, 15, 24, 26, 9, 11, 13, 9, 18, 9, 21, 21, 16, 18, 7, 11, 7, 5, 27, 20, 8, 9, 9, 10, 2, 23, 21, 22, 16, 5, 21, 11, 16, 27, 8, 9, 16, 22, 26, 18, 9, 3, 23, 9, 30, 3, 20, 6, 9, 18, 3, 15, 21, 25, 2, 13, 9, 21, 6, 7, 2, 15, 2, 11, 14, 27, 11, 21, 9, 8, 10, 6, 21, 15,  ...

# %% [markdown]
# # class 별 갯수
# - 10개 이하 class는 삭제 해줌
# - 삭제해야할 label - 0, 12, 17, 28

# %%
root_path = './data/public/PlantDoc/train'

with open('./data/public/PlantDoc/train/_modi_classes.txt', 'r') as f :
    classese = f.readlines()

label_list = []
img_list = []
for i in range(1, len(classese)) :
    img_list.append(root_path + '/' + classese[i].split(', ')[0])
    if '1' in classese[i].split(', ') :
        label_list.append(classese[i].split(', ').index('1'))
    elif '1\n' in classese[i].split(', ') :
        label_list.append(classese[i].split(', ').index('1\n'))
    else : 
        label_list.append(0)
label_cnt = {k : 0 for k, v in label_decoder.items()}

for i in label_list :
    label_cnt[label_encoder[i]] += 1

display(label_cnt)
# Out:
# {'None': 10,
#  'Apple Scab Leaf': 83,
#  'Apple leaf': 82,
#  'Apple rust leaf': 78,
#  'Bell_pepper leaf': 53,
#  'Bell_pepper leaf spot': 62,
#  'Blueberry leaf': 103,
#  'Cherry leaf': 47,
#  'Corn Gray leaf spot': 61,
#  'Corn leaf blight': 178,
#  'Corn rust leaf': 106,
#  'Peach leaf': 101,
#  'Potato leaf': 3,
#  'Potato leaf early blight': 103,
#  'Potato leaf late blight': 94,
#  'Raspberry leaf': 112,
#  'Soyabean leaf': 57,
#  'Soybean leaf': 1,
#  'Squash Powdery mildew leaf': 124,
#  'Strawberry leaf': 87,
#  'Tomato Early blight leaf': 79,
#  'Tomato Septoria leaf spot': 137,
#  'Tomato leaf': 56,
#  'Tomato leaf bacterial spot': 101,
#  'Tomato leaf late blight': 99,
#  'Tomato leaf mosaic virus': 44,
#  'Tomato leaf yellow virus': 68,
#  'Tomato mold leaf': 86,
#  'Tomato two spotted spider mites leaf': 0,
#  'grape leaf': 57,
#  'grape leaf black rot': 56}

# %% [markdown]
# ### class 삭제

# %%
label_cnt_ = {label_decoder[k] : v for k, v in label_cnt.items()}
display(label_cnt_)
remove_list = []
for k, v in label_cnt_.items() :
    for i in range(0, len(label_list)) :
        if label_list[i] == k and v <= 10 :
            remove_list.append(i)
            print(label_list[i])
            print(img_list[i])
            
display(remove_list)
remove_list.sort(reverse=True)
display(remove_list)

print(len(img_list))
print(len(label_list))
for remove_num in remove_list :
    del img_list[remove_num]
    del label_list[remove_num]

print(len(img_list))
print(len(label_list))


### 0, 12, 17, 28 삭제해야할 label
# Out:
# {0: 10,
#  1: 83,
#  2: 82,
#  3: 78,
#  4: 53,
#  5: 62,
#  6: 103,
#  7: 47,
#  8: 61,
#  9: 178,
#  10: 106,
#  11: 101,
#  12: 3,
#  13: 103,
#  14: 94,
#  15: 112,
#  16: 57,
#  17: 1,
#  18: 124,
#  19: 87,
#  20: 79,
#  21: 137,
#  22: 56,
#  23: 101,
#  24: 99,
#  25: 44,
#  26: 68,
#  27: 86,
#  28: 0,
#  29: 57,
#  30: 56}
# 0
# ./data/public/PlantDoc/train/270412tglr-wild-strawberry-flowers-and-leaf-patch_jpg.rf.11e3d6fa8e0828ac716e6e40f92ebd6b.jpg
# 0
# ./data/public/PlantDoc/train/Hydrangea+%2527Claudie%2527%252C+Powdery+Mildew_JPG_jpg.rf.241a2ba81fae4dd8f4d42a639bf4c542.jpg
# 0
# ./data/public/PlantDoc/train/tomato_D4a-TobRingspotVirus-1000077_zoom_jpg.rf.2e3bf56fca79319caad79756a5a3489f.jpg
# 0
# ./data/public/PlantDoc/train/Downy%20mildew_JPG_jpg.rf.5cd0d81448f536b690c687fe43801ad8.jpg
# 0
# ./data/public/PlantDoc/train/raspberries_jpg.rf.6f265fc0cc6e20357544cda8c1e08794.jpg
# 0
# ./data/public/PlantDoc/train/powdery-mildew-erysiphe-plantani-on-young-sycamore-leaf-b372wn_jpg.rf.9f2fd157b98d7080ee62fda831e913e9.jpg
# 0
# ./data/public/PlantDoc/train/Black+Raspberry+Leaves+3_jpg.rf.a5118930e06e0d086213803cfdda04b3.jpg
# 0
# ./data/public/PlantDoc/train/raspberry-db_jpg.rf.b3eabfd7a40d314ed0bd68e867f3bf6b.jpg
# 0
# ./data/public/PlantDoc/train/aquilegia-powdery-mildew-erysiphe-aquilegiae-on-columbine-leaves-bga5xr_jpg.rf.bd049474ad6eb0ee96506e9b2a2771ac.jpg
# 0
# ./data/public/PlantDoc/train/pm1_600px_jpg.rf.cd599fa610030885978e3f8741b8eba8.jpg
# 12
# ./data/public/PlantDoc/train/1200px-Late_blight_on_potato_leaf_2_jpg.rf.a251ceac978237a73cd76afaf2d54761.jpg
# 12
# ./data/public/PlantDoc/train/0042241_jpg.rf.bcaadbb721fdeb7e52d0638843eeda75.jpg
# 12
# ./data/public/PlantDoc/train/21-late%20blight-early%20symptoms%20potato_jpg.rf.d2edfe558f9d078bb2e78524d0fea1b3.jpg
# 17
# ./data/public/PlantDoc/train/ac-0018_pdf-2_2_jpg.rf.044964ac83324535fd56bd0a05363b2e.jpg
# [151, 324, 415, 827, 996, 1433, 1500, 1629, 1717, 1847, 1471, 1706, 1916, 36]
# [1916, 1847, 1717, 1706, 1629, 1500, 1471, 1433, 996, 827, 415, 324, 151, 36]
# 2328
# 2328
# 2314
# 2314

# %% [markdown]
# ### 삭제된 라벨만큼 라벨 번호 당기기

# %%
for i in range(0, len(label_list)) :
    print(label_list[i])
    if label_list[i] > 0 and label_list[i] < 12 :
        label_list[i] -= 1
    elif label_list[i] > 12 and label_list[i] < 17 :
        label_list[i] -= 2
    elif label_list[i] > 17 and label_list[i] < 28 :
        label_list[i] -= 3
    elif label_list[i] > 28 :
        label_list[i] -= 4
    print(label_list[i])
    print()
# Out:
# 24
# 21
#
# 9
# 8
#
# 27
# 24
#
# 9
# 8
#
# 6
# 5
#
# 1
# 0
#
# 10
# 9
#
# 26
# 23
#
# 9
# 8
#
# 21
# 18
#
# 30
# 26
#
# 5
# 4
#
# 5
# 4
#
# 9
# 8
#
# 4
# 3
#
# 5
# 4
#
# 1
# 0
#
# 13
# 11
#
# 23
# 20
#
# 3
# 2
#
# 15
# 13
#
# 25
# 22
#
# 9
# 8
#
# 18
# 15
#
# 14
# 12
#
# 18
# 15
#
# 9
# 8
#
# 20
# 17
#
# 9
# 8
#
# 13
# 11
#
# 14
# 12
#
# 20
# 17
#
# 21
# 18
#
# 20
# 17
#
# 24
# 21
#
# 11
# 10
#
# 16
# 14
#
# 1
# 0
#
# 8
# 7
#
# 15
# 13
#
# 26
# 23
#
# 27
# 24
#
# 18
# 15
#
# 23
# 20
#
# 15
# 13
#
# 20
# 17
#
# 2
# 1
#
# 18
# 15
#
# 6
# 5
#
# 24
# 21
#
# 10
# 9
#
# 18
# 15
#
# 3
# 2
#
# 19
# 16
#
# 18
# 15
#
# 11
# 10
#
# 26
# 23
#
# 11
# 10
#
# 27
# 24
#
# 13
# 11
#
# 1
# 0
#
# 7
# 6
#
# 3
# 2
#
# 2
# 1
#
# 15
# 13
#
# 26
# 23
#
# 14
# 12
#
# 19
# 16
#
# 21
# 18
#
# 13
# 11
#
# 20
# 17
#
# 14
# 12
#
# 25
# 22
#
# 15
# 13
#
# 23
# 20
#
# 26
# 23
#
# 24
# 21
#
# 25
# 22
#
# 6
# 5
#
# 11
# 10
#
# 6
# 5
#
# 2
# 1
#
# 1
# 0
#
# 15
# 13
#
# 15
# 13
#
# 1
# 0
#
# 14
# 12
#
# 6
# 5
#
# 10
# 9
#
# 15
# 13
#
# 14
# 12
#
# 18
# 15
#
# 16
# 14
#
# 14
# 12
#
# 2
# 1
#
# 6
# 5
#
# 21
# 18
#
# 26
# 23
#
# 13
# 11
#
# 15
# 13
#
# 22
# 19
#
# 16
# 14
#
# 13
# 11
#
# 21
# 18
#
# 13
# 11
#
# 18
# 15
#
# 21
# 18
#
# 25
# 22
#
# 19
# 16
#
# 16
# 14
#
# 21
# 18
#
# 21
# 18
#
# 6
# 5
#
# 24
# 21
#
# 16
# 14
#
# 9
# 8
#
# 9
# 8
#
# 9
# 8
#
# 3
# 2
#
# 26
# 23
#
# 18
# 15
#
# 11
# 10
#
# 13
# 11
#
# 30
# 26
#
# 13
# 11
#
# 10
# 9
#
# 9
# 8
#
# 6
# 5
#
# 11
# 10
#
# 8
# 7
#
# 21
# 18
#
# 5
# 4
#
# 23
# 20
#
# 2
# 1
#
# 15
# 13
#
# 24
# 21
#
# 26
# 23
#
# 30
# 26
#
# 24
# 21
#
# 18
# 15
#
# 4
# 3
#
# 27
# 24
#
# 14
# 12
#
# 26
# 23
#
# 7
# 6
#
# 6
# 5
#
# 13
# 11
#
# 9
# 8
#
# 18
# 15
#
# 6
# 5
#
# 26
# 23
#
# 2
# 1
#
# 9
# 8
#
# 27
# 24
#
# 8
# 7
#
# 14
# 12
#
# 27
# 24
#
# 1
# 0
#
# 18
# 15
#
# 27
# 24
#
# 15
# 13
#
# 7
# 6
#
# 20
# 17
#
# 13
# 11
#
# 6
# 5
#
# 9
# 8
#
# 23
# 20
#
# 18
# 15
#
# 21
# 18
#
# 13
# 11
#
# 20
# 17
#
# 9
# 8
#
# 1
# 0
#
# 13
# 11
#
# 30
# 26
#
# 6
# 5
#
# 23
# 20
#
# 16
# 14
#
# 10
# 9
#
# 30
# 26
#
# 25
# 22
#
# 18
# 15
#
# 1
# 0
#
# 26
# 23
#
# 6
# 5
#
# 25
# 22
#
# 8
# 7
#
# 6
# 5
#
# 6
# 5
#
# 23
# 20
#
# 16
# 14
#
# 3
# 2
#
# 6
# 5
#
# 20
# 17
#
# 23
# 20
#
# 5
# 4
#
# 19
# 16
#
# 29
# 25
#
# 30
# 26
#
# 1
# 0
#
# 19
# 16
#
# 18
# 15
#
# 5
# 4
#
# 29
# 25
#
# 26
# 23
#
# 2
# 1
#
# 27
# 24
#
# 9
# 8
#
# 1
# 0
#
# 5
# 4
#
# 1
# 0
#
# 9
# 8
#
# 1
# 0
#
# 26
# 23
#
# 18
# 15
#
# 23
# 20
#
# 21
# 18
#
# 22
# 19
#
# 19
# 16
#
# 23
# 20
#
# 24
# 21
#
# 19
# 16
#
# 11
# 10
#
# 9
# 8
#
# 24
# 21
#
# 8
# 7
#
# 19
# 16
#
# 30
# 26
#
# 23
# 20
#
# 9
# 8
#
# 6
# 5
#
# 19
# 16
#
# 2
# 1
#
# 20
# 17
#
# 7
# 6
#
# 20
# 17
#
# 29
# 25
#
# 11
# 10
#
# 5
# 4
#
# 9
# 8
#
# 9
# 8
#
# 19
# 16
#
# 6
# 5
#
# 3
# 2
#
# 14
# 12
#
# 20
# 17
#
# 27
# 24
#
# 26
# 23
#
# 15
# 13
#
# 9
# 8
#
# 2
# 1
#
# 24
# 21
#
# 5
# 4
#
# 2
# 1
#
# 24
# 21
#
# 2
# 1
#
# 14
# 12
#
# 20
# 17
#
# 21
# 18
#
# 21
# 18
#
# 14
# 12
#
# 4
# 3
#
# 19
# 16
#
# 10
# 9
#
# 10
# 9
#
# 8
# 7
#
# 27
# 24
#
# 24
# 21
#
# 21
# 18
#
# 3
# 2
#
# 15
# 13
#
# 9
# 8
#
# 29
# 25
#
# 14
# 12
#
# 4
# 3
#
# 10
# 9
#
# 9
# 8
#
# 13
# 11
#
# 2
# 1
#
# 24
# 21
#
# 26
# 23
#
# 6
# 5
#
# 10
# 9
#
# 22
# 19
#
# 30
# 26
#
# 8
# 7
#
# 20
# 17
#
# 18
# 15
#
# 24
# 21
#
# 30
# 26
#
# 4
# 3
#
# 18
# 15
#
# 14
# 12
#
# 23
# 20
#
# 18
# 15
#
# 20
# 17
#
# 13
# 11
#
# 1
# 0
#
# 27
# 24
#
# 3
# 2
#
# 11
# 10
#
# 9
# 8
#
# 23
# 20
#
# 6
# 5
#
# 15
# 13
#
# 3
# 2
#
# 4
# 3
#
# 27
# 24
#
# 1
# 0
#
# 3
# 2
#
# 27
# 24
#
# 2
# 1
#
# 8
# 7
#
# 10
# 9
#
# 10
# 9
#
# 15
# 13
#
# 18
# 15
#
# 23
# 20
#
# 2
# 1
#
# 10
# 9
#
# 3
# 2
#
# 11
# 10
#
# 20
# 17
#
# 1
# 0
#
# 16
# 14
#
# 1
# 0
#
# 2
# 1
#
# 16
# 14
#
# 23
# 20
#
# 10
# 9
#
# 7
# 6
#
# 23
# 20
#
# 5
# 4
#
# 15
# 13
#
# 13
# 11
#
# 1
# 0
#
# 10
# 9
#
# 29
# 25
#
# 13
# 11
#
# 14
# 12
#
# 18
# 15
#
# 2
# 1
#
# 30
# 26
#
# 9
# 8
#
# 19
# 16
#
# 5
# 4
#
# 1
# 0
#
# 19
# 16
#
# 10
# 9
#
# 21
# 18
#
# 21
# 18
#
# 5
# 4
#
# 30
# 26
#
# 3
# 2
#
# 3
# 2
#
# 2
# 1
#
# 30
# 26
#
# 30
# 26
#
# 13
# 11
#
# 23
# 20
#
# 16
# 14
#
# 16
# 14
#
# 10
# 9
#
# 6
# 5
#
# 21
# 18
#
# 16
# 14
#
# 5
# 4
#
# 13
# 11
#
# 27
# 24
#
# 20
# 17
#
# 19
# 16
#
# 22
# 19
#
# 1
# 0
#
# 23
# 20
#
# 6
# 5
#
# 10
# 9
#
# 23
# 20
#
# 16
# 14
#
# 2
# 1
#
# 23
# 20
#
# 23
# 20
#
# 13
# 11
#
# 18
# 15
#
# 27
# 24
#
# 19
# 16
#
# 23
# 20
#
# 6
# 5
#
# 27
# 24
#
# 7
# 6
#
# 20
# 17
#
# 23
# 20
#
# 9
# 8
#
# 15
# 13
#
# 27
# 24
#
# 10
# 9
#
# 2
# 1
#
# 6
# 5
#
# 18
# 15
#
# 14
# 12
#
# 9
# 8
#
# 29
# 25
#
# 9
# 8
#
# 23
# 20
#
# 21
# 18
#
# 24
# 21
#
# 20
# 17
#
# 22
# 19
#
# 11
# 10
#
# 14
# 12
#
# 6
# 5
#
# 21
# 18
#
# 19
# 16
#
# 21
# 18
#
# 30
# 26
#
# 15
# 13
#
# 20
# 17
#
# 10
# 9
#
# 5
# 4
#
# 30
# 26
#
# 24
# 21
#
# 18
# 15
#
# 24
# 21
#
# 22
# 19
#
# 11
# 10
#
# 10
# 9
#
# 18
# 15
#
# 24
# 21
#
# 11
# 10
#
# 21
# 18
#
# 21
# 18
#
# 18
# 15
#
# 1
# 0
#
# 9
# 8
#
# 19
# 16
#
# 13
# 11
#
# 9
# 8
#
# 29
# 25
#
# 18
# 15
#
# 1
# 0
#
# 29
# 25
#
# 2
# 1
#
# 11
# 10
#
# 13
# 11
#
# 25
# 22
#
# 13
# 11
#
# 10
# 9
#
# 30
# 26
#
# 18
# 15
#
# 14
# 12
#
# 1
# 0
#
# 18
# 15
#
# 11
# 10
#
# 11
# 10
#
# 21
# 18
#
# 14
# 12
#
# 23
# 20
#
# 20
# 17
#
# 15
# 13
#
# 15
# 13
#
# 11
# 10
#
# 7
# 6
#
# 24
# 21
#
# 11
# 10
#
# 11
# 10
#
# 27
# 24
#
# 9
# 8
#
# 4
# 3
#
# 15
# 13
#
# 9
# 8
#
# 18
# 15
#
# 24
# 21
#
# 5
# 4
#
# 15
# 13
#
# 10
# 9
#
# 19
# 16
#
# 1
# 0
#
# 15
# 13
#
# 18
# 15
#
# 23
# 20
#
# 3
# 2
#
# 2
# 1
#
# 19
# 16
#
# 9
# 8
#
# 14
# 12
#
# 11
# 10
#
# 14
# 12
#
# 8
# 7
#
# 6
# 5
#
# 6
# 5
#
# 9
# 8
#
# 22
# 19
#
# 5
# 4
#
# 4
# 3
#
# 2
# 1
#
# 24
# 21
#
# 19
# 16
#
# 26
# 23
#
# 18
# 15
#
# 26
# 23
#
# 15
# 13
#
# 7
# 6
#
# 22
# 19
#
# 24
# 21
#
# 15
# 13
#
# 10
# 9
#
# 21
# 18
#
# 13
# 11
#
# 4
# 3
#
# 1
# 0
#
# 1
# 0
#
# 10
# 9
#
# 2
# 1
#
# 15
# 13
#
# 4
# 3
#
# 15
# 13
#
# 30
# 26
#
# 27
# 24
#
# 24
# 21
#
# 8
# 7
#
# 21
# 18
#
# 8
# 7
#
# 26
# 23
#
# 18
# 15
#
# 29
# 25
#
# 7
# 6
#
# 22
# 19
#
# 2
# 1
#
# 27
# 24
#
# 21
# 18
#
# 11
# 10
#
# 30
# 26
#
# 1
# 0
#
# 11
# 10
#
# 26
# 23
#
# 24
# 21
#
# 18
# 15
#
# 11
# 10
#
# 9
# 8
#
# 18
# 15
#
# 6
# 5
#
# 10
# 9
#
# 13
# 11
#
# 24
# 21
#
# 15
# 13
#
# 9
# 8
#
# 20
# 17
#
# 24
# 21
#
# 21
# 18
#
# 10
# 9
#
# 9
# 8
#
# 23
# 20
#
# 16
# 14
#
# 6
# 5
#
# 14
# 12
#
# 14
# 12
#
# 20
# 17
#
# 13
# 11
#
# 23
# 20
#
# 19
# 16
#
# 21
# 18
#
# 26
# 23
#
# 13
# 11
#
# 27
# 24
#
# 26
# 23
#
# 29
# 25
#
# 11
# 10
#
# 19
# 16
#
# 29
# 25
#
# 20
# 17
#
# 19
# 16
#
# 9
# 8
#
# 13
# 11
#
# 24
# 21
#
# 6
# 5
#
# 16
# 14
#
# 14
# 12
#
# 4
# 3
#
# 26
# 23
#
# 2
# 1
#
# 18
# 15
#
# 15
# 13
#
# 5
# 4
#
# 7
# 6
#
# 8
# 7
#
# 18
# 15
#
# 7
# 6
#
# 10
# 9
#
# 13
# 11
#
# 2
# 1
#
# 21
# 18
#
# 22
# 19
#
# 13
# 11
#
# 18
# 15
#
# 21
# 18
#
# 24
# 21
#
# 13
# 11
#
# 1
# 0
#
# 1
# 0
#
# 24
# 21
#
# 24
# 21
#
# 29
# 25
#
# 27
# 24
#
# 24
# 21
#
# 9
# 8
#
# 13
# 11
#
# 15
# 13
#
# 4
# 3
#
# 23
# 20
#
# 24
# 21
#
# 8
# 7
#
# 24
# 21
#
# 18
# 15
#
# 19
# 16
#
# 20
# 17
#
# 21
# 18
#
# 30
# 26
#
# 18
# 15
#
# 29
# 25
#
# 23
# 20
#
# 13
# 11
#
# 9
# 8
#
# 14
# 12
#
# 23
# 20
#
# 10
# 9
#
# 11
# 10
#
# 22
# 19
#
# 15
# 13
#
# 4
# 3
#
# 22
# 19
#
# 13
# 11
#
# 2
# 1
#
# 8
# 7
#
# 21
# 18
#
# 1
# 0
#
# 9
# 8
#
# 2
# 1
#
# 10
# 9
#
# 23
# 20
#
# 21
# 18
#
# 7
# 6
#
# 30
# 26
#
# 23
# 20
#
# 16
# 14
#
# 3
# 2
#
# 21
# 18
#
# 4
# 3
#
# 11
# 10
#
# 30
# 26
#
# 2
# 1
#
# 27
# 24
#
# 13
# 11
#
# 6
# 5
#
# 23
# 20
#
# 9
# 8
#
# 22
# 19
#
# 1
# 0
#
# 26
# 23
#
# 1
# 0
#
# 11
# 10
#
# 3
# 2
#
# 11
# 10
#
# 22
# 19
#
# 9
# 8
#
# 1
# 0
#
# 1
# 0
#
# 10
# 9
#
# 24
# 21
#
# 26
# 23
#
# 3
# 2
#
# 8
# 7
#
# 7
# 6
#
# 6
# 5
#
# 24
# 21
#
# 9
# 8
#
# 4
# 3
#
# 13
# 11
#
# 9
# 8
#
# 23
# 20
#
# 13
# 11
#
# 19
# 16
#
# 9
# 8
#
# 13
# 11
#
# 11
# 10
#
# 10
# 9
#
# 20
# 17
#
# 13
# 11
#
# 11
# 10
#
# 21
# 18
#
# 2
# 1
#
# 2
# 1
#
# 15
# 13
#
# 23
# 20
#
# 10
# 9
#
# 3
# 2
#
# 9
# 8
#
# 9
# 8
#
# 4
# 3
#
# 23
# 20
#
# 23
# 20
#
# 20
# 17
#
# 19
# 16
#
# 10
# 9
#
# 10
# 9
#
# 1
# 0
#
# 18
# 15
#
# 4
# 3
#
# 5
# 4
#
# 11
# 10
#
# 3
# 2
#
# 19
# 16
#
# 5
# 4
#
# 30
# 26
#
# 26
# 23
#
# 21
# 18
#
# 9
# 8
#
# 4
# 3
#
# 10
# 9
#
# 26
# 23
#
# 7
# 6
#
# 25
# 22
#
# 20
# 17
#
# 30
# 26
#
# 19
# 16
#
# 8
# 7
#
# 19
# 16
#
# 21
# 18
#
# 9
# 8
#
# 7
# 6
#
# 3
# 2
#
# 11
# 10
#
# 9
# 8
#
# 1
# 0
#
# 9
# 8
#
# 18
# 15
#
# 30
# 26
#
# 26
# 23
#
# 27
# 24
#
# 30
# 26
#
# 22
# 19
#
# 11
# 10
#
# 1
# 0
#
# 21
# 18
#
# 27
# 24
#
# 15
# 13
#
# 21
# 18
#
# 29
# 25
#
# 19
# 16
#
# 23
# 20
#
# 16
# 14
#
# 6
# 5
#
# 15
# 13
#
# 13
# 11
#
# 14
# 12
#
# 3
# 2
#
# 3
# 2
#
# 5
# 4
#
# 14
# 12
#
# 24
# 21
#
# 2
# 1
#
# 13
# 11
#
# 30
# 26
#
# 9
# 8
#
# 19
# 16
#
# 29
# 25
#
# 20
# 17
#
# 9
# 8
#
# 26
# 23
#
# 4
# 3
#
# 2
# 1
#
# 30
# 26
#
# 11
# 10
#
# 20
# 17
#
# 26
# 23
#
# 9
# 8
#
# 19
# 16
#
# 27
# 24
#
# 21
# 18
#
# 22
# 19
#
# 4
# 3
#
# 2
# 1
#
# 21
# 18
#
# 22
# 19
#
# 15
# 13
#
# 24
# 21
#
# 22
# 19
#
# 24
# 21
#
# 4
# 3
#
# 24
# 21
#
# 10
# 9
#
# 13
# 11
#
# 14
# 12
#
# 18
# 15
#
# 14
# 12
#
# 1
# 0
#
# 27
# 24
#
# 22
# 19
#
# 9
# 8
#
# 23
# 20
#
# 9
# 8
#
# 14
# 12
#
# 2
# 1
#
# 21
# 18
#
# 9
# 8
#
# 9
# 8
#
# 6
# 5
#
# 5
# 4
#
# 15
# 13
#
# 10
# 9
#
# 6
# 5
#
# 6
# 5
#
# 4
# 3
#
# 24
# 21
#
# 13
# 11
#
# 9
# 8
#
# 27
# 24
#
# 2
# 1
#
# 13
# 11
#
# 8
# 7
#
# 18
# 15
#
# 9
# 8
#
# 1
# 0
#
# 25
# 22
#
# 6
# 5
#
# 15
# 13
#
# 11
# 10
#
# 16
# 14
#
# 21
# 18
#
# 9
# 8
#
# 9
# 8
#
# 21
# 18
#
# 19
# 16
#
# 1
# 0
#
# 24
# 21
#
# 19
# 16
#
# 8
# 7
#
# 3
# 2
#
# 6
# 5
#
# 11
# 10
#
# 30
# 26
#
# 13
# 11
#
# 6
# 5
#
# 26
# 23
#
# 9
# 8
#
# 23
# 20
#
# 10
# 9
#
# 1
# 0
#
# 10
# 9
#
# 16
# 14
#
# 18
# 15
#
# 16
# 14
#
# 25
# 22
#
# 1
# 0
#
# 22
# 19
#
# 1
# 0
#
# 19
# 16
#
# 9
# 8
#
# 22
# 19
#
# 24
# 21
#
# 16
# 14
#
# 20
# 17
#
# 22
# 19
#
# 21
# 18
#
# 23
# 20
#
# 8
# 7
#
# 21
# 18
#
# 3
# 2
#
# 14
# 12
#
# 16
# 14
#
# 19
# 16
#
# 5
# 4
#
# 11
# 10
#
# 21
# 18
#
# 3
# 2
#
# 13
# 11
#
# 6
# 5
#
# 27
# 24
#
# 21
# 18
#
# 8
# 7
#
# 2
# 1
#
# 5
# 4
#
# 24
# 21
#
# 5
# 4
#
# 23
# 20
#
# 1
# 0
#
# 8
# 7
#
# 29
# 25
#
# 23
# 20
#
# 10
# 9
#
# 13
# 11
#
# 2
# 1
#
# 8
# 7
#
# 27
# 24
#
# 25
# 22
#
# 13
# 11
#
# 14
# 12
#
# 10
# 9
#
# 6
# 5
#
# 21
# 18
#
# 30
# 26
#
# 3
# 2
#
# 15
# 13
#
# 27
# 24
#
# 14
# 12
#
# 11
# 10
#
# 3
# 2
#
# 15
# 13
#
# 11
# 10
#
# 29
# 25
#
# 23
# 20
#
# 14
# 12
#
# 14
# 12
#
# 25
# 22
#
# 15
# 13
#
# 30
# 26
#
# 18
# 15
#
# 10
# 9
#
# 9
# 8
#
# 30
# 26
#
# 2
# 1
#
# 23
# 20
#
# 25
# 22
#
# 9
# 8
#
# 15
# 13
#
# 1
# 0
#
# 23
# 20
#
# 10
# 9
#
# 27
# 24
#
# 1
# 0
#
# 9
# 8
#
# 2
# 1
#
# 19
# 16
#
# 29
# 25
#
# 14
# 12
#
# 14
# 12
#
# 6
# 5
#
# 22
# 19
#
# 5
# 4
#
# 21
# 18
#
# 15
# 13
#
# 2
# 1
#
# 15
# 13
#
# 19
# 16
#
# 22
# 19
#
# 20
# 17
#
# 14
# 12
#
# 11
# 10
#
# 18
# 15
#
# 25
# 22
#
# 22
# 19
#
# 10
# 9
#
# 18
# 15
#
# 20
# 17
#
# 6
# 5
#
# 20
# 17
#
# 13
# 11
#
# 3
# 2
#
# 5
# 4
#
# 9
# 8
#
# 1
# 0
#
# 22
# 19
#
# 4
# 3
#
# 7
# 6
#
# 9
# 8
#
# 6
# 5
#
# 11
# 10
#
# 25
# 22
#
# 6
# 5
#
# 2
# 1
#
# 6
# 5
#
# 21
# 18
#
# 22
# 19
#
# 29
# 25
#
# 21
# 18
#
# 7
# 6
#
# 5
# 4
#
# 1
# 0
#
# 29
# 25
#
# 9
# 8
#
# 3
# 2
#
# 10
# 9
#
# 21
# 18
#
# 18
# 15
#
# 3
# 2
#
# 4
# 3
#
# 30
# 26
#
# 2
# 1
#
# 29
# 25
#
# 4
# 3
#
# 11
# 10
#
# 21
# 18
#
# 14
# 12
#
# 1
# 0
#
# 5
# 4
#
# 10
# 9
#
# 18
# 15
#
# 14
# 12
#
# 15
# 13
#
# 20
# 17
#
# 21
# 18
#
# 13
# 11
#
# 15
# 13
#
# 18
# 15
#
# 4
# 3
#
# 27
# 24
#
# 18
# 15
#
# 21
# 18
#
# 24
# 21
#
# 21
# 18
#
# 6
# 5
#
# 18
# 15
#
# 3
# 2
#
# 13
# 11
#
# 21
# 18
#
# 15
# 13
#
# 24
# 21
#
# 26
# 23
#
# 9
# 8
#
# 11
# 10
#
# 13
# 11
#
# 9
# 8
#
# 18
# 15
#
# 9
# 8
#
# 21
# 18
#
# 21
# 18
#
# 16
# 14
#
# 18
# 15
#
# 7
# 6
#
# 11
# 10
#
# 7
# 6
#
# 5
# 4
#
# 27
# 24
#
# 20
# 17
#
# 8
# 7
#
# 9
# 8
#
# 9
# 8
#
# 10
# 9
#
# 2
# 1
#
# 23
# 20
#
# 21
# 18
#
# 22
# 19
#
# 16
# 14
#
# 5
# 4
#
# 21
# 18
#
# 11
# 10
#
# 16
# 14
#
# 27
# 24
#
# 8
# 7
#
# 9
# 8
#
# 16
# 14
#
# 22
# 19
#
# 26
# 23
#
# 18
# 15
#
# 9
# 8
#
# 3
# 2
#
# 23
# 20
#
# 9
# 8
#
# 30
# 26
#
# 3
# 2
#
# 20
# 17
#
# 6
# 5
#
# 9
# 8
#
# 18
# 15
#
# 3
# 2
#
# 15
# 13
#
# 21
# 18
#
# 25
# 22
#
# 2
# 1
#
# 13
# 11
#
# 9
# 8
#
# 21
# 18
#
# 6
# 5
#
# 7
# 6
#
# 2
# 1
#
# 15
# 13
#
# 2
# 1
#
# 11
# 10
#
# 14
# 12
#
# 27
# 24
#
# 11
# 10
#
# 21
# 18
#
# 9
# 8
#
# 8
# 7
#
# 10
# 9
#
# 6
# 5
#
# 21
# 18
#
# 15
# 13
#
# 2
# 1
#
# 20
# 17
#
# 21
# 18
#
# 9
# 8
#
# 9
# 8
#
# 30
# 26
#
# 2
# 1
#
# 8
# 7
#
# 8
# 7
#
# 9
# 8
#
# 24
# 21
#
# 10
# 9
#
# 25
# 22
#
# 15
# 13
#
# 26
# 23
#
# 26
# 23
#
# 21
# 18
#
# 10
# 9
#
# 6
# 5
#
# 16
# 14
#
# 8
# 7
#
# 16
# 14
#
# 13
# 11
#
# 16
# 14
#
# 2
# 1
#
# 21
# 18
#
# 27
# 24
#
# 16
# 14
#
# 5
# 4
#
# 18
# 15
#
# 25
# 22
#
# 14
# 12
#
# 21
# 18
#
# 29
# 25
#
# 20
# 17
#
# 15
# 13
#
# 9
# 8
#
# 15
# 13
#
# 6
# 5
#
# 19
# 16
#
# 18
# 15
#
# 18
# 15
#
# 16
# 14
#
# 13
# 11
#
# 29
# 25
#
# 3
# 2
#
# 8
# 7
#
# 6
# 5
#
# 7
# 6
#
# 21
# 18
#
# 13
# 11
#
# 1
# 0
#
# 11
# 10
#
# 24
# 21
#
# 11
# 10
#
# 10
# 9
#
# 9
# 8
#
# 8
# 7
#
# 13
# 11
#
# 15
# 13
#
# 3
# 2
#
# 16
# 14
#
# 27
# 24
#
# 15
# 13
#
# 11
# 10
#
# 20
# 17
#
# 21
# 18
#
# 19
# 16
#
# 24
# 21
#
# 7
# 6
#
# 23
# 20
#
# 19
# 16
#
# 21
# 18
#
# 18
# 15
#
# 10
# 9
#
# 25
# 22
#
# 8
# 7
#
# 11
# 10
#
# 19
# 16
#
# 26
# 23
#
# 4
# 3
#
# 6
# 5
#
# 3
# 2
#
# 24
# 21
#
# 18
# 15
#
# 14
# 12
#
# 14
# 12
#
# 11
# 10
#
# 19
# 16
#
# 9
# 8
#
# 10
# 9
#
# 19
# 16
#
# 5
# 4
#
# 18
# 15
#
# 6
# 5
#
# 22
# 19
#
# 16
# 14
#
# 27
# 24
#
# 21
# 18
#
# 18
# 15
#
# 20
# 17
#
# 26
# 23
#
# 6
# 5
#
# 13
# 11
#
# 6
# 5
#
# 2
# 1
#
# 29
# 25
#
# 15
# 13
#
# 11
# 10
#
# 27
# 24
#
# 23
# 20
#
# 13
# 11
#
# 27
# 24
#
# 30
# 26
#
# 27
# 24
#
# 9
# 8
#
# 6
# 5
#
# 25
# 22
#
# 26
# 23
#
# 9
# 8
#
# 21
# 18
#
# 22
# 19
#
# 22
# 19
#
# 21
# 18
#
# 25
# 22
#
# 29
# 25
#
# 2
# 1
#
# 22
# 19
#
# 9
# 8
#
# 2
# 1
#
# 7
# 6
#
# 13
# 11
#
# 13
# 11
#
# 14
# 12
#
# 21
# 18
#
# 18
# 15
#
# 23
# 20
#
# 2
# 1
#
# 30
# 26
#
# 21
# 18
#
# 27
# 24
#
# 19
# 16
#
# 4
# 3
#
# 2
# 1
#
# 20
# 17
#
# 24
# 21
#
# 24
# 21
#
# 9
# 8
#
# 4
# 3
#
# 11
# 10
#
# 23
# 20
#
# 16
# 14
#
# 9
# 8
#
# 18
# 15
#
# 19
# 16
#
# 15
# 13
#
# 8
# 7
#
# 25
# 22
#
# 20
# 17
#
# 14
# 12
#
# 10
# 9
#
# 13
# 11
#
# 10
# 9
#
# 21
# 18
#
# 16
# 14
#
# 10
# 9
#
# 21
# 18
#
# 23
# 20
#
# 11
# 10
#
# 6
# 5
#
# 5
# 4
#
# 23
# 20
#
# 5
# 4
#
# 3
# 2
#
# 30
# 26
#
# 27
# 24
#
# 9
# 8
#
# 9
# 8
#
# 6
# 5
#
# 4
# 3
#
# 9
# 8
#
# 20
# 17
#
# 26
# 23
#
# 27
# 24
#
# 18
# 15
#
# 3
# 2
#
# 5
# 4
#
# 3
# 2
#
# 6
# 5
#
# 11
# 10
#
# 13
# 11
#
# 5
# 4
#
# 29
# 25
#
# 30
# 26
#
# 20
# 17
#
# 9
# 8
#
# 13
# 11
#
# 18
# 15
#
# 23
# 20
#
# 3
# 2
#
# 10
# 9
#
# 6
# 5
#
# 23
# 20
#
# 14
# 12
#
# 22
# 19
#
# 30
# 26
#
# 21
# 18
#
# 23
# 20
#
# 14
# 12
#
# 15
# 13
#
# 23
# 20
#
# 18
# 15
#
# 6
# 5
#
# 18
# 15
#
# 15
# 13
#
# 30
# 26
#
# 10
# 9
#
# 16
# 14
#
# 9
# 8
#
# 25
# 22
#
# 23
# 20
#
# 9
# 8
#
# 24
# 21
#
# 4
# 3
#
# 27
# 24
#
# 9
# 8
#
# 18
# 15
#
# 15
# 13
#
# 6
# 5
#
# 18
# 15
#
# 26
# 23
#
# 18
# 15
#
# 19
# 16
#
# 29
# 25
#
# 15
# 13
#
# 8
# 7
#
# 24
# 21
#
# 11
# 10
#
# 26
# 23
#
# 27
# 24
#
# 25
# 22
#
# 9
# 8
#
# 18
# 15
#
# 5
# 4
#
# 3
# 2
#
# 23
# 20
#
# 29
# 25
#
# 5
# 4
#
# 19
# 16
#
# 15
# 13
#
# 19
# 16
#
# 27
# 24
#
# 23
# 20
#
# 10
# 9
#
# 9
# 8
#
# 23
# 20
#
# 21
# 18
#
# 5
# 4
#
# 22
# 19
#
# 19
# 16
#
# 29
# 25
#
# 10
# 9
#
# 21
# 18
#
# 29
# 25
#
# 14
# 12
#
# 8
# 7
#
# 4
# 3
#
# 21
# 18
#
# 9
# 8
#
# 18
# 15
#
# 21
# 18
#
# 10
# 9
#
# 3
# 2
#
# 15
# 13
#
# 6
# 5
#
# 3
# 2
#
# 2
# 1
#
# 24
# 21
#
# 6
# 5
#
# 13
# 11
#
# 26
# 23
#
# 1
# 0
#
# 18
# 15
#
# 9
# 8
#
# 4
# 3
#
# 19
# 16
#
# 6
# 5
#
# 3
# 2
#
# 3
# 2
#
# 15
# 13
#
# 3
# 2
#
# 18
# 15
#
# 11
# 10
#
# 27
# 24
#
# 13
# 11
#
# 13
# 11
#
# 11
# 10
#
# 22
# 19
#
# 18
# 15
#
# 5
# 4
#
# 26
# 23
#
# 8
# 7
#
# 27
# 24
#
# 29
# 25
#
# 23
# 20
#
# 10
# 9
#
# 10
# 9
#
# 11
# 10
#
# 6
# 5
#
# 7
# 6
#
# 4
# 3
#
# 27
# 24
#
# 25
# 22
#
# 18
# 15
#
# 14
# 12
#
# 20
# 17
#
# 21
# 18
#
# 1
# 0
#
# 29
# 25
#
# 7
# 6
#
# 3
# 2
#
# 27
# 24
#
# 3
# 2
#
# 6
# 5
#
# 20
# 17
#
# 24
# 21
#
# 13
# 11
#
# 11
# 10
#
# 3
# 2
#
# 8
# 7
#
# 9
# 8
#
# 27
# 24
#
# 5
# 4
#
# 14
# 12
#
# 4
# 3
#
# 30
# 26
#
# 7
# 6
#
# 1
# 0
#
# 30
# 26
#
# 24
# 21
#
# 3
# 2
#
# 18
# 15
#
# 9
# 8
#
# 25
# 22
#
# 11
# 10
#
# 19
# 16
#
# 14
# 12
#
# 18
# 15
#
# 9
# 8
#
# 20
# 17
#
# 30
# 26
#
# 26
# 23
#
# 18
# 15
#
# 23
# 20
#
# 5
# 4
#
# 18
# 15
#
# 20
# 17
#
# 18
# 15
#
# 15
# 13
#
# 7
# 6
#
# 14
# 12
#
# 18
# 15
#
# 14
# 12
#
# 9
# 8
#
# 1
# 0
#
# 10
# 9
#
# 4
# 3
#
# 16
# 14
#
# 11
# 10
#
# 6
# 5
#
# 13
# 11
#
# 18
# 15
#
# 22
# 19
#
# 18
# 15
#
# 26
# 23
#
# 15
# 13
#
# 14
# 12
#
# 4
# 3
#
# 15
# 13
#
# 21
# 18
#
# 10
# 9
#
# 23
# 20
#
# 16
# 14
#
# 14
# 12
#
# 6
# 5
#
# 20
# 17
#
# 23
# 20
#
# 5
# 4
#
# 2
# 1
#
# 4
# 3
#
# 26
# 23
#
# 20
# 17
#
# 11
# 10
#
# 23
# 20
#
# 9
# 8
#
# 22
# 19
#
# 27
# 24
#
# 18
# 15
#
# 13
# 11
#
# 5
# 4
#
# 8
# 7
#
# 24
# 21
#
# 6
# 5
#
# 15
# 13
#
# 10
# 9
#
# 19
# 16
#
# 9
# 8
#
# 23
# 20
#
# 23
# 20
#
# 19
# 16
#
# 19
# 16
#
# 14
# 12
#
# 10
# 9
#
# 2
# 1
#
# 21
# 18
#
# 3
# 2
#
# 5
# 4
#
# 18
# 15
#
# 24
# 21
#
# 9
# 8
#
# 30
# 26
#
# 14
# 12
#
# 29
# 25
#
# 21
# 18
#
# 18
# 15
#
# 20
# 17
#
# 6
# 5
#
# 19
# 16
#
# 22
# 19
#
# 25
# 22
#
# 3
# 2
#
# 27
# 24
#
# 1
# 0
#
# 8
# 7
#
# 24
# 21
#
# 18
# 15
#
# 19
# 16
#
# 18
# 15
#
# 21
# 18
#
# 9
# 8
#
# 3
# 2
#
# 25
# 22
#
# 9
# 8
#
# 29
# 25
#
# 15
# 13
#
# 10
# 9
#
# 18
# 15
#
# 2
# 1
#
# 7
# 6
#
# 18
# 15
#
# 9
# 8
#
# 18
# 15
#
# 23
# 20
#
# 4
# 3
#
# 20
# 17
#
# 5
# 4
#
# 26
# 23
#
# 2
# 1
#
# 6
# 5
#
# 21
# 18
#
# 24
# 21
#
# 5
# 4
#
# 11
# 10
#
# 21
# 18
#
# 15
# 13
#
# 20
# 17
#
# 1
# 0
#
# 25
# 22
#
# 15
# 13
#
# 8
# 7
#
# 3
# 2
#
# 14
# 12
#
# 20
# 17
#
# 10
# 9
#
# 16
# 14
#
# 23
# 20
#
# 20
# 17
#
# 13
# 11
#
# 14
# 12
#
# 21
# 18
#
# 9
# 8
#
# 9
# 8
#
# 9
# 8
#
# 10
# 9
#
# 9
# 8
#
# 5
# 4
#
# 18
# 15
#
# 24
# 21
#
# 10
# 9
#
# 7
# 6
#
# 3
# 2
#
# 10
# 9
#
# 6
# 5
#
# 15
# 13
#
# 9
# 8
#
# 21
# 18
#
# 19
# 16
#
# 18
# 15
#
# 30
# 26
#
# 5
# 4
#
# 13
# 11
#
# 24
# 21
#
# 15
# 13
#
# 20
# 17
#
# 20
# 17
#
# 21
# 18
#
# 6
# 5
#
# 26
# 23
#
# 9
# 8
#
# 27
# 24
#
# 11
# 10
#
# 27
# 24
#
# 24
# 21
#
# 25
# 22
#
# 25
# 22
#
# 8
# 7
#
# 10
# 9
#
# 11
# 10
#
# 23
# 20
#
# 21
# 18
#
# 20
# 17
#
# 21
# 18
#
# 21
# 18
#
# 15
# 13
#
# 2
# 1
#
# 15
# 13
#
# 25
# 22
#
# 4
# 3
#
# 21
# 18
#
# 14
# 12
#
# 14
# 12
#
# 16
# 14
#
# 11
# 10
#
# 22
# 19
#
# 27
# 24
#
# 3
# 2
#
# 15
# 13
#
# 13
# 11
#
# 6
# 5
#
# 6
# 5
#
# 9
# 8
#
# 9
# 8
#
# 14
# 12
#
# 26
# 23
#
# 25
# 22
#
# 1
# 0
#
# 6
# 5
#
# 15
# 13
#
# 13
# 11
#
# 10
# 9
#
# 9
# 8
#
# 15
# 13
#
# 5
# 4
#
# 30
# 26
#
# 10
# 9
#
# 27
# 24
#
# 8
# 7
#
# 24
# 21
#
# 26
# 23
#
# 19
# 16
#
# 3
# 2
#
# 9
# 8
#
# 25
# 22
#
# 11
# 10
#
# 24
# 21
#
# 19
# 16
#
# 14
# 12
#
# 11
# 10
#
# 20
# 17
#
# 4
# 3
#
# 9
# 8
#
# 26
# 23
#
# 23
# 20
#
# 15
# 13
#
# 18
# 15
#
# 15
# 13
#
# 23
# 20
#
# 9
# 8
#
# 19
# 16
#
# 13
# 11
#
# 21
# 18
#
# 23
# 20
#
# 20
# 17
#
# 1
# 0
#
# 13
# 11
#
# 11
# 10
#
# 22
# 19
#
# 25
# 22
#
# 1
# 0
#
# 16
# 14
#
# 24
# 21
#
# 18
# 15
#
# 7
# 6
#
# 20
# 17
#
# 22
# 19
#
# 10
# 9
#
# 23
# 20
#
# 16
# 14
#
# 2
# 1
#
# 26
# 23
#
# 9
# 8
#
# 5
# 4
#
# 16
# 14
#
# 8
# 7
#
# 18
# 15
#
# 10
# 9
#
# 10
# 9
#
# 8
# 7
#
# 3
# 2
#
# 11
# 10
#
# 27
# 24
#
# 21
# 18
#
# 24
# 21
#
# 29
# 25
#
# 21
# 18
#
# 25
# 22
#
# 19
# 16
#
# 20
# 17
#
# 30
# 26
#
# 15
# 13
#
# 23
# 20
#
# 10
# 9
#
# 29
# 25
#
# 23
# 20
#
# 30
# 26
#
# 7
# 6
#
# 3
# 2
#
# 1
# 0
#
# 3
# 2
#
# 20
# 17
#
# 13
# 11
#
# 19
# 16
#
# 16
# 14
#
# 10
# 9
#
# 11
# 10
#
# 15
# 13
#
# 2
# 1
#
# 14
# 12
#
# 10
# 9
#
# 9
# 8
#
# 11
# 10
#
# 6
# 5
#
# 15
# 13
#
# 10
# 9
#
# 9
# 8
#
# 18
# 15
#
# 9
# 8
#
# 4
# 3
#
# 4
# 3
#
# 15
# 13
#
# 3
# 2
#
# 8
# 7
#
# 19
# 16
#
# 13
# 11
#
# 14
# 12
#
# 8
# 7
#
# 24
# 21
#
# 23
# 20
#
# 27
# 24
#
# 2
# 1
#
# 18
# 15
#
# 3
# 2
#
# 24
# 21
#
# 10
# 9
#
# 14
# 12
#
# 3
# 2
#
# 2
# 1
#
# 11
# 10
#
# 11
# 10
#
# 21
# 18
#
# 29
# 25
#
# 11
# 10
#
# 27
# 24
#
# 14
# 12
#
# 21
# 18
#
# 1
# 0
#
# 3
# 2
#
# 26
# 23
#
# 16
# 14
#
# 15
# 13
#
# 4
# 3
#
# 27
# 24
#
# 2
# 1
#
# 30
# 26
#
# 6
# 5
#
# 18
# 15
#
# 30
# 26
#
# 30
# 26
#
# 18
# 15
#
# 24
# 21
#
# 29
# 25
#
# 29
# 25
#
# 10
# 9
#
# 30
# 26
#
# 14
# 12
#
# 2
# 1
#
# 21
# 18
#
# 29
# 25
#
# 1
# 0
#
# 13
# 11
#
# 30
# 26
#
# 29
# 25
#
# 14
# 12
#
# 23
# 20
#
# 2
# 1
#
# 4
# 3
#
# 9
# 8
#
# 2
# 1
#
# 11
# 10
#
# 11
# 10
#
# 21
# 18
#
# 15
# 13
#
# 21
# 18
#
# 18
# 15
#
# 23
# 20
#
# 21
# 18
#
# 15
# 13
#
# 15
# 13
#
# 29
# 25
#
# 9
# 8
#
# 14
# 12
#
# 21
# 18
#
# 9
# 8
#
# 26
# 23
#
# 9
# 8
#
# 7
# 6
#
# 24
# 21
#
# 16
# 14
#
# 8
# 7
#
# 11
# 10
#
# 22
# 19
#
# 22
# 19
#
# 21
# 18
#
# 7
# 6
#
# 8
# 7
#
# 1
# 0
#
# 22
# 19
#
# 2
# 1
#
# 2
# 1
#
# 13
# 11
#
# 18
# 15
#
# 20
# 17
#
# 23
# 20
#
# 6
# 5
#
# 14
# 12
#
# 13
# 11
#
# 23
# 20
#
# 10
# 9
#
# 29
# 25
#
# 20
# 17
#
# 27
# 24
#
# 21
# 18
#
# 27
# 24
#
# 19
# 16
#
# 2
# 1
#
# 11
# 10
#
# 24
# 21
#
# 18
# 15
#
# 13
# 11
#
# 3
# 2
#
# 21
# 18
#
# 6
# 5
#
# 8
# 7
#
# 14
# 12
#
# 29
# 25
#
# 7
# 6
#
# 8
# 7
#
# 14
# 12
#
# 15
# 13
#
# 24
# 21
#
# 19
# 16
#
# 29
# 25
#
# 15
# 13
#
# 11
# 10
#
# 8
# 7
#
# 1
# 0
#
# 15
# 13
#
# 23
# 20
#
# 4
# 3
#
# 6
# 5
#
# 9
# 8
#
# 10
# 9
#
# 19
# 16
#
# 21
# 18
#
# 15
# 13
#
# 9
# 8
#
# 10
# 9
#
# 14
# 12
#
# 26
# 23
#
# 24
# 21
#
# 6
# 5
#
# 22
# 19
#
# 9
# 8
#
# 6
# 5
#
# 27
# 24
#
# 4
# 3
#
# 24
# 21
#
# 10
# 9
#
# 9
# 8
#
# 6
# 5
#
# 25
# 22
#
# 3
# 2
#
# 10
# 9
#
# 4
# 3
#
# 3
# 2
#
# 1
# 0
#
# 18
# 15
#
# 21
# 18
#
# 19
# 16
#
# 19
# 16
#
# 25
# 22
#
# 23
# 20
#
# 9
# 8
#
# 9
# 8
#
# 27
# 24
#
# 10
# 9
#
# 24
# 21
#
# 23
# 20
#
# 1
# 0
#
# 24
# 21
#
# 24
# 21
#
# 9
# 8
#
# 14
# 12
#
# 10
# 9
#
# 19
# 16
#
# 14
# 12
#
# 23
# 20
#
# 10
# 9
#
# 7
# 6
#
# 18
# 15
#
# 19
# 16
#
# 9
# 8
#
# 15
# 13
#
# 15
# 13
#
# 9
# 8
#
# 6
# 5
#
# 29
# 25
#
# 23
# 20
#
# 11
# 10
#
# 24
# 21
#
# 3
# 2
#
# 30
# 26
#
# 20
# 17
#
# 19
# 16
#
# 11
# 10
#
# 7
# 6
#
# 29
# 25
#
# 3
# 2
#
# 15
# 13
#
# 22
# 19
#
# 27
# 24
#
# 4
# 3
#
# 14
# 12
#
# 22
# 19
#
# 13
# 11
#
# 22
# 19
#
# 13
# 11
#
# 21
# 18
#
# 1
# 0
#
# 10
# 9
#
# 18
# 15
#
# 8
# 7
#
# 7
# 6
#
# 13
# 11
#
# 8
# 7
#
# 3
# 2
#
# 9
# 8
#
# 20
# 17
#
# 8
# 7
#
# 2
# 1
#
# 27
# 24
#
# 10
# 9
#
# 6
# 5
#
# 27
# 24
#
# 15
# 13
#
# 19
# 16
#
# 18
# 15
#
# 7
# 6
#
# 14
# 12
#
# 24
# 21
#
# 13
# 11
#
# 9
# 8
#
# 16
# 14
#
# 2
# 1
#
# 9
# 8
#
# 10
# 9
#
# 23
# 20
#
# 24
# 21
#
# 15
# 13
#
# 13
# 11
#
# 22
# 19
#
# 9
# 8
#
# 14
# 12
#
# 10
# 9
#
# 9
# 8
#
# 14
# 12
#
# 16
# 14
#
# 6
# 5
#
# 10
# 9
#
# 21
# 18
#
# 21
# 18
#
# 5
# 4
#
# 18
# 15
#
# 15
# 13
#
# 15
# 13
#
# 27
# 24
#
# 13
# 11
#
# 21
# 18
#
# 24
# 21
#
# 13
# 11
#
# 27
# 24
#
# 3
# 2
#
# 1
# 0
#
# 19
# 16
#
# 6
# 5
#
# 9
# 8
#
# 5
# 4
#
# 29
# 25
#
# 18
# 15
#
# 19
# 16
#
# 9
# 8
#
# 8
# 7
#
# 21
# 18
#
# 1
# 0
#
# 8
# 7
#
# 15
# 13
#
# 26
# 23
#
# 21
# 18
#
# 10
# 9
#
# 23
# 20
#
# 29
# 25
#
# 2
# 1
#
# 5
# 4
#
# 23
# 20
#
# 6
# 5
#
# 21
# 18
#
# 29
# 25
#
# 15
# 13
#
# 10
# 9
#
# 14
# 12
#
# 5
# 4
#
# 20
# 17
#
# 26
# 23
#
# 29
# 25
#
# 9
# 8
#
# 5
# 4
#
# 9
# 8
#
# 24
# 21
#
# 29
# 25
#
# 9
# 8
#
# 15
# 13
#
# 1
# 0
#
# 11
# 10
#
# 13
# 11
#
# 3
# 2
#
# 2
# 1
#
# 13
# 11
#
# 13
# 11
#
# 9
# 8
#
# 11
# 10
#
# 15
# 13
#
# 9
# 8
#
# 10
# 9
#
# 6
# 5
#
# 7
# 6
#
# 7
# 6
#
# 24
# 21
#
# 18
# 15
#
# 14
# 12
#
# 22
# 19
#
# 9
# 8
#
# 20
# 17
#
# 21
# 18
#
# 14
# 12
#
# 18
# 15
#
# 11
# 10
#
# 3
# 2
#
# 3
# 2
#
# 9
# 8
#
# 11
# 10
#
# 18
# 15
#
# 25
# 22
#
# 13
# 11
#
# 6
# 5
#
# 26
# 23
#
# 2
# 1
#
# 24
# 21
#
# 6
# 5
#
# 11
# 10
#
# 24
# 21
#
# 9
# 8
#
# 20
# 17
#
# 19
# 16
#
# 13
# 11
#
# 20
# 17
#
# 24
# 21
#
# 10
# 9
#
# 9
# 8
#
# 27
# 24
#
# 5
# 4
#
# 14
# 12
#
# 9
# 8
#
# 23
# 20
#
# 6
# 5
#
# 26
# 23
#
# 3
# 2
#
# 2
# 1
#
# 13
# 11
#
# 13
# 11
#
# 5
# 4
#
# 24
# 21
#
# 9
# 8
#
# 15
# 13
#
# 1
# 0
#
# 9
# 8
#
# 11
# 10
#
# 26
# 23
#
# 6
# 5
#
# 1
# 0
#
# 11
# 10
#
# 7
# 6
#
# 9
# 8
#
# 4
# 3
#
# 24
# 21
#
# 7
# 6
#
# 26
# 23
#
# 24
# 21
#
# 15
# 13
#
# 22
# 19
#
# 8
# 7
#
# 22
# 19
#
# 1
# 0
#
# 1
# 0
#
# 19
# 16
#
# 21
# 18
#
# 9
# 8
#
# 9
# 8
#
# 20
# 17
#
# 16
# 14
#
# 27
# 24
#
# 27
# 24
#
# 22
# 19
#
# 21
# 18
#
# 14
# 12
#
# 11
# 10
#
# 10
# 9
#
# 1
# 0
#
# 23
# 20
#
# 22
# 19
#
# 27
# 24
#
# 27
# 24
#
# 21
# 18
#
# 23
# 20
#
# 19
# 16
#
# 21
# 18
#
# 14
# 12
#
# 21
# 18
#
# 20
# 17
#
# 1
# 0
#
# 19
# 16
#
# 14
# 12
#
# 25
# 22
#
# 15
# 13
#
# 6
# 5
#
# 14
# 12
#
# 11
# 10
#
# 9
# 8
#
# 4
# 3
#
# 27
# 24
#
# 18
# 15
#
# 27
# 24
#
# 11
# 10
#
# 6
# 5
#
# 13
# 11
#
# 18
# 15
#
# 19
# 16
#
# 7
# 6
#
# 14
# 12
#
# 21
# 18
#
# 18
# 15
#
# 13
# 11
#
# 21
# 18
#
# 20
# 17
#
# 27
# 24
#
# 5
# 4
#
# 10
# 9
#
# 9
# 8
#
# 19
# 16
#
# 24
# 21
#
# 27
# 24
#
# 29
# 25
#
# 2
# 1
#
# 1
# 0
#
# 20
# 17
#
# 24
# 21
#
# 7
# 6
#
# 6
# 5
#
# 15
# 13
#
# 24
# 21
#
# 23
# 20
#
# 29
# 25
#
# 16
# 14
#
# 24
# 21
#
# 30
# 26
#
# 5
# 4
#
# 21
# 18
#
# 20
# 17
#
# 1
# 0
#
# 18
# 15
#
# 23
# 20
#
# 26
# 23
#
# 15
# 13
#
# 11
# 10
#
# 24
# 21
#
# 26
# 23
#
# 21
# 18
#
# 27
# 24
#
# 3
# 2
#
# 20
# 17
#
# 19
# 16
#
# 16
# 14
#
# 13
# 11
#
# 16
# 14
#
# 9
# 8
#
# 24
# 21
#
# 27
# 24
#
# 4
# 3
#
# 18
# 15
#
# 4
# 3
#
# 1
# 0
#
# 21
# 18
#
# 10
# 9
#
# 7
# 6
#
# 19
# 16
#
# 25
# 22
#
# 24
# 21
#
# 9
# 8
#
# 16
# 14
#
# 11
# 10
#
# 15
# 13
#
# 21
# 18
#
# 25
# 22
#
# 3
# 2
#
# 29
# 25
#
# 18
# 15
#
# 14
# 12
#
# 14
# 12
#
# 13
# 11
#
# 15
# 13
#
# 21
# 18
#
# 26
# 23
#
# 11
# 10
#
# 9
# 8
#
# 10
# 9
#
# 13
# 11
#
# 21
# 18
#
# 1
# 0
#
# 20
# 17
#
# 22
# 19
#
# 26
# 23
#
# 9
# 8
#
# 30
# 26
#
# 26
# 23
#
# 8
# 7
#
# 18
# 15
#
# 26
# 23
#
# 19
# 16
#
# 21
# 18
#
# 29
# 25
#
# 15
# 13
#
# 19
# 16
#
# 9
# 8
#
# 6
# 5
#
# 23
# 20
#
# 13
# 11
#
# 16
# 14
#
# 11
# 10
#
# 25
# 22
#
# 5
# 4
#
# 9
# 8
#
# 27
# 24
#
# 8
# 7
#
# 2
# 1
#
# 5
# 4
#
# 8
# 7
#
# 20
# 17
#
# 9
# 8
#
# 1
# 0
#
# 10
# 9
#
# 7
# 6
#
# 11
# 10
#
# 16
# 14
#
# 25
# 22
#
# 27
# 24
#
# 13
# 11
#
# 27
# 24
#
# 19
# 16
#
# 1
# 0
#
# 9
# 8
#
# 23
# 20
#
# 9
# 8
#
# 9
# 8
#
# 18
# 15
#
# 14
# 12
#
# 11
# 10
#
# 19
# 16
#
# 6
# 5
#
# 23
# 20
#
# 15
# 13
#
# 14
# 12
#
# 8
# 7
#
# 26
# 23
#
# 15
# 13
#
# 21
# 18
#
# 2
# 1
#
# 1
# 0
#
# 7
# 6
#
# 24
# 21
#
# 11
# 10
#
# 8
# 7
#
# 16
# 14
#
# 24
# 21
#
# 16
# 14
#
# 6
# 5
#
# 26
# 23
#
# 29
# 25
#
# 23
# 20
#
# 2
# 1

# %% [markdown]
# ### label_decoder encoder 재선언

# %%
import pandas as pd

label_csv = pd.read_csv('./data/public/PlantDoc/train/_modi_classes.txt')
columns_name = list(label_csv.columns)
columns_name.remove('filename')
columns_name.remove(' Potato leaf') # 12
columns_name.remove(' Soybean leaf') # 17
columns_name.remove(' Tomato two spotted spider mites leaf') # 28

label_encoder = {idx : val.lstrip() for idx, val in enumerate(columns_name)}
label_decoder = {val : key for key, val in label_encoder.items()}
display(label_encoder)
display(label_decoder)
# Out:
# {0: 'Apple Scab Leaf',
#  1: 'Apple leaf',
#  2: 'Apple rust leaf',
#  3: 'Bell_pepper leaf',
#  4: 'Bell_pepper leaf spot',
#  5: 'Blueberry leaf',
#  6: 'Cherry leaf',
#  7: 'Corn Gray leaf spot',
#  8: 'Corn leaf blight',
#  9: 'Corn rust leaf',
#  10: 'Peach leaf',
#  11: 'Potato leaf early blight',
#  12: 'Potato leaf late blight',
#  13: 'Raspberry leaf',
#  14: 'Soyabean leaf',
#  15: 'Squash Powdery mildew leaf',
#  16: 'Strawberry leaf',
#  17: 'Tomato Early blight leaf',
#  18: 'Tomato Septoria leaf spot',
#  19: 'Tomato leaf',
#  20: 'Tomato leaf bacterial spot',
#  21: 'Tomato leaf late blight',
#  22: 'Tomato leaf mosaic virus',
#  23: 'Tomato leaf yellow virus',
#  24: 'Tomato mold leaf',
#  25: 'grape leaf',
#  26: 'grape leaf black rot'}
# {'Apple Scab Leaf': 0,
#  'Apple leaf': 1,
#  'Apple rust leaf': 2,
#  'Bell_pepper leaf': 3,
#  'Bell_pepper leaf spot': 4,
#  'Blueberry leaf': 5,
#  'Cherry leaf': 6,
#  'Corn Gray leaf spot': 7,
#  'Corn leaf blight': 8,
#  'Corn rust leaf': 9,
#  'Peach leaf': 10,
#  'Potato leaf early blight': 11,
#  'Potato leaf late blight': 12,
#  'Raspberry leaf': 13,
#  'Soyabean leaf': 14,
#  'Squash Powdery mildew leaf': 15,
#  'Strawberry leaf': 16,
#  'Tomato Early blight leaf': 17,
#  'Tomato Septoria leaf spot': 18,
#  'Tomato leaf': 19,
#  'Tomato leaf bacterial spot': 20,
#  'Tomato leaf late blight': 21,
#  'Tomato leaf mosaic virus': 22,
#  'Tomato leaf yellow virus': 23,
#  'Tomato mold leaf': 24,
#  'grape leaf': 25,
#  'grape leaf black rot': 26}

# %% [markdown]
# ### 라벨 카운트

# %%
label_cnt = {k : 0 for k, v in label_decoder.items()}

for i in label_list :
    label_cnt[label_encoder[i]] += 1

display(label_cnt)
# Out:
# {'Apple Scab Leaf': 83,
#  'Apple leaf': 82,
#  'Apple rust leaf': 78,
#  'Bell_pepper leaf': 53,
#  'Bell_pepper leaf spot': 62,
#  'Blueberry leaf': 103,
#  'Cherry leaf': 47,
#  'Corn Gray leaf spot': 61,
#  'Corn leaf blight': 178,
#  'Corn rust leaf': 106,
#  'Peach leaf': 101,
#  'Potato leaf early blight': 103,
#  'Potato leaf late blight': 94,
#  'Raspberry leaf': 112,
#  'Soyabean leaf': 57,
#  'Squash Powdery mildew leaf': 124,
#  'Strawberry leaf': 87,
#  'Tomato Early blight leaf': 79,
#  'Tomato Septoria leaf spot': 137,
#  'Tomato leaf': 56,
#  'Tomato leaf bacterial spot': 101,
#  'Tomato leaf late blight': 99,
#  'Tomato leaf mosaic virus': 44,
#  'Tomato leaf yellow virus': 68,
#  'Tomato mold leaf': 86,
#  'grape leaf': 57,
#  'grape leaf black rot': 56}

# %% [markdown]
# # Custom dataset 정의

# %%
class DocDataset(Dataset) :
    def __init__(self, imgs, labels, transform) :
        super(VillageDataset, self).__init__()
        self.imgs = imgs
        self.labels = labels
        self.transform = transform
        
    def __len__(self) :
        assert len(self.imgs) == len(self.labels)
        return len(self.imgs)
    
    def __getitem__(self, idx) :
        
        label = self.labels[idx]
        
        img = cv2.imread(self.imgs[idx])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = self.transform(image=img)['image']
        img = img.transpose(2, 0, 1)
        
        return torch.tensor(img, dtype=torch.float32), torch.tensor(label, dtype=torch.long)

# %% [markdown]
# # DataLoader w/o kfold

# %%
train_transforms = A.Compose([
                A.Resize(224 ,224),
                A.OneOf([
                    A.Rotate(),
                    A.HorizontalFlip(),
                    A.VerticalFlip()
                ], p=1)
            ])

val_transforms = A.Compose([
    A.Resize(224,224)
])


train_img, val_img, train_label, val_label = train_test_split(img_list, label_list, test_size=0.3, shuffle=True, stratify=label_list)

print("train_img : ", len(train_img))
print("train_lable : ", len(train_label))

print("val_img : ", len(val_img))
print("val_lable : ", len(val_label))

print(train_img[572])
print(train_label[572])

# train_dataset = VillageDataset(train, train_transforms)
# val_dataset = VillageDataset(val, val_transforms)

# train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
# val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
# Out:
# train_img :  1619
# train_lable :  1619
# val_img :  695
# val_lable :  695
# ./data/public/PlantDoc/train/fpls-08-01602-g001_jpg.rf.cb2535a202d5ec940624e190d81f3526.jpg
# 19

# %% [markdown]
# # Doc +Village = 라벨 합치기
# - Doc == Village
# - 11: 'Potato leaf early blight', ==  2: 'Potato___Early_blight',
# - 12: 'Potato leaf late blight', ==  4: 'Potato___Late_blight',
# - 17: 'Tomato Early blight leaf', ==  6: 'Tomato_Early_blight',
# - 18: 'Tomato Septoria leaf spot', ==  10: 'Tomato_Septoria_leaf_spot',
# - 19: 'Tomato leaf', ==  7: 'Tomato_healthy',
# - 20: 'Tomato leaf bacterial spot', ==  5: 'Tomato_Bacterial_spot',
# - 21: 'Tomato leaf late blight', ==  8: 'Tomato_Late_blight',
# - 22: 'Tomato leaf mosaic virus', ==  13: 'Tomato__Tomato_mosaic_virus',
# - 23: 'Tomato leaf yellow virus', ==  14: 'Tomato__Tomato_YellowLeaf__Curl_Virus'

# %% [markdown]
# ## Village img, label data

# %%
village_data = os.listdir('./data/public/PlantVillage')
vill_label_encoder = {}
for idx, data_name in enumerate(village_data) :
    vill_label_encoder[idx] = data_name

vill_label_decoder = {val:key for key, val in vill_label_encoder.items()}
display(vill_label_decoder)
display(vill_label_encoder)

vill_img_list = glob('./data/public/PlantVillage/*/*.JPG')
vill_label_list = [vill_label_decoder[img_path.split('\\')[-2]] for img_path in vill_img_list]

print(len(vill_img_list))
print(len(vill_label_list))
# Out:
# {'Pepper__bell___Bacterial_spot': 0,
#  'Pepper__bell___healthy': 1,
#  'Potato___Early_blight': 2,
#  'Potato___healthy': 3,
#  'Potato___Late_blight': 4,
#  'Tomato_Bacterial_spot': 5,
#  'Tomato_Early_blight': 6,
#  'Tomato_healthy': 7,
#  'Tomato_Late_blight': 8,
#  'Tomato_Leaf_Mold': 9,
#  'Tomato_Septoria_leaf_spot': 10,
#  'Tomato_Spider_mites_Two_spotted_spider_mite': 11,
#  'Tomato__Target_Spot': 12,
#  'Tomato__Tomato_mosaic_virus': 13,
#  'Tomato__Tomato_YellowLeaf__Curl_Virus': 14}
# {0: 'Pepper__bell___Bacterial_spot',
#  1: 'Pepper__bell___healthy',
#  2: 'Potato___Early_blight',
#  3: 'Potato___healthy',
#  4: 'Potato___Late_blight',
#  5: 'Tomato_Bacterial_spot',
#  6: 'Tomato_Early_blight',
#  7: 'Tomato_healthy',
#  8: 'Tomato_Late_blight',
#  9: 'Tomato_Leaf_Mold',
#  10: 'Tomato_Septoria_leaf_spot',
#  11: 'Tomato_Spider_mites_Two_spotted_spider_mite',
#  12: 'Tomato__Target_Spot',
#  13: 'Tomato__Tomato_mosaic_virus',
#  14: 'Tomato__Tomato_YellowLeaf__Curl_Virus'}
# 20636
# 20636

# %% [markdown]
# ## Doc img, label data

# %%
import copy
doc_img_list = copy.deepcopy(img_list)
doc_label_list = copy.deepcopy(label_list)

doc_label_decoder = copy.deepcopy(label_decoder) 
doc_label_encoder = copy.deepcopy(label_encoder)

display(doc_label_decoder)
display(doc_label_encoder)
print(len(doc_img_list))
print(len(doc_label_list))
# Out:
# {'Apple Scab Leaf': 0,
#  'Apple leaf': 1,
#  'Apple rust leaf': 2,
#  'Bell_pepper leaf': 3,
#  'Bell_pepper leaf spot': 4,
#  'Blueberry leaf': 5,
#  'Cherry leaf': 6,
#  'Corn Gray leaf spot': 7,
#  'Corn leaf blight': 8,
#  'Corn rust leaf': 9,
#  'Peach leaf': 10,
#  'Potato leaf early blight': 11,
#  'Potato leaf late blight': 12,
#  'Raspberry leaf': 13,
#  'Soyabean leaf': 14,
#  'Squash Powdery mildew leaf': 15,
#  'Strawberry leaf': 16,
#  'Tomato Early blight leaf': 17,
#  'Tomato Septoria leaf spot': 18,
#  'Tomato leaf': 19,
#  'Tomato leaf bacterial spot': 20,
#  'Tomato leaf late blight': 21,
#  'Tomato leaf mosaic virus': 22,
#  'Tomato leaf yellow virus': 23,
#  'Tomato mold leaf': 24,
#  'grape leaf': 25,
#  'grape leaf black rot': 26}
# {0: 'Apple Scab Leaf',
#  1: 'Apple leaf',
#  2: 'Apple rust leaf',
#  3: 'Bell_pepper leaf',
#  4: 'Bell_pepper leaf spot',
#  5: 'Blueberry leaf',
#  6: 'Cherry leaf',
#  7: 'Corn Gray leaf spot',
#  8: 'Corn leaf blight',
#  9: 'Corn rust leaf',
#  10: 'Peach leaf',
#  11: 'Potato leaf early blight',
#  12: 'Potato leaf late blight',
#  13: 'Raspberry leaf',
#  14: 'Soyabean leaf',
#  15: 'Squash Powdery mildew leaf',
#  16: 'Strawberry leaf',
#  17: 'Tomato Early blight leaf',
#  18: 'Tomato Septoria leaf spot',
#  19: 'Tomato leaf',
#  20: 'Tomato leaf bacterial spot',
#  21: 'Tomato leaf late blight',
#  22: 'Tomato leaf mosaic virus',
#  23: 'Tomato leaf yellow virus',
#  24: 'Tomato mold leaf',
#  25: 'grape leaf',
#  26: 'grape leaf black rot'}
# 2314
# 2314

# %% [markdown]
# ## Village -> Doc

# %% [markdown]
# ### Village Label 번호 변경

# %%
 # {vill : doc}
same_label_list_encoder = {0:27, 1:28, 2:11, 3:29, 4:12, 5:20, 6:17, 7:19, 8:21, 9:30, 10:18, 11:31, 12:32, 13:22, 14:23}
for i in range(0, len(vill_label_list)) :
    vill_label_list[i] = same_label_list_encoder[vill_label_list[i]]

# %% [markdown]
# ## add

# %%
sum_img_list = doc_img_list + vill_img_list
sum_label_list = doc_label_list + vill_label_list

print(len(sum_img_list))
print(len(sum_label_list))
# Out:
# 22950
# 22950

# %% [markdown]
# ## sum_label_encoder decoder 선언

# %%
same_label_list_encoder = {0:27, 1:28, 2:11, 3:29, 4:12, 5:20, 6:17, 7:19, 8:21, 9:30, 10:18, 11:31, 12:32, 13:22, 14:23}
same_label_list_decoder = {v : k for k, v in same_label_list_encoder.items()}

additional_list = [0, 1, 3, 9, 11, 12]

sum_label_encoder = {}
for i in range(0, 33) :
    if i in same_label_list_decoder and i in doc_label_encoder :
        sum_label_encoder[i] = doc_label_encoder[i]
#         sum_label_encoder[vill_label_encoder[i]] = same_label_list_encoder[i]

    elif i in same_label_list_decoder and i not in doc_label_encoder :
        sum_label_encoder[i] = vill_label_encoder[same_label_list_decoder[i]]
#         sum_label_encoder[doc_label_encoder[i]] = same_label_list_encoder[i]
        
    elif i not in same_label_list_decoder and i in doc_label_encoder :
        sum_label_encoder[i] = doc_label_encoder[i]
        
sum_label_decoder = {v : k for k, v in sum_label_encoder.items()}

display(sum_label_encoder)
display(sum_label_decoder)
# Out:
# {0: 'Apple Scab Leaf',
#  1: 'Apple leaf',
#  2: 'Apple rust leaf',
#  3: 'Bell_pepper leaf',
#  4: 'Bell_pepper leaf spot',
#  5: 'Blueberry leaf',
#  6: 'Cherry leaf',
#  7: 'Corn Gray leaf spot',
#  8: 'Corn leaf blight',
#  9: 'Corn rust leaf',
#  10: 'Peach leaf',
#  11: 'Potato leaf early blight',
#  12: 'Potato leaf late blight',
#  13: 'Raspberry leaf',
#  14: 'Soyabean leaf',
#  15: 'Squash Powdery mildew leaf',
#  16: 'Strawberry leaf',
#  17: 'Tomato Early blight leaf',
#  18: 'Tomato Septoria leaf spot',
#  19: 'Tomato leaf',
#  20: 'Tomato leaf bacterial spot',
#  21: 'Tomato leaf late blight',
#  22: 'Tomato leaf mosaic virus',
#  23: 'Tomato leaf yellow virus',
#  24: 'Tomato mold leaf',
#  25: 'grape leaf',
#  26: 'grape leaf black rot',
#  27: 'Pepper__bell___Bacterial_spot',
#  28: 'Pepper__bell___healthy',
#  29: 'Potato___healthy',
#  30: 'Tomato_Leaf_Mold',
#  31: 'Tomato_Spider_mites_Two_spotted_spider_mite',
#  32: 'Tomato__Target_Spot'}
# {'Apple Scab Leaf': 0,
#  'Apple leaf': 1,
#  'Apple rust leaf': 2,
#  'Bell_pepper leaf': 3,
#  'Bell_pepper leaf spot': 4,
#  'Blueberry leaf': 5,
#  'Cherry leaf': 6,
#  'Corn Gray leaf spot': 7,
#  'Corn leaf blight': 8,
#  'Corn rust leaf': 9,
#  'Peach leaf': 10,
#  'Potato leaf early blight': 11,
#  'Potato leaf late blight': 12,
#  'Raspberry leaf': 13,
#  'Soyabean leaf': 14,
#  'Squash Powdery mildew leaf': 15,
#  'Strawberry leaf': 16,
#  'Tomato Early blight leaf': 17,
#  'Tomato Septoria leaf spot': 18,
#  'Tomato leaf': 19,
#  'Tomato leaf bacterial spot': 20,
#  'Tomato leaf late blight': 21,
#  'Tomato leaf mosaic virus': 22,
#  'Tomato leaf yellow virus': 23,
#  'Tomato mold leaf': 24,
#  'grape leaf': 25,
#  'grape leaf black rot': 26,
#  'Pepper__bell___Bacterial_spot': 27,
#  'Pepper__bell___healthy': 28,
#  'Potato___healthy': 29,
#  'Tomato_Leaf_Mold': 30,
#  'Tomato_Spider_mites_Two_spotted_spider_mite': 31,
#  'Tomato__Target_Spot': 32}
